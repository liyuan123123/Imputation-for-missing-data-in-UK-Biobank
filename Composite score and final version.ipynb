# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import statistics
import warnings
import numpy as np
import os
warnings.filterwarnings('ignore')
pd.set_option("display.max_rows", None)#可显示1000行
pd.set_option("display.max_columns", None)#可显示1000列

# %%
file_Pwd=('../UKB')
Category_Name=['Anthropometry','Arterial_stiffness','Blood_Urine','Bone_densitometry_of_heel','Cognitive','Carotid_ultrasound','ECG_at_rest','ECG_during_exercise','Eyesight','Food_24_hours','Hearing','Lifestyle','Physical_activity','Male_specific_factors','Mental_health_web_based_questionnaire','Mental_health_assessment_questionnaire','Sociodemographics','Spirometry','Physical_health','Female_specific_factors','Digestive_health']

# %%
#Anthropometry
j=0
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df['Leg fat mass (right)-0.0'][df['Leg fat mass (right)-0.0'].isna()]=df['Leg fat mass (left)-0.0'][df['Leg fat mass (right)-0.0'].isna()]
df['Leg fat-free mass (left)-0.0'][df['Leg fat-free mass (left)-0.0'].isna()]=df['Leg predicted mass (left)-0.0'][df['Leg fat-free mass (left)-0.0'].isna()]
df['Leg fat-free mass (right)-0.0'][df['Leg fat-free mass (right)-0.0'].isna()]=df['Leg fat-free mass (left)-0.0'][df['Leg fat-free mass (right)-0.0'].isna()]
df['Leg predicted mass (right)-0.0'][df['Leg predicted mass (right)-0.0'].isna()]=df['Leg predicted mass (left)-0.0'][df['Leg predicted mass (right)-0.0'].isna()]
df['Leg fat percentage (right)-0.0'][df['Leg fat percentage (right)-0.0'].isna()]=df['Leg fat percentage (left)-0.0'][df['Leg fat percentage (right)-0.0'].isna()]
df['Arm fat-free mass (left)-0.0'][df['Arm fat-free mass (left)-0.0'].isna()]=df['Arm predicted mass (left)-0.0'][df['Arm fat-free mass (left)-0.0'].isna()]
df['Arm fat percentage (right)-0.0'][df['Arm fat percentage (right)-0.0'].isna()]=df['Arm fat percentage (left)-0.0'][df['Arm fat percentage (right)-0.0'].isna()]
df['Arm fat-free mass (right)-0.0'][df['Arm fat-free mass (right)-0.0'].isna()]=df['Arm fat-free mass (left)-0.0'][df['Arm fat-free mass (right)-0.0'].isna()]
df['Arm fat mass (right)-0.0'][df['Arm fat mass (right)-0.0'].isna()]=df['Arm fat mass (left)-0.0'][df['Arm fat mass (right)-0.0'].isna()]
df['Arm predicted mass (right)-0.0'][df['Arm predicted mass (right)-0.0'].isna()]=df['Arm predicted mass (left)-0.0'][df['Arm predicted mass (right)-0.0'].isna()]
df['Trunk predicted mass-0.0'][df['Trunk predicted mass-0.0'].isna()]=df['Trunk fat-free mass-0.0'][df['Trunk predicted mass-0.0'].isna()]
df['Whole body water mass-0.0'][df['Whole body water mass-0.0'].isna()]=df['Whole body fat-free mass-0.0'][df['Whole body water mass-0.0'].isna()]
df['Impedance of arm (right)-0.0'][df['Impedance of arm (right)-0.0'].isna()]=df['Impedance of arm (left)-0.0'][df['Impedance of arm (right)-0.0'].isna()]
df=df.set_index('eid')
df['Hand grip strength-0.0']=(df['Hand grip strength (left)-0.0']+df['Hand grip strength (right)-0.0'])/2
del df['Hand grip strength (left)-0.0']
del df['Hand grip strength (right)-0.0']
df['Impedance of leg-0.0']=(df['Impedance of leg (right)-0.0']+df['Impedance of leg (left)-0.0'])/2
del df['Impedance of leg (right)-0.0']
del df['Impedance of leg (left)-0.0']
df['Impedance of arm-0.0']=(df['Impedance of arm (right)-0.0']+df['Impedance of arm (left)-0.0'])/2
del df['Impedance of arm (right)-0.0']
del df['Impedance of arm (left)-0.0']
df['Leg fat percentage-0.0']=(df['Leg fat percentage (left)-0.0']+df['Leg fat percentage (left)-0.0'])/2
del df['Leg fat percentage (left)-0.0']
del df['Leg fat percentage (right)-0.0']
df['Leg fat mass-0.0']=(df['Leg fat mass (left)-0.0']+df['Leg fat mass (right)-0.0'])/2
del df['Leg fat mass (left)-0.0']
del df['Leg fat mass (right)-0.0']
df['Leg predicted mass-0.0']=(df['Leg predicted mass (left)-0.0']+df['Leg predicted mass (right)-0.0'])/2
del df['Leg predicted mass (left)-0.0']
del df['Leg predicted mass (right)-0.0']
df['Arm fat percentage-0.0']=(df['Arm fat percentage (left)-0.0']+df['Arm fat percentage (left)-0.0'])/2
del df['Arm fat percentage (left)-0.0']
del df['Arm fat percentage (right)-0.0']
df['Arm fat mass-0.0']=(df['Arm fat mass (left)-0.0']+df['Arm fat mass (right)-0.0'])/2
del df['Arm fat mass (left)-0.0']
del df['Arm fat mass (right)-0.0']
df['Arm predicted mass-0.0']=(df['Arm predicted mass (left)-0.0']+df['Arm predicted mass (right)-0.0'])/2
del df['Arm predicted mass (left)-0.0']
del df['Arm predicted mass (right)-0.0']
df['Leg fat-free mass-0.0']=(df['Leg fat-free mass (left)-0.0']+df['Leg fat-free mass (right)-0.0'])/2
del df['Leg fat-free mass (left)-0.0']
del df['Leg fat-free mass (right)-0.0']
df['Arm fat-free mass-0.0']=(df['Arm fat-free mass (left)-0.0']+df['Arm fat-free mass (right)-0.0'])/2
del df['Arm fat-free mass (left)-0.0']
del df['Arm fat-free mass (right)-0.0']
df[df<0]=0
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 502146 entries, 1000012.0 to 6024933.0
# Data columns (total 33 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Age when attended assessment centre-0.0  502146 non-null  int64
#  1   Waist circumference-0.0                  502146 non-null  float64
#  2   Hip circumference-0.0                    502146 non-null  float64
#  3   Standing height-0.0                      502146 non-null  float64
#  4   Seated height-0.0                        502146 non-null  float64
#  5   Comparative body size at age 10-0.0      502146 non-null  int64
#  6   Comparative height size at age 10-0.0    502146 non-null  int64
#  7   Handedness (chirality/laterality)-0.0    502146 non-null  int64
#  8   Seating box height-0.0                   502146 non-null  int64
#  9   Sitting height-0.0                       502146 non-null  float64
# ...

# %%
#Arterial stiffness
j=1
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df[df<0]=0
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 172803 entries, 1000012.0 to 6024887.0
# Data columns (total 9 columns):
#  #   Column                                               Non-Null Count   Dtype
# ---  ------                                               --------------   -----
#  0   Age when attended assessment centre-0.0              172803 non-null  int64
#  1   Pulse rate-0.0                                       172803 non-null  float64
#  2   Pulse wave reflection index-0.0                      172803 non-null  float64
#  3   Pulse wave peak to peak time-0.0                     172803 non-null  float64
#  4   Position of the pulse wave peak-0.0                  172803 non-null  float64
#  5   Position of pulse wave notch-0.0                     172803 non-null  float64
#  6   Position of the shoulder on the pulse waveform-0.0   172803 non-null  float64
#  7   Absence of notch position in the pulse waveform-0.0  172803 non-null  int64
# ...

# %%
#Blood and Urine
j=2
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['High light scatter reticulocyte count-0.0']=df['High light scatter reticulocyte count-0.0']/100
df[df<0]=0
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 498507 entries, 1000012.0 to 6024933.0
# Data columns (total 66 columns):
#  #   Column                                               Non-Null Count   Dtype
# ---  ------                                               --------------   -----
#  0   Age when attended assessment centre-0.0              498507 non-null  int64
#  1   Microalbumin in urine-0.0                            498507 non-null  float64
#  2   Creatinine (enzymatic) in urine-0.0                  498507 non-null  float64
#  3   Potassium in urine-0.0                               498507 non-null  float64
#  4   Sodium in urine-0.0                                  498507 non-null  float64
#  5   White blood cell (leukocyte) count-0.0               498507 non-null  float64
#  6   Red blood cell (erythrocyte) count-0.0               498507 non-null  float64
#  7   Haemoglobin concentration-0.0                        498507 non-null  float64
# ...

# %%
#Bone-densitometry of heel
j=3
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Heel quantitative ultrasound index (QUI), direct entry-0.0'][df['Heel quantitative ultrasound index (QUI), direct entry-0.0'].isna()]=df['Heel bone mineral density (BMD)-0.0'][df['Heel quantitative ultrasound index (QUI), direct entry-0.0'].isna()]*178
df['Heel bone mineral density (BMD) T-score, automated-0.0'].fillna(df['Heel bone mineral density (BMD) T-score, automated-0.0'].mean(),inplace=True)
df['Heel bone mineral density (BMD)-0.0'][df['Heel bone mineral density (BMD)-0.0']<0]=0
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[i for i in range(0,5)]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 488753 entries, 1000012.0 to 6024933.0
# Data columns (total 9 columns):
#  #   Column                                                      Non-Null Count   Dtype
# ---  ------                                                      --------------   -----
#  0   Age when attended assessment centre-0.0                     488753 non-null  int64
#  1   Ankle spacing width-0.0                                     488753 non-null  float64
#  2   Heel Broadband ultrasound attenuation, direct entry-0.0     488753 non-null  float64
#  3   Speed of sound through heel-0.0                             488753 non-null  float64
#  4   Heel bone mineral density (BMD)-0.0                         488753 non-null  float64
#  5   Heel quantitative ultrasound index (QUI), direct entry-0.0  488753 non-null  float64
#  6   Heel bone mineral density (BMD) T-score, automated-0.0      488753 non-null  float64
# ...

# %%
#Cognitive
j=4
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['FI7 : synonym-0.0'].fillna(3,inplace=True)
df['Number of symbol digit matches made correctly-0.0'][df['Number of symbol digit matches made correctly-0.0'].isna()]=df['Number of symbol digit matches attempted-0.0'][df['Number of symbol digit matches made correctly-0.0'].isna()]
for i in range(1,8):
    df['Values entered-0.'+str(i)][df['Values entered-0.'+str(i)].isna()]=df['Values wanted-0.'+str(i)][df['Values entered-0.'+str(i)].isna()]
for i in range(9,32):
    df['Values wanted-0.'+str(i)][df['Values wanted-0.'+str(i)].isna()]=df['Values entered-0.'+str(i)][df['Values wanted-0.'+str(i)].isna()]
df[df<0]=0
df=df.astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[0,1,2,6,7,8,9,21,23,25]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 125482 entries, 1000085.0 to 6024933.0
# Data columns (total 227 columns):
#  #    Column                                                                                Non-Null Count   Dtype
# ---   ------                                                                                --------------   -----
#  0    Age when attended assessment centre-0.0                                               125482 non-null  int32
#  1    Duration to complete numeric path (trail #1)-0.0                                      125482 non-null  int32
#  2    Duration to complete alphanumeric path (trail #2)-0.0                                 125482 non-null  int32
#  3    First code array presented-0.0                                                        125482 non-null  int32
#  4    Values entered-0.0                                                                    125482 non-null  int32
# ...

# %%
#Carotid ultrasound
j=5
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df=df.astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 47067 entries, 1000160.0 to 6024822.0
# Data columns (total 13 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Age when attended assessment centre-2.0                           47067 non-null  int32
#  1   Minimum carotid IMT (intima-medial thickness) at 120 degrees-2.0  47067 non-null  int32
#  2   Mean carotid IMT (intima-medial thickness) at 120 degrees-2.0     47067 non-null  int32
#  3   Maximum carotid IMT (intima-medial thickness) at 120 degrees-2.0  47067 non-null  int32
#  4   Minimum carotid IMT (intima-medial thickness) at 150 degrees-2.0  47067 non-null  int32
#  5   Mean carotid IMT (intima-medial thickness) at 150 degrees-2.0     47067 non-null  int32
#  6   Maximum carotid IMT (intima-medial thickness) at 150 degrees-2.0  47067 non-null  int32
# ...

# %%
#ECG at rest
j=6
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df=df.astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 42385 entries, 1000160.0 to 6024646.0
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Age when attended assessment centre-2.0  42385 non-null  int32
#  1   Ventricular rate-2.0                     42385 non-null  int32
#  2   P duration-2.0                           42385 non-null  int32
#  3   QRS duration-2.0                         42385 non-null  int32
#  4   PQ interval-2.0                          42385 non-null  int32
#  5   QT interval-2.0                          42385 non-null  int32
#  6   QTC interval-2.0                         42385 non-null  int32
#  7   RR interval-2.0                          42385 non-null  int32
#  8   PP interval-2.0                          42385 non-null  int32
#  9   P axis-2.0                               42385 non-null  int32
# ...

# %%
#ECG during exercise
j=7
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['ECG, phase duration-0.0'].fillna(15,inplace=True)
df['ECG, phase duration-0.1'].fillna(360,inplace=True)
df['ECG, phase duration-0.2'].fillna(60,inplace=True)
df['ECG, number of stages in a phase-0.1'].fillna(df['ECG, number of stages in a phase-0.1'].mean(),inplace=True)
df['ECG, number of stages in a phase-0.2'].fillna(1,inplace=True)
df['ECG, heart rate-0.46'][df['ECG, heart rate-0.46'].isna()]=df['ECG, heart rate-0.45'][df['ECG, heart rate-0.46'].isna()]
df['ECG, heart rate-0.10'][df['ECG, heart rate-0.10'].isna()]=df['ECG, heart rate-0.11'][df['ECG, heart rate-0.10'].isna()]
df['ECG, load-0.27'][df['ECG, load-0.27'].isna()]=df['ECG, load-0.28'][df['ECG, load-0.27'].isna()]
df['ECG, load-0.43'][df['ECG, load-0.43'].isna()]=df['ECG, load-0.44'][df['ECG, load-0.43'].isna()]
df['Bicycle speed-0.2'][df['Bicycle speed-0.2'].isna()]=df['Bicycle speed-0.1'][df['Bicycle speed-0.2'].isna()]
for i in range(12,60):
    df['Bicycle speed-0.'+str(i)][df['Bicycle speed-0.'+str(i)].isna()]=df['Bicycle speed-0.'+str(i-1)][df['Bicycle speed-0.'+str(i)].isna()]
for i in [57,58,59,19,20,21,22,23,24,25,26]:
    df['ECG, phase time-0.'+str(i)][df['ECG, phase time-0.'+str(i)].isna()]=df['ECG, phase time-0.'+str(i-1)][df['ECG, phase time-0.'+str(i)].isna()]
for i in [7,8,9,10,27]:
    df['ECG, phase time-0.'+str(i)].fillna(df['ECG, phase time-0.'+str(i)].mean(),inplace=True)
for i in [i for i in range(2,10)]+[i for i in range(12,60)]:
    df['ECG, heart rate-0.'+str(i)][df['ECG, heart rate-0.'+str(i)].isna()]=df['ECG, heart rate-0.'+str(i-1)][df['ECG, heart rate-0.'+str(i)].isna()]
for i in [i for i in range(7,60)]:
    df['ECG, load-0.'+str(i)][df['ECG, load-0.'+str(i)].isna()]=df['ECG, load-0.'+str(i-1)][df['ECG, load-0.'+str(i)].isna()]
df[df<0]=0
df=df.astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[0,3,4,5,7]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 79201 entries, 1000193.0 to 6024887.0
# Data columns (total 256 columns):
#  #    Column                                                         Non-Null Count  Dtype
# ---   ------                                                         --------------  -----
#  0    Age when attended assessment centre-0.0                        79201 non-null  int32
#  1    ECG, heart rate-0.0                                            79201 non-null  int32
#  2    ECG, phase time-0.0                                            79201 non-null  int32
#  3    Maximum workload during fitness test-0.0                       79201 non-null  int32
#  4    Maximum heart rate during fitness test-0.0                     79201 non-null  int32
#  5    Target heart rate achieved-0.0                                 79201 non-null  int32
#  6    Number of trend entries-0.0                                    79201 non-null  int32
# ...

# %%
#Eyesight
j=8
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Duration at which refractometer first shown (left)-0.0'].fillna(df['Duration at which refractometer first shown (left)-0.0'].mean(),inplace=True)
df['Glasses worn/required (right)-0.0'][df['Glasses worn/required (right)-0.0'].isna()]=df['Glasses worn/required (left)-0.0'][df['Glasses worn/required (right)-0.0'].isna()]
df['logMAR in round (left)-0.0'].fillna(df['logMAR in round (left)-0.0'].mean(),inplace=True)
df['logMAR in round (right)-0.0'].fillna(df['logMAR in round (right)-0.0'].mean(),inplace=True)
for i in range(1,16):
    df['logMAR in round (right)-0.'+str(i)]=df['logMAR in round (right)-0.'+str(i-1)]-0.1
    df['logMAR in round (left)-0.'+str(i)]=df['logMAR in round (left)-0.'+str(i-1)]-0.1
df['6mm weak meridian (left)-0.0'][df['6mm weak meridian (left)-0.0'].isna()]=df['3mm weak meridian (right)-0.0'][df['6mm weak meridian (left)-0.0'].isna()]
df['3mm weak meridian (left)-0.0'][df['3mm weak meridian (left)-0.0'].isna()]=df['3mm weak meridian (right)-0.0'][df['3mm weak meridian (left)-0.0'].isna()]
df['6mm weak meridian (right)-0.0'][df['6mm weak meridian (right)-0.0'].isna()]=df['6mm weak meridian (left)-0.0'][df['6mm weak meridian (right)-0.0'].isna()]
df['3mm strong meridian (right)-0.0'][df['3mm strong meridian (right)-0.0'].isna()]=df['6mm strong meridian (left)-0.0'][df['3mm strong meridian (right)-0.0'].isna()]
df['3mm strong meridian (left)-0.0'][df['3mm strong meridian (left)-0.0'].isna()]=df['6mm strong meridian (left)-0.0'][df['3mm strong meridian (left)-0.0'].isna()]
df['6mm strong meridian (right)-0.0'][df['6mm strong meridian (right)-0.0'].isna()]=df['6mm strong meridian (left)-0.0'][df['6mm strong meridian (right)-0.0'].isna()]
df['Duration at which refractometer first shown (right)-0.0'].fillna(df['Duration at which refractometer first shown (right)-0.0'].mean(),inplace=True)
df = df.drop(df.columns[[i for i in range(59,97)]+[i for i in range(109,113)]+[i for i in range(125,141)]+[i for i in range(144,195)]+[i for i in range(225,270)]], axis = 1)
df['Index of best refractometry result (right)-0.0']=df['Index of best refractometry result (right)-0.0'].astype(int)
df['3mm index of best keratometry results (right)-0.0']=df['3mm index of best keratometry results (right)-0.0'].astype(int)
df['6mm index of best keratometry results (right)-0.0']=df['6mm index of best keratometry results (right)-0.0'].astype(int)
df['Intra-ocular pressure, corneal-compensated (right)-0.0'][df['Intra-ocular pressure, corneal-compensated (right)-0.0']<0]=0
df['Intra-ocular pressure, Goldmann-correlated (right)-0.0'][df['Intra-ocular pressure, Goldmann-correlated (right)-0.0']<0]=0
df['Intra-ocular pressure, corneal-compensated (left)-0.0'][df['Intra-ocular pressure, corneal-compensated (left)-0.0']<0]=0
df['Intra-ocular pressure, Goldmann-correlated (left)-0.0'][df['Intra-ocular pressure, Goldmann-correlated (left)-0.0']<0]=0
df['Corneal resistance factor (left)-0.0'][df['Corneal resistance factor (left)-0.0']<0]=0
df['Index of best refractometry result (left)-0.0']=df['Index of best refractometry result (left)-0.0'].astype(int)
df['3mm index of best keratometry results (left)-0.0']=df['3mm index of best keratometry results (left)-0.0'].astype(int)
df['6mm index of best keratometry results (left)-0.0']=df['6mm index of best keratometry results (left)-0.0'].astype(int)
df['Cylindrical power (left)-0.0']=df['Cylindrical power (left)-0.0'].astype(int)
df['Cylindrical power (right)-0.0']=df['Cylindrical power (right)-0.0'].astype(int)
df['Astigmatism angle (right)-0.0']=df['Astigmatism angle (right)-0.0'].astype(int)
df['Astigmatism angle (left)-0.0']=df['Astigmatism angle (left)-0.0'].astype(int)
df['Number of rounds to result (left)-0.0']=df['Number of rounds to result (left)-0.0'].astype(int)
df['Duration at which refractometer first shown (right)-0.0']=df['Duration at which refractometer first shown (right)-0.0'].astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[0,4,5,8,9,16,17,20,21,22,23,24,25,54,57]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117674 entries, 1000012 to 6024887
# Data columns (total 116 columns):
#  #    Column                                                            Non-Null Count   Dtype
# ---   ------                                                            --------------   -----
#  0    Age when attended assessment centre-0.0                           117674 non-null  int64
#  1    Index of best refractometry result (right)-0.0                    117674 non-null  int32
#  2    3mm index of best keratometry results (right)-0.0                 117674 non-null  int32
#  3    6mm index of best keratometry results (right)-0.0                 117674 non-null  int32
#  4    Intra-ocular pressure, corneal-compensated (right)-0.0            117674 non-null  float64
#  5    Intra-ocular pressure, Goldmann-correlated (right)-0.0            117674 non-null  float64
# ...

# %%
#Food-24 hours
j=9
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df[df<0]=0
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103780 entries, 1000031 to 6024822
# Data columns (total 27 columns):
#  #   Column                                           Non-Null Count   Dtype
# ---  ------                                           --------------   -----
#  0   Time spent doing vigorous physical activity-3.0  103780 non-null  int64
#  1   Time spent doing moderate physical activity-3.0  103780 non-null  int64
#  2   Time spent doing light physical activity-3.0     103780 non-null  float64
#  3   Food weight-3.0                                  103780 non-null  float64
#  4   Energy-3.0                                       103780 non-null  float64
#  5   Protein-3.0                                      103780 non-null  float64
#  6   Fat-3.0                                          103780 non-null  float64
#  7   Carbohydrate-3.0                                 103780 non-null  float64
# ...

# %%
#Hearing
j=10
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Signal-to-noise-ratio (SNR) of triplet (left)-0.1'].fillna(2,inplace=True)
df['Mean signal-to-noise ratio (SNR), (left)-0.8'][df['Mean signal-to-noise ratio (SNR), (left)-0.8'].isna()]=df['Signal-to-noise-ratio (SNR) of triplet (left)-0.8'][df['Mean signal-to-noise ratio (SNR), (left)-0.8'].isna()]
df['Mean signal-to-noise ratio (SNR), (right)-0.8'][df['Mean signal-to-noise ratio (SNR), (right)-0.8'].isna()]=df['Signal-to-noise-ratio (SNR) of triplet (right)-0.8'][df['Mean signal-to-noise ratio (SNR), (right)-0.8'].isna()]
for i in range(9,16):
    df['Mean signal-to-noise ratio (SNR), (left)-0.'+str(i)][df['Mean signal-to-noise ratio (SNR), (left)-0.'+str(i)].isna()]=df['Mean signal-to-noise ratio (SNR), (left)-0.'+str(i-1)][df['Mean signal-to-noise ratio (SNR), (left)-0.'+str(i)].isna()]
    df['Mean signal-to-noise ratio (SNR), (right)-0.'+str(i)][df['Mean signal-to-noise ratio (SNR), (right)-0.'+str(i)].isna()]=df['Mean signal-to-noise ratio (SNR), (right)-0.'+str(i-1)][df['Mean signal-to-noise ratio (SNR), (right)-0.'+str(i)].isna()]
for i in [4,5,6,7]+[i for i in range(23,85)]+[i for i in range(100,168)]:
    df.iloc[:,i][df.iloc[:,i]<0]=0
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[i for i in range(0,7)]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 171825 entries, 1000012.0 to 6024887.0
# Data columns (total 205 columns):
#  #    Column                                                 Non-Null Count   Dtype
# ---   ------                                                 --------------   -----
#  0    Age when attended assessment centre-0.0                171825 non-null  int64
#  1    Speech-reception-threshold (SRT) estimate (left)-0.0   171825 non-null  float64
#  2    Speech-reception-threshold (SRT) estimate (right)-0.0  171825 non-null  float64
#  3    Volume level set by participant (left)-0.0             171825 non-null  int64
#  4    Duration of hearing test (left)-0.0                    171825 non-null  float64
#  5    Volume level set by participant (right)-0.0            171825 non-null  int64
#  6    Duration of hearing test (right)-0.0                   171825 non-null  float64
# ...

# %%
#Lifestyle
j=11
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Bread type-0.0'][df['Bread type-0.0']<1.5]=1
df['Bread type-0.0'][(df['Bread type-0.0']>=1.5)&(df['Bread type-0.0']<2.5)]=2
df['Bread type-0.0'][(df['Bread type-0.0']>=2.5)&(df['Bread type-0.0']<3.5)]=3
df['Bread type-0.0'][df['Bread type-0.0']>=3.5]=4
df['Cereal type-0.0'][(df['Cereal type-0.0']>=1.5)&(df['Cereal type-0.0']<2.5)]=2
df['Cereal type-0.0'][(df['Cereal type-0.0']>=2.5)&(df['Cereal type-0.0']<3.5)]=3
df['Cereal type-0.0'][df['Cereal type-0.0']>=3.5]=4
df['Partial fibre score-0.0']=np.nan
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==1)&(df['Bread type-0.0']==1)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+0.68*df['Bread intake-0.0']+7.16*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==1)&(df['Bread type-0.0']==2)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+0.68*df['Bread intake-0.0']+2.92*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==1)&(df['Bread type-0.0']==3)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+0.68*df['Bread intake-0.0']+1.92*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==1)&(df['Bread type-0.0']==4)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+0.68*df['Bread intake-0.0']+4.18*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==2)&(df['Bread type-0.0']==1)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.26*df['Bread intake-0.0']+7.16*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==2)&(df['Bread type-0.0']==2)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.26*df['Bread intake-0.0']+2.92*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==2)&(df['Bread type-0.0']==3)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.26*df['Bread intake-0.0']+1.92*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==2)&(df['Bread type-0.0']==4)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.26*df['Bread intake-0.0']+4.18*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==3)&(df['Bread type-0.0']==1)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.8*df['Bread intake-0.0']+7.16*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==3)&(df['Bread type-0.0']==2)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.8*df['Bread intake-0.0']+2.92*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==3)&(df['Bread type-0.0']==3)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.8*df['Bread intake-0.0']+1.92*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==3)&(df['Bread type-0.0']==4)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.8*df['Bread intake-0.0']+4.18*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==4)&(df['Bread type-0.0']==1)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.25*df['Bread intake-0.0']+7.16*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==4)&(df['Bread type-0.0']==2)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.25*df['Bread intake-0.0']+2.92*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==4)&(df['Bread type-0.0']==3)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.25*df['Bread intake-0.0']+1.92*df['Cereal intake-0.0']
df['Partial fibre score-0.0'][(df['Cereal type-0.0']==4)&(df['Bread type-0.0']==4)]=2*df['Fresh fruit intake-0.0']+0.5*df['Dried fruit intake-0.0']+df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']+1.25*df['Bread intake-0.0']+4.18*df['Cereal intake-0.0']
df['Total vegetable intake-0.0']=np.nan
df['Total vegetable intake-0.0']=df['Cooked vegetable intake-0.0']+df['Salad or raw vegetable intake-0.0']
df['Total fruit intake-0.0']=np.nan
df['Total fruit intake-0.0']=df['Fresh fruit intake-0.0']+df['Dried fruit intake-0.0']
df['Total fish intake-0.0']=np.nan
df['Total fish intake-0.0']=df['Oily fish intake-0.0']+df['Non-oily fish intake-0.0']
df['Total unprocessed red meat intake-0.0']=np.nan
df['Total unprocessed red meat intake-0.0']=df['Beef intake-0.0']+df['Lamb or mutton intake-0.0']+df['Pork intake-0.0']
df['Milk intake-0.0']=np.nan
df['Milk intake-0.0'][df['Milk type used-0.0']==6]=0
df['Milk intake-0.0'][df['Milk type used-0.0']!=6]=df['Cereal intake-0.0']*100+df['Tea intake-0.0']*35
df['1']=np.nan
df['1']=df['Fresh fruit intake-0.0']+df['Dried fruit intake-0.0']
df['1'][df['1']>=3]=1
df['1'][df['1']<3]=0
df['2']=np.nan
df['2']=df['Salad or raw vegetable intake-0.0']+df['Cooked vegetable intake-0.0']
df['2'][df['2']>=3]=1
df['2'][df['2']<3]=0
df['3']=np.nan
df['3']=df['Oily fish intake-0.0']+df['Non-oily fish intake-0.0']
df['3'][df['3']>=3]=1
df['3'][df['3']<3]=0
df['4']=np.nan
df['4'][df['Processed meat intake-0.0']<2]=1
df['4'][df['Processed meat intake-0.0']>=2]=0
df['5']=np.nan
df['5'][df['Total unprocessed red meat intake-0.0']<2.5]=1
df['5'][df['Total unprocessed red meat intake-0.0']>=2.5]=0
df['6']=np.nan
df['6'][(df['Cereal type-0.0']==1)&(df['Cereal intake-0.0']>=3)]=1
df['6'].fillna(0,inplace=True)
df['7']=np.nan
df['7'][(df['Cereal type-0.0']!=1)&(df['Cereal intake-0.0']<=1.5)]=1
df['7'].fillna(0,inplace=True)
df['Healthy diet score-0.0']=np.nan
df['Healthy diet score-0.0']=df['1']+df['2']+df['3']+df['4']+df['5']+df['6']+df['7']
del df['1']
del df['2']
del df['3']
del df['4']
del df['5']
del df['6']
del df['7']
df['Moderate alcohol consumption-0.0']=np.nan
df['Moderate alcohol consumption-0.0']=(df['Average weekly red wine intake-0.0']+df['Average weekly champagne plus white wine intake-0.0'])*0.85*14+df['Average weekly fortified wine intake-0.0']*0.56*14+df['Average weekly spirits intake-0.0']*0.57*14+df['Average weekly beer plus cider intake-0.0']*1.28*14
df['Health sleep score-0.0']=np.nan
df['1']=np.nan
df['1'][df['Morning/evening person (chronotype)-0.0']<2.5]=1
df['1'].fillna(0,inplace=True)
df['2']=np.nan
df['2'][(df['Sleep duration-0.0']>=7)&(df['Sleep duration-0.0']<=8)]=1
df['2'].fillna(0,inplace=True)
df['3']=np.nan
df['3'][df['Sleeplessness or insomnia-0.0']<1.5]=1
df['3'].fillna(0,inplace=True)
df['4']=np.nan
df['4'][df['Snoring-0.0']==2]=1
df['4'].fillna(0,inplace=True)
df['5']=np.nan
df['5'][(df['Daytime dozing / sleeping (narcolepsy)-0.0']==0)|(df['Daytime dozing / sleeping (narcolepsy)-0.0']==1)]=1
df['5'].fillna(0,inplace=True)
df['Health sleep score-0.0']=df['1']+df['2']+df['3']+df['4']+df['5']
del df['1']
del df['2']
del df['3']
del df['4']
del df['5']
df['Regular physical activity-0.0']=np.nan
df['Regular physical activity-0.0'][(df['Number of days/week of moderate physical activity 10+ minutes-0.0']>=5)|(df['Number of days/week of vigorous physical activity 10+ minutes-0.0']>=1)|(df['Duration of moderate activity-0.0']>=150)|(df['Duration of vigorous activity-0.0']>=75)]=1
df['Regular physical activity-0.0'].fillna(0,inplace=True)
df[df<0]=0
for i in [i for i in range(0,17)]+[i for i in range(22,33)]+[44,45,46,47]+[i for i in range(55,100)]:
    df.iloc[:,i]=df.iloc[:,i].astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[0,10,11,12,13,14,15,1,17,18,19,20,8,24,25,26,27,28,29,30,31,3,4,83,57,6,7,75,94,62,63,64,67,68,69]+[i for i in range(100,110)]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 501618 entries, 1000012.0 to 6024933.0
# Data columns (total 110 columns):
#  #    Column                                                               Non-Null Count   Dtype
# ---   ------                                                               --------------   -----
#  0    Age when attended assessment centre-0.0                              501618 non-null  int32
#  1    Frequency of stair climbing in last 4 weeks-0.0                      501618 non-null  int32
#  2    Difference in mobile phone use compared to two years previously-0.0  501618 non-null  int32
#  3    Current tobacco smoking-0.0                                          501618 non-null  int32
#  4    Past tobacco smoking-0.0                                             501618 non-null  int32
#  5    Facial ageing-0.0                                                    501618 non-null  int32
# ...

# %%
#Male-specific factors
j=13
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df=df.astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 226931 entries, 1000012.0 to 6024933.0
# Data columns (total 5 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Age when attended assessment centre-0.0  226931 non-null  int32
#  1   Relative age of first facial hair-0.0    226931 non-null  int32
#  2   Relative age voice broke-0.0             226931 non-null  int32
#  3   Hair/balding pattern-0.0                 226931 non-null  int32
#  4   Number of children fathered-0.0          226931 non-null  int32
# dtypes: int32(5)
# memory usage: 6.1 MB

# %%
#Mental health-web based questionnaire
j=14
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Patient Health Questionnaire 9-question score-0.0']=np.nan
df['Patient Health Questionnaire 9-question score-0.0']=df['Recent changes in speed/amount of moving or speaking-0.0']+df['Recent feelings of depression-0.0']+df['Recent feelings of inadequacy-0.0']+df['Recent feelings of tiredness or low energy-0.0']+df['Recent lack of interest or pleasure in doing things-0.0']+df['Recent poor appetite or overeating-0.0']+df['Recent thoughts of suicide or self-harm-0.0']+df['Recent trouble concentrating on things-0.0']+df['Trouble falling or staying asleep, or sleeping too much-0.0']
df['General anxiety disorder score-0.0']=np.nan
df['General anxiety disorder score-0.0']=df['Recent easy annoyance or irritability-0.0']+df['Recent feelings of foreboding-0.0']+df['Recent feelings or nervousness or anxiety-0.0']+df['Recent inability to stop or control worrying-0.0']+df['Recent restlessness-0.0']+df['Recent trouble relaxing-0.0']+df['Recent worrying too much about different things-0.0']
df['Wellbeing score-0.0']=np.nan
df['Wellbeing score-0.0']=df['General happiness-0.0']+df['General happiness with own health-0.0']+df['Belief that own life is meaningful-0.0']
df['Post-traumatic stress disorder Check List score-0.0']=np.nan
df['Post-traumatic stress disorder Check List score-0.0']=df['Felt irritable or had angry outbursts in past month-0.0']+df['Avoided activities or situations because of previous stressful experience in past month-0.0']+df['Felt distant from other people in past month-0.0']+df['Repeated disturbing thoughts of stressful experience in past month-0.0']+df['Felt very upset when reminded of stressful experience in past month-0.0']+df['Recent trouble concentrating on things-0.0']
df['Number of ongoing addiction-0.0']=np.nan
df['Number of ongoing addiction-0.0']=df['Ongoing addiction to alcohol-0.0']+df['Ongoing behavioural or miscellanous addiction-0.0']+df['Ongoing addiction or dependence on illicit or recreational drugs-0.0']
df['Possible hallucination or delusion-0.0']=np.nan
df['Possible hallucination or delusion-0.0'][(df['Ever heard an un-real voice-0.0']==1)|(df['Ever seen an un-real vision-0.0']==1)|(df['Ever believed in an un-real conspiracy against self-0.0']==1)|(df['Ever believed in un-real communications or signs-0.0']==1)]=1
df['Possible hallucination or delusion-0.0'][df['Possible hallucination or delusion-0.0'].isna()]=0
df['Hallucination or delusion in the last year-0.0']=np.nan
df['Hallucination or delusion in the last year-0.0'][df['Frequency of unusual or psychotic experiences in past year-0.0']>0]=1
df['Hallucination or delusion in the last year-0.0'].fillna(0,inplace=True)
df['Childhood adverse events-0.0']=np.nan
df['Childhood adverse events-0.0'][(df['Felt hated by family member as a child-0.0']>=1)|(df['Physically abused by family as a child-0.0']>=1)|(df['Felt loved as a child-0.0']==0)|(df['Sexually molested as a child-0.0']>=1)|(df['Someone to take to doctor when needed as a child-0.0']==0)]=1
df['Childhood adverse events-0.0'][df['Childhood adverse events-0.0'].isna()]=0
df['Adult adverse events-0.0']=np.nan
df['Adult adverse events-0.0'][(df['Belittlement by partner or ex-partner as an adult-0.0']>0)|(df['Physical violence by partner or ex-partner as an adult-0.0']>0)|(df['Been in a confiding relationship as an adult-0.0']==0)|(df['Sexual interference by partner or ex-partner without consent as an adult-0.0']>0)|(df['Able to pay rent/mortgage as an adult-0.0']==0)]=1
df['Adult adverse events-0.0'][df['Adult adverse events-0.0'].isna()]=0
df['Catastrophic trauma score-0.0']=np.nan
df['Catastrophic trauma score-0.0']=df['Been in serious accident believed to be life-threatening-0.0']+df['Been involved in combat or exposed to war-zone-0.0']+df['Diagnosed with life-threatening illness-0.0']+df['Victim of physically violent crime-0.0']+df['Witnessed sudden violent death-0.0']+df['Victim of sexual assault-0.0']
df['Amount of alcohol drunk on a typical drinking day-0.0'].replace(0,1,inplace=True)
df['Amount of alcohol drunk on a typical drinking day-0.0']=df['Amount of alcohol drunk on a typical drinking day-0.0']-1
df['Frequency of consuming six or more units of alcohol-0.0'].replace(0,1,inplace=True)
df['Frequency of consuming six or more units of alcohol-0.0']=df['Frequency of consuming six or more units of alcohol-0.0']-1
df['Frequency of failure to fulfil normal expectations due to drinking alcohol in last year-0.0'].replace(0,1,inplace=True)
df['Frequency of failure to fulfil normal expectations due to drinking alcohol in last year-0.0']=df['Frequency of failure to fulfil normal expectations due to drinking alcohol in last year-0.0']-1
df['Frequency of feeling guilt or remorse after drinking alcohol in last year-0.0'].replace(0,1,inplace=True)
df['Frequency of feeling guilt or remorse after drinking alcohol in last year-0.0']=df['Frequency of feeling guilt or remorse after drinking alcohol in last year-0.0']-1
df['Ever been injured or injured someone else through drinking alcohol-0.0']=df['Ever been injured or injured someone else through drinking alcohol-0.0']*2
df['Ever had known person concerned about, or recommend reduction of, alcohol consumption-0.0']=df['Ever had known person concerned about, or recommend reduction of, alcohol consumption-0.0']*2
df['Alcohol Use Disorders Identification Test score-0.0']=df['Frequency of drinking alcohol-0.0']+df['Amount of alcohol drunk on a typical drinking day-0.0']+df['Frequency of consuming six or more units of alcohol-0.0']+df['Frequency of failure to fulfil normal expectations due to drinking alcohol in last year-0.0']+df['Frequency of needing morning drink of alcohol after heavy drinking session in last year-0.0']+df['Frequency of feeling guilt or remorse after drinking alcohol in last year-0.0']+df['Frequency of memory loss due to drinking alcohol in last year-0.0']+df['Ever been injured or injured someone else through drinking alcohol-0.0']+df['Ever had known person concerned about, or recommend reduction of, alcohol consumption-0.0']
df['Times of hallucination or delusion-0']=np.nan
df['Times of hallucination or delusion-0']=df['Number of times believed in an un-real conspiracy against self-0.0']+df['Number of times believed in un-real communications or signs-0.0']+df['Number of times heard an un-real voice-0.0']+df['Number of times seen an un-real vision-0.0']
df['Addiction or dependence ongoing-0.0']=np.nan
df['Addiction or dependence ongoing-0.0']=df.iloc[:,[102,104,107]].T.sum().T
df['Lifetime depression-0.0']=np.nan
df['Lifetime depression-0.0'][((df['Ever had prolonged feelings of sadness or depression-0.0']==1)|(df['Ever had prolonged loss of interest in normal activities-0.0']==1))&((df['Feelings of tiredness during worst episode of depression-0.0']+df['Did your sleep change?-0.0']+df['Difficulty concentrating during worst depression-0.0']+df['Feelings of worthlessness during worst period of depression-0.0']+df['Thoughts of death during worst depression-0.0']>=4)|(df['Ever had prolonged feelings of sadness or depression-0.0']==1)|(df['Ever had prolonged loss of interest in normal activities-0.0']==1))&(((df['Feelings of tiredness during worst episode of depression-0.0']+df['Did your sleep change?-0.0']+df['Difficulty concentrating during worst depression-0.0']+df['Feelings of worthlessness during worst period of depression-0.0']+df['Thoughts of death during worst depression-0.0']==3)&(df['Weight change during worst episode of depression-0.0']>0)))]=1
df['Lifetime depression-0.0'][df['Lifetime depression-0.0'].isna()]=0
df['Lifetime manic symptoms-0.0']=np.nan
#Bipolar disorder,type 2
df['Lifetime manic symptoms-0.0'][((df['Ever had period of mania / excitability-0.0']==1)|(df['Ever had period extreme irritability-0.0']==1))&(df['Sum of manifestations of mania or irritability']>=5)&(df['Longest period of mania or irritability-0.0']==3)]=2
#Bipolar disorder,type 1
df['Lifetime manic symptoms-0.0'][((df['Ever had period of mania / excitability-0.0']==1)|(df['Ever had period extreme irritability-0.0']==1))&(df['Sum of manifestations of mania or irritability']>=5)&(df['Longest period of mania or irritability-0.0']==3)&(df['Severity of problems due to mania or irritability-0.0']==1)]=1
#control
df['Lifetime manic symptoms-0.0'][df['Lifetime manic symptoms-0.0'].isna()]=0
df['Lifetime anxiety disorder-0.0']=np.nan
df['Lifetime anxiety disorder-0.0'][(df['Ever felt worried, tense, or anxious for most of a month or longer-0.0']==1)&(df['Longest period spent worried or anxious-0.0']>=6)&(df['Worried most days during period of worst anxiety-0.0']==1)&((df['Ever worried more than most people would in similar situation-0.0']==1)|(df['Stronger worrying (than other people) during period of worst anxiety-0.0']==1))&((df['Number of things worried about during worst period of anxiety-0.0']==2)|(df['Multiple worries during worst period of anxiety-0.0']))&((df['Difficulty stopping worrying during worst period of anxiety-0.0']==1)|(df['Frequency of inability to stop worrying during worst period of anxiety-0.0']>=2)|(df['Frequency of difficulty controlling worry during worst period of anxiety-0.0']>=2))&(df['Impact on normal roles during worst period of anxiety-0.0']>=2)&(df['Tense, sore, or aching muscles during worst period of anxiety-0.0']+df['Difficulty concentrating during worst period of anxiety-0.0']+df['More irritable than usual during worst period of anxiety-0.0']+df['Keyed up or on edge during worst period of anxiety-0.0']+df['Restless during period of worst anxiety-0.0']+df['Frequent trouble falling or staying asleep during worst period of anxiety-0.0']+df['Easily tired during worst period of anxiety-0.0']>=3)]=1
df['Lifetime anxiety disorder-0.0'][df['Lifetime anxiety disorder-0.0'].isna()]=0
df[df<0]=0
for i in [11,20,21,37]:
    df.iloc[:,i]=df.iloc[:,i].astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157339 entries, 1000050 to 6024933
# Data columns (total 152 columns):
#  #    Column                                                                                       Non-Null Count   Dtype
# ---   ------                                                                                       --------------   -----
#  0    Amount of alcohol drunk on a typical drinking day-0.0                                        157339 non-null  int64
#  1    Frequency of failure to fulfil normal expectations due to drinking alcohol in last year-0.0  157339 non-null  int64
#  2    Frequency of memory loss due to drinking alcohol in last year-0.0                            157339 non-null  int64
#  3    Frequency of feeling guilt or remorse after drinking alcohol in last year-0.0                157339 non-null  int64
#  4    Frequency of needing morning drink of alcohol after heavy drinking session in last year-0.0  157339 non-null  int64
# ...

# %%
#Mental health-assessment center questionnaire
j=15
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Recent depressive symptoms-4 score-0.0']=np.nan
df['Recent depressive symptoms-4 score-0.0']=df['Frequency of depressed mood in last 2 weeks-0.0']+df['Frequency of unenthusiasm / disinterest in last 2 weeks-0.0']+df['Frequency of tenseness / restlessness in last 2 weeks-0.0']+df['Frequency of tiredness / lethargy in last 2 weeks-0.0']
df['Probable depression status-0.0']=np.nan
df['Probable depression status-0.0'][((df['Ever unenthusiastic/disinterested for a whole week-0.0']==1)|(df['Ever depressed for a whole week-0.0']==1))&((df['Longest period of unenthusiasm / disinterest-0.0']>=1)|(df['Longest period of depression-0.0']>=1))&((df['Seen doctor (GP) for nerves, anxiety, tension or depression-0.0']==1)|(df['Seen a psychiatrist for nerves, anxiety, tension or depression-0.0']==1))]=1
df['Probable depression status-0.0'][df['Probable depression status-0.0'].isna()]=0
df[df<0]=0
for i in [2,3,4,25,26]:
    df.iloc[:,i]=df.iloc[:,i].astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 501588 entries, 1000012.0 to 6024933.0
# Data columns (total 40 columns):
#  #   Column                                                              Non-Null Count   Dtype
# ---  ------                                                              --------------   -----
#  0   Age of attending assessment centre-0.0                              501588 non-null  int64
#  1   Longest period of unenthusiasm / disinterest-0.0                    501588 non-null  float64
#  2   Number of unenthusiastic/disinterested episodes-0.0                 501588 non-null  int32
#  3   Length of longest manic/irritable episode-0.0                       501588 non-null  int32
#  4   Mood swings-0.0                                                     501588 non-null  int32
#  5   Miserableness-0.0                                                   501588 non-null  int64
# ...

# %%
#Sociodemographic
j=16
Country1='England'
Country2='Scotland'
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country1+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country1+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country1+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Nitrogen dioxide air pollution; 2005-0.0'][df['Nitrogen dioxide air pollution; 2005-0.0'].isna()]=df['Nitrogen dioxide air pollution; 2007-0.0'][df['Nitrogen dioxide air pollution; 2005-0.0'].isna()]
df['Nitrogen dioxide air pollution; 2006-0.0'][df['Nitrogen dioxide air pollution; 2006-0.0'].isna()]=df['Nitrogen dioxide air pollution; 2007-0.0'][df['Nitrogen dioxide air pollution; 2006-0.0'].isna()]
df['Average evening sound level of noise pollution-0.0'][df['Average evening sound level of noise pollution-0.0'].isna()]=df['Average daytime sound level of noise pollution-0.0'][df['Average evening sound level of noise pollution-0.0'].isna()]-4
df['Average night-time sound level of noise pollution-0.0'][df['Average night-time sound level of noise pollution-0.0'].isna()]=df['Average evening sound level of noise pollution-0.0'][df['Average night-time sound level of noise pollution-0.0'].isna()]-5
df['Greenspace percentage, buffer 1000m-0.0'].fillna(df['Greenspace percentage, buffer 1000m-0.0'].mean(),inplace=True)
df['Employment status-0.0']=np.nan
df['Employment status-0.0'][df['In paid employment or self-employed-0.0']==1]=0
df['Employment status-0.0'][df['Retired-0.0']==1]=1
df['Employment status-0.0'][df['Employment status-0.0'].isna()]=2
del df['In paid employment or self-employed-0.0']
del df['Retired-0.0']
for i in [6,7,9,10]:
    df.iloc[:,i]=df.iloc[:,i].astype(int)
for i in range(3,29):
    df.iloc[:,i][df.iloc[:,i]<0]=0
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country1+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[0,44,10,11,12]+[i for i in range(20,36)]+[1]+[i for i in range(13,17)]+[19,42,43,2,3,4,54,5,47,46,8,9,39,37]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country1+'/'+Category_Name[j]+'-final-important.csv')
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country2+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country2+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country2+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Nitrogen dioxide air pollution; 2005-0.0'][df['Nitrogen dioxide air pollution; 2005-0.0'].isna()]=df['Nitrogen dioxide air pollution; 2007-0.0'][df['Nitrogen dioxide air pollution; 2005-0.0'].isna()]
df['Nitrogen dioxide air pollution; 2006-0.0'][df['Nitrogen dioxide air pollution; 2006-0.0'].isna()]=df['Nitrogen dioxide air pollution; 2007-0.0'][df['Nitrogen dioxide air pollution; 2006-0.0'].isna()]
df['Average evening sound level of noise pollution-0.0'][df['Average evening sound level of noise pollution-0.0'].isna()]=df['Average daytime sound level of noise pollution-0.0'][df['Average evening sound level of noise pollution-0.0'].isna()]-4
df['Average night-time sound level of noise pollution-0.0'][df['Average night-time sound level of noise pollution-0.0'].isna()]=df['Average evening sound level of noise pollution-0.0'][df['Average night-time sound level of noise pollution-0.0'].isna()]-5
df['Employment status-0.0']=np.nan
df['Employment status-0.0'][df['In paid employment or self-employed-0.0']==1]=0
df['Employment status-0.0'][df['Retired-0.0']==1]=1
df['Employment status-0.0'][df['Employment status-0.0'].isna()]=2
del df['In paid employment or self-employed-0.0']
del df['Retired-0.0']
df['Attendance allowance-0.0'].fillna(0,inplace=True)
df['Disability living allowance-0.0'].fillna(0,inplace=True)
df['Blue badge-0.0'].fillna(0,inplace=True)
df['Ethnic background-0.0'].fillna(1,inplace=True)
df['Age of immigrated to UK (United Kingdom)'].fillna(0,inplace=True)
df['Looking after home and/or family-0.0'].fillna(0,inplace=True)
df['Unable to work because of sickness or disability-0.0'].fillna(0,inplace=True)
df['Unemployed-0.0'].fillna(0,inplace=True)
df['Doing unpaid or voluntary work-0.0'].fillna(0,inplace=True)
df['Full or part-time student-0.0'].fillna(0,inplace=True)
df['Attendance allowance-0.0'].fillna(0,inplace=True)
for i in [8,9]:
    df.iloc[:,i]=df.iloc[:,i].astype(int)
for i in range(3,22):
    df.iloc[:,i][df.iloc[:,i]<0]=0
df['Crime score (Scotland)-0.0'][df['Crime score (Scotland)-0.0']<0]=0
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country2+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[0,16,17,18,11,12,14,10,15,31,32,2,3,4,43,5,36,35,8,9,33,27,1]+[i for i in range(20,26)]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country2+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 35849 entries, 1000068.0 to 6024699.0
# Data columns (total 44 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Age when attended assessment centre-0.0                      35849 non-null  int64
#  1   Townsend deprivation index at recruitment-0.0                35849 non-null  float64
#  2   Number in household-0.0                                      35849 non-null  float64
#  3   Number of vehicles in household-0.0                          35849 non-null  float64
#  4   Average total household income before tax-0.0                35849 non-null  int64
#  5   Length of working week for main job-0.0                      35849 non-null  float64
#  6   Age completed full time education-0.0                        35849 non-null  float64
# ...

# %%
#Spirometry
j=17
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['Forced vital capacity (FVC)-0.0'][df['Forced vital capacity (FVC)-0.0'].isna()]=df['Forced vital capacity (FVC), Best measure-0.0'][df['Forced vital capacity (FVC)-0.0'].isna()]
df['Forced vital capacity (FVC)-0.1'][df['Forced vital capacity (FVC)-0.1'].isna()]=df['Forced vital capacity (FVC)-0.0'][df['Forced vital capacity (FVC)-0.1'].isna()]
df['Forced vital capacity (FVC)-0.2'][df['Forced vital capacity (FVC)-0.2'].isna()]=df['Forced vital capacity (FVC)-0.1'][df['Forced vital capacity (FVC)-0.2'].isna()]
df['Forced expiratory volume in 1-second (FEV1)-0.0'][df['Forced expiratory volume in 1-second (FEV1)-0.0'].isna()]=df['Forced expiratory volume in 1-second (FEV1), Best measure-0.0'][df['Forced expiratory volume in 1-second (FEV1)-0.0'].isna()]
df['Forced expiratory volume in 1-second (FEV1)-0.1'][df['Forced expiratory volume in 1-second (FEV1)-0.1'].isna()]=df['Forced expiratory volume in 1-second (FEV1)-0.0'][df['Forced expiratory volume in 1-second (FEV1)-0.1'].isna()]
df['Forced expiratory volume in 1-second (FEV1)-0.2'][df['Forced expiratory volume in 1-second (FEV1)-0.2'].isna()]=df['Forced expiratory volume in 1-second (FEV1)-0.1'][df['Forced expiratory volume in 1-second (FEV1)-0.2'].isna()]
df['Forced expiratory volume in 1-second (FEV1), predicted-0.0'][df['Forced expiratory volume in 1-second (FEV1), predicted-0.0']<0]=0
df['Peak expiratory flow (PEF)-0.1'][df['Peak expiratory flow (PEF)-0.1']<0]=0
df['Peak expiratory flow (PEF)-0.2'][df['Peak expiratory flow (PEF)-0.2']<0]=0
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[i for i in range(0,9)]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 460005 entries, 1000012.0 to 6024933.0
# Data columns (total 17 columns):
#  #   Column                                                                 Non-Null Count   Dtype
# ---  ------                                                                 --------------   -----
#  0   Age when attended assessment centre-0.0                                460005 non-null  int64
#  1   Peak expiratory flow (PEF)-0.0                                         460005 non-null  float64
#  2   Forced expiratory volume in 1-second (FEV1), Best measure-0.0          460005 non-null  float64
#  3   Forced vital capacity (FVC), Best measure-0.0                          460005 non-null  float64
#  4   Forced expiratory volume in 1-second (FEV1), predicted-0.0             460005 non-null  float64
#  5   Forced expiratory volume in 1-second (FEV1), predicted percentage-0.0  460005 non-null  float64
# ...

# %%
#Physical health
j=18
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df['Insulin-0.0'].fillna(0,inplace=True)
df=df.set_index('eid')
df['Oral health-0.0']=np.nan
df['Oral health-0.0'][df['Painful gums-0.0']==1]=1
df['Oral health-0.0'][df['Loose teeth-0.0']==1]=1
df['Oral health-0.0'][df['Bleeding gums-0.0']==1]=1
df['Oral health-0.0'].fillna(0,inplace=True)
df['Number of chronic pain sites-0.0']=np.nan
df['Hip pain-0.0'][df['Hip pain-0.0']==1]=0
df['Back pain-0.0'][df['Back pain-0.0']==1]=0
df['Knee pain-0.0'][df['Knee pain-0.0']==1]=0
df['Headaches-0.0'][df['Headaches-0.0']==1]=0
df['General pain-0.0'][df['General pain-0.0']==1]=0
df['Stomach/abdominal pain-0.0'][df['Stomach/abdominal pain-0.0']==1]=0
df['Facial pains-0.0'][df['Facial pains-0.0']==1]=0
df['Neck/shoulder pain-0.0'][df['Neck/shoulder pain-0.0']==1]=0
df['Number of chronic pain sites-0.0']=(df['Hip pain-0.0']+df['Back pain-0.0']+df['Knee pain-0.0']+df['Headaches-0.0']+df['General pain-0.0']+df['Stomach/abdominal pain-0.0']+df['Facial pains-0.0']+df['Neck/shoulder pain-0.0'])/2
df['Number of Medication for cholesterol, blood pressure or diabetes-0.0']=np.nan
df['Number of Medication for cholesterol, blood pressure or diabetes-0.0']=df['Cholesterol lowering medication-0.0']+df['Blood pressure medication-0.0']+df['Insulin-0.0']
df['Number of vitamin and mineral supplements-0.0']=np.nan
df['Number of vitamin and mineral supplements-0.0']=df['Vitamin A-0.0']+df['Vitamin B-0.0']+df['Vitamin C-0.0']+df['Vitamin D-0.0']+df['Vitamin E-0.0']+df['Folic acid or Folate-0.0']+df['Multivitamins +/- minerals-0.0']
df['Mineral and other dietary supplements-0.0']=np.nan
df['Mineral and other dietary supplements-0.0']=df['Zinc-0.0']+df['Calcium-0.0']+df['Selenium-0.0']+df['Iron-0.0']+df['Fish oil-0.0']+df['Glucosamine-0.0']
df['Number of vascular/heart problems diagnosed by doctor-0.0']=np.nan
df['Number of vascular/heart problems diagnosed by doctor-0.0']=df['Heart attack-0.0']+df['Angina-0.0']+df['Stroke-0.0']+df['High blood pressure-0.0']
df['Number of blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor']=np.nan
df['Number of blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor']=df['Blood clot in the leg (DVT)-0.0']+df['Blood clot in the lung-0.0']+df['Emphysema/chronic bronchitis-0.0']+df['Asthma-0.0']+df['Hayfever, allergic rhinitis or eczema-0.0']
df[df<0]=0
df=df.astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[0,8,9,16,17,39,40,71,77,17,31,13,14,33,34,73,78,3,56,199,53,54,55,92,93,94,97,98,99,100,12,10,4,201,202,203,50,51,52,21,47,48,49]+[i for i in range(57,62)]+[2,68]+[95,96,130,200,204,205]+[i for i in range(88,92)]+[i for i in range(149,199)]+[i for i in range(131,137)]+[i for i in range(101,130)]+[1,6,7,18,19,22,32,38,29]+[24,25,26]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 502155 entries, 1000012.0 to 6024933.0
# Data columns (total 206 columns):
#  #    Column                                                                                                   Non-Null Count   Dtype
# ---   ------                                                                                                   --------------   -----
#  0    Age when attended assessment centre-0.0                                                                  502155 non-null  int32
#  1    Mother Heart disease-0.0                                                                                 502155 non-null  int32
#  2    Number of self-reported non-cancer illnesses-0.0                                                         502155 non-null  int32
#  3    Number of operations, self-reported-0.0                                                                  502155 non-null  int32
# ...

# %%
#Female-specific factors
j=19
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df[df<0]=0
df=df.astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272957 entries, 1000050 to 6024921
# Data columns (total 30 columns):
#  #   Column                                                           Non-Null Count   Dtype
# ---  ------                                                           --------------   -----
#  0   Age when attended assessment centre-0.0                          272957 non-null  int32
#  1   Age started hormone-replacement therapy (HRT)-0.0                272957 non-null  int32
#  2   Age last used hormone-replacement therapy (HRT)-0.0              272957 non-null  int32
#  3   Ever had hysterectomy (womb removed)-0.0                         272957 non-null  int32
#  4   Length of menstrual cycle-0.0                                    272957 non-null  int32
#  5   Number of spontaneous miscarriages-0.0                           272957 non-null  int32
#  6   Number of pregnancy terminations-0.0                             272957 non-null  int32
# ...

# %%
#Digestive health
j=20
dfcol=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv')
dfMICE=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-after_MICE.csv')
dfMICE.columns=list(dfcol)
dfcal=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv')
df=pd.concat([dfMICE,dfcal],axis=1)
df=df.set_index('eid')
df['IBS severity score-0.0']=np.nan
df['IBS severity score-0.0']=df['Number of days (out of 10) with abdominal pain-0.0']+df['Severity of current abdominal distension/tightness-0.0']+df['Satisfaction with bowel habits-0.0']+df['Degree to which abdominal pain/discomfort/altered bowel habits affect/interfere with life in general-0.0']
df['IBS severity degree-0.0']=np.nan
df['IBS severity degree-0.0'][df['IBS severity score-0.0']<7.5]=0
df['IBS severity degree-0.0'][(df['IBS severity score-0.0']>=7.5)&(df['IBS severity score-0.0']<17.5)]=1
df['IBS severity degree-0.0'][(df['IBS severity score-0.0']>=17.5)&(df['IBS severity score-0.0']<30)]=2
df['IBS severity degree-0.0'][df['IBS severity score-0.0']>=30]=3
df['IBS subtype-0.0']=np.nan
df['IBS subtype-0.0'][(df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']<3)&(df['Abdominal discomfort/pain for 6 months or longer-0.0']==0)&(df['Frequency of discomfort/pain getting better or stopping after a bowel movement-0.0']==0)&(df['More frequent bowel movements when abdominal discomfort/pain started-0.0']==0)&(df['Less frequent bowel movements when abdominal discomfort/pain started-0.0']==0)&(df['Stools looser when abdominal discomfort/pain started-0.0']==0)&(df['Frequency of harder stools when abdominal discomfort/pain started-0.0']==0)]=0
#control
df['IBS subtype-0.0'][(df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']>=3)&(df['Abdominal discomfort/pain for 6 months or longer-0.0']==1)&(df['Frequency of discomfort/pain getting better or stopping after a bowel movement-0.0']>0)&(df['More frequent bowel movements when abdominal discomfort/pain started-0.0']>0)&(df['Less frequent bowel movements when abdominal discomfort/pain started-0.0']>0)&(df['Stools looser when abdominal discomfort/pain started-0.0']>0)&(df['Frequency of harder stools when abdominal discomfort/pain started-0.0']>0)&(df['Frequency of hard/lumpy stools in the last 3 months-0.0']>0)&(df['Frequency of loose/mushy/watery stools in the last 3 months-0.0']==0)]=1
#IBS-C
df['IBS subtype-0.0'][(df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']>=3)&(df['Abdominal discomfort/pain for 6 months or longer-0.0']==1)&(df['Frequency of discomfort/pain getting better or stopping after a bowel movement-0.0']>0)&(df['More frequent bowel movements when abdominal discomfort/pain started-0.0']>0)&(df['Less frequent bowel movements when abdominal discomfort/pain started-0.0']>0)&(df['Stools looser when abdominal discomfort/pain started-0.0']>0)&(df['Frequency of harder stools when abdominal discomfort/pain started-0.0']>0)&(df['Frequency of hard/lumpy stools in the last 3 months-0.0']==0)&(df['Frequency of loose/mushy/watery stools in the last 3 months-0.0']>0)]=2
#IBS-D
df['IBS subtype-0.0'][(df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']>=3)&(df['Abdominal discomfort/pain for 6 months or longer-0.0']==1)&(df['Frequency of discomfort/pain getting better or stopping after a bowel movement-0.0']>0)&(df['More frequent bowel movements when abdominal discomfort/pain started-0.0']>0)&(df['Less frequent bowel movements when abdominal discomfort/pain started-0.0']>0)&(df['Stools looser when abdominal discomfort/pain started-0.0']>0)&(df['Frequency of harder stools when abdominal discomfort/pain started-0.0']>0)&(df['Frequency of hard/lumpy stools in the last 3 months-0.0']>0)&(df['Frequency of loose/mushy/watery stools in the last 3 months-0.0']>0)]=3
#IBS-M
df['IBS subtype-0.0'][df['IBS subtype-0.0'].isna()]=4
#IBS-U
df['PHQ-12 somatic symptom score-0.0']=np.nan
df['PHQ-12 somatic symptom score-0.0']=df['Degree bothered by back pain in the past 3 months-0.0']+df['Degree bothered by pain in arms/legs/joints in the past 3 months-0.0']+df['Degree bothered by headaches in the last 3 months-0.0']+df['Degree bothered by chest pain in the last 3 months-0.0']+df['Degree bothered by dizziness in the last 3 months-0.0']+df['Degree bothered by feeling heart pound/race in the last 3 months-0.0']+df['Degree bothered by shortness of breath in the last 3 months-0.0']+df['Degree bothered by pain/problems during intercourse in the last 3 months-0.0']+df['Degree bothered by feeling tired all the time in the last 3 months-0.0']+df['Degree bothered by trouble sleeping in the last 3 months-0.0']+df['Degree bothered by menstrual cramps or other problems with period in the last 3 months-0.0']+df['Degree bothered by fainting spells in the last 3 months-0.0']
df=df.astype(int)
df.info(verbose=True,null_counts=True)
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df.iloc[:,[37,53]+[i for i in range(20,32)]+[50,51,14,15,16,52]+[i for i in range(1,13)]].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174760 entries, 1000050 to 6024933
# Data columns (total 54 columns):
#  #   Column                                                                                                    Non-Null Count   Dtype
# ---  ------                                                                                                    --------------   -----
#  0   Ever diagnosed with IBS-0.0                                                                               174760 non-null  int32
#  1   Frequency of discomfort/pain in abdomen in last 3 months-0.0                                              174760 non-null  int32
#  2   Abdominal discomfort/pain for 6 months or longer-0.0                                                      174760 non-null  int32
#  3   Frequency of discomfort/pain getting better or stopping after a bowel movement-0.0                        174760 non-null  int32
# ...

# %%
#Deleting intermediate files
for i in range(len(Category_Name)):
    if os.path.exists(file_Pwd+'/'+Category_Name[i]+'/'+Category_Name[i]+'_raw.csv'):
        os.remove(file_Pwd+'/'+Category_Name[i]+'/'+Category_Name[i]+'_raw.csv')
    if os.path.exists(file_Pwd+'/'+Category_Name[i]+'/'+Category_Name[i]+'-after_MICE.csv'):
        os.remove(file_Pwd+'/'+Category_Name[i]+'/'+Category_Name[i]+'-after_MICE.csv')
    if os.path.exists(file_Pwd+'/'+Category_Name[i]+'/'+Category_Name[i]+'-for_MICE.csv'):
        os.remove(file_Pwd+'/'+Category_Name[i]+'/'+Category_Name[i]+'-for_MICE.csv')
    if os.path.exists(file_Pwd+'/'+Category_Name[i]+'/'+Category_Name[i]+'-for_calculted.csv'):
        os.remove(file_Pwd+'/'+Category_Name[i]+'/'+Category_Name[i]+'-for_calculted.csv')
