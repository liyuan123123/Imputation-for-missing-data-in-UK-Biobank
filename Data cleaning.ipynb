# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import statistics
import warnings
import pandas as pd
import os
warnings.filterwarnings('ignore')
pd.set_option("display.max_rows", None)#可显示1000行
pd.set_option("display.max_columns", None)#可显示1000列

# %%
file_Pwd=('../UKB')
Category_Name=['Anthropometry','Arterial_stiffness','Blood_Urine','Bone_densitometry_of_heel','Cognitive','Carotid_ultrasound','ECG_at_rest','ECG_during_exercise','Eyesight','Food_24_hours','Hearing','Lifestyle','Physical_activity','Male_specific_factors','Mental_health_web_based_questionnaire','Mental_health_assessment_questionnaire','Sociodemographics','Spirometry','Physical_health','Female_specific_factors','Digestive_health']

# %%
#Cleaning-Anthropometry
j=0
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('23130','Trunk predicted mass')
    i=i.replace('23129','Trunk fat-free mass')
    i=i.replace('23128','Trunk fat mass')
    i=i.replace('23127','Trunk fat percentage')
    i=i.replace('23126','Arm predicted mass (left)')
    i=i.replace('23125','Arm fat-free mass (left)')
    i=i.replace('23124','Arm fat mass (left)')
    i=i.replace('23123','Arm fat percentage (left)')
    i=i.replace('23122','Arm predicted mass (right)')
    i=i.replace('23121','Arm fat-free mass (right)')
    i=i.replace('23120','Arm fat mass (right)')
    i=i.replace('23119','Arm fat percentage (right)')
    i=i.replace('23118','Leg predicted mass (left)')
    i=i.replace('23117','Leg fat-free mass (left)')
    i=i.replace('23116','Leg fat mass (left)')
    i=i.replace('23115','Leg fat percentage (left)')
    i=i.replace('23114','Leg predicted mass (right)')
    i=i.replace('23113','Leg fat-free mass (right)')
    i=i.replace('23112','Leg fat mass (right)')
    i=i.replace('23111','Leg fat percentage (right)')
    i=i.replace('23110','Impedance of arm (left)')
    i=i.replace('23109','Impedance of arm (right)')
    i=i.replace('23108','Impedance of leg (left)')
    i=i.replace('23107','Impedance of leg (right)')
    i=i.replace('23106','Impedance of whole body')
    i=i.replace('23104','Body mass index (BMI)')
    i=i.replace('23102','Whole body water mass')
    i=i.replace('23101','Whole body fat-free mass')
    i=i.replace('23100','Whole body fat mass')
    i=i.replace('23099','Body fat percentage')
    i=i.replace('23098','Weight')
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('21002','Weight')
    i=i.replace('21001','Body mass index (BMI)')
    i=i.replace('20022','Birth weight')
    i=i.replace('20015','Sitting height')
    i=i.replace('6222','Impedance of arm, manual entry (left)')
    i=i.replace('6221','Impedance of arm, manual entry (right)')
    i=i.replace('6220','Impedance of leg, manual entry (left)')
    i=i.replace('6219','Impedance of leg, manual entry (right)')
    i=i.replace('6218','Impedance of whole body, manual entry')
    i=i.replace('3160','Weight, manual entry')
    i=i.replace('3077','Seating box height')
    i=i.replace('1707','Handedness (chirality/laterality)')
    i=i.replace('1697','Comparative height size at age 10')
    i=i.replace('1687','Comparative body size at age 10')
    i=i.replace('120','Birth weight known')
    i=i.replace('51-','Seated height-')
    i=i.replace('50-','Standing height-')
    i=i.replace('49-','Hip circumference-')
    i=i.replace('48-','Waist circumference-')
    i=i.replace('47-','Hand grip strength (right)-')
    i=i.replace('46-','Hand grip strength (left)-')
    d.append(i)
df.columns=d
df['Handedness (chirality/laterality)-0.0'][df['Handedness (chirality/laterality)-0.0']<0]=np.nan
df['Comparative body size at age 10-0.0'][df['Comparative body size at age 10-0.0']<0]=np.nan
df['Comparative height size at age 10-0.0'][df['Comparative height size at age 10-0.0']<0]=np.nan
df['Impedance of whole body-0.0'][df['Impedance of whole body-0.0'].isna()]=df['Impedance of whole body, manual entry-0.0'][df['Impedance of whole body-0.0'].isna()]
df['Impedance of leg (right)-0.0'][df['Impedance of leg (right)-0.0'].isna()]=df['Impedance of leg, manual entry (right)-0.0'][df['Impedance of leg (right)-0.0'].isna()]
df['Impedance of leg (left)-0.0'][df['Impedance of leg (left)-0.0'].isna()]=df['Impedance of leg, manual entry (left)-0.0'][df['Impedance of leg (left)-0.0'].isna()]
df['Impedance of arm (right)-0.0'][df['Impedance of arm (right)-0.0'].isna()]=df['Impedance of arm, manual entry (right)-0.0'][df['Impedance of arm (right)-0.0'].isna()]
df['Impedance of arm (left)-0.0'][df['Impedance of arm (left)-0.0'].isna()]=df['Impedance of arm, manual entry (left)-0.0'][df['Impedance of arm (left)-0.0'].isna()]
df['Birth weight-0.0'][df['Birth weight known-0.0']==2]=2.2*df['Birth weight-0.0'][df['Birth weight known-0.0']==2]
del df['Weight, manual entry-0.0']
del df['Impedance of whole body, manual entry-0.0']
del df['Impedance of leg, manual entry (right)-0.0']
del df['Impedance of leg, manual entry (left)-0.0']
del df['Impedance of arm, manual entry (right)-0.0']
del df['Impedance of arm, manual entry (left)-0.0']
df = df.loc[:,~df.columns.duplicated()]
#High Pearson correlation coefficient variables
df['Impedance of arm (left)-0.0'][df['Impedance of arm (left)-0.0'].isnull()] = df['Impedance of arm (right)-0.0'][df['Impedance of arm (left)-0.0'].isnull()]
df['Leg predicted mass (right)-0.0'][df['Leg predicted mass (right)-0.0'].isnull()] = df['Leg fat-free mass (right)-0.0'][df['Leg predicted mass (right)-0.0'].isnull()]
df['Leg fat percentage (left)-0.0'][df['Leg fat percentage (left)-0.0'].isnull()] = df['Leg fat percentage (right)-0.0'][df['Leg fat percentage (left)-0.0'].isnull()]
df['Leg fat mass (left)-0.0'][df['Leg fat mass (left)-0.0'].isnull()] = df['Leg fat mass (right)-0.0'][df['Leg fat mass (left)-0.0'].isnull()]
df['Leg predicted mass (left)-0.0'][df['Leg predicted mass (left)-0.0'].isnull()] = df['Leg predicted mass (right)-0.0'][df['Leg predicted mass (left)-0.0'].isnull()]
df['Arm predicted mass (right)-0.0'][df['Arm predicted mass (right)-0.0'].isnull()] = df['Arm fat-free mass (right)-0.0'][df['Arm predicted mass (right)-0.0'].isnull()]
df['Arm fat mass (left)-0.0'][df['Arm fat mass (left)-0.0'].isnull()] = df['Arm fat mass (right)-0.0'][df['Arm fat mass (left)-0.0'].isnull()]
df['Arm fat percentage (left)-0.0'][df['Arm fat percentage (left)-0.0'].isnull()] = df['Arm fat percentage (right)-0.0'][df['Arm fat percentage (left)-0.0'].isnull()]
df['Arm predicted mass (left)-0.0'][df['Arm predicted mass (left)-0.0'].isnull()] = df['Arm predicted mass (right)-0.0'][df['Arm predicted mass (left)-0.0'].isnull()]
df['Arm predicted mass (left)-0.0'][df['Arm predicted mass (left)-0.0'].isnull()] = df['Arm fat-free mass (left)-0.0'][df['Arm predicted mass (left)-0.0'].isnull()]
df['Leg predicted mass (left)-0.0'][df['Leg predicted mass (left)-0.0'].isnull()] = df['Leg fat-free mass (left)-0.0'][df['Leg predicted mass (left)-0.0'].isnull()]
df['Trunk fat-free mass-0.0'][df['Trunk fat-free mass-0.0'].isnull()] = df['Trunk predicted mass-0.0'][df['Trunk fat-free mass-0.0'].isnull()]
df[['eid','Trunk predicted mass-0.0','Whole body water mass-0.0','Impedance of arm (right)-0.0','Leg fat-free mass (right)-0.0','Leg fat percentage (right)-0.0','Leg fat mass (right)-0.0','Leg predicted mass (right)-0.0','Arm fat-free mass (right)-0.0','Arm fat mass (right)-0.0','Arm fat percentage (right)-0.0','Arm predicted mass (right)-0.0','Arm fat-free mass (left)-0.0','Leg fat-free mass (left)-0.0']].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['Trunk predicted mass-0.0']
del df['Whole body water mass-0.0']
del df['Impedance of arm (right)-0.0']
del df['Leg fat-free mass (right)-0.0']
del df['Leg fat percentage (right)-0.0']
del df['Leg fat mass (right)-0.0']
del df['Leg predicted mass (right)-0.0']
del df['Arm fat-free mass (right)-0.0']
del df['Arm fat mass (right)-0.0']
del df['Arm fat percentage (right)-0.0']
del df['Arm predicted mass (right)-0.0']
del df['Arm fat-free mass (left)-0.0']
del df['Leg fat-free mass (left)-0.0']
del df['Birth weight known-0.0']
del df['eid']
df[df<0]=np.nan
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Arterial stiffness
j=1
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('21021','Pulse wave Arterial Stiffness index')
    i=i.replace('4207','Pulse wave velocity (manual entry)')
    i=i.replace('4204','Absence of notch position in the pulse waveform')
    i=i.replace('4200','Position of the shoulder on the pulse waveform')
    i=i.replace('4199','Position of pulse wave notch')
    i=i.replace('4198','Position of the pulse wave peak')
    i=i.replace('4196','Pulse wave peak to peak time')
    i=i.replace('4195','Pulse wave reflection index')
    i=i.replace('4194','Pulse rate')
    i=i.replace('4186','Stiffness method')
    d.append(i)
df.columns=d
del df['Stiffness method-0.0']
del df['Pulse wave velocity (manual entry)-0.0']
df['eid'].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['eid']
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Blood and Urine
j=2
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('30890','Vitamin D')
    i=i.replace('30880','Urate')
    i=i.replace('30870','Triglycerides')
    i=i.replace('30860','Total protein')
    i=i.replace('30850','Testosterone')
    i=i.replace('30840','Total bilirubin')
    i=i.replace('30830','SHBG')
    i=i.replace('30820','Rheumatoid factor')
    i=i.replace('30810','Phosphate')
    i=i.replace('30800','Oestradiol')
    i=i.replace('30790','Lipoprotein A')
    i=i.replace('30780','LDL direct')
    i=i.replace('30770','IGF-1')
    i=i.replace('30760','HDL cholesterol')
    i=i.replace('30750','Glycated haemoglobin (HbA1c)')
    i=i.replace('30740','Glucose')
    i=i.replace('30730','Gamma glutamyltransferase')
    i=i.replace('30720','Cystatin C')
    i=i.replace('30710','C-reactive protein')
    i=i.replace('30700','Creatinine')
    i=i.replace('30690','Cholesterol')
    i=i.replace('30680','Calcium')
    i=i.replace('30670','Urea')
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('30660','Direct bilirubin')
    i=i.replace('30650','Aspartate aminotransferase')
    i=i.replace('30640','Apolipoprotein B')
    i=i.replace('30630','Apolipoprotein A')
    i=i.replace('30620','Alanine aminotransferase')
    i=i.replace('30610','Alkaline phosphatase')
    i=i.replace('30600','Albumin')
    i=i.replace('30300','High light scatter reticulocyte count')
    i=i.replace('30290','High light scatter reticulocyte percentage')
    i=i.replace('30280','Immature reticulocyte fraction')
    i=i.replace('30270','Mean sphered cell volume')
    i=i.replace('30260','Mean reticulocyte volume')
    i=i.replace('30250','Reticulocyte count')
    i=i.replace('30240','Reticulocyte percentage')
    i=i.replace('30230','Nucleated red blood cell percentage')
    i=i.replace('30220','Basophill percentage')
    i=i.replace('30210','Eosinophill percentage')
    i=i.replace('30200','Neutrophill percentage')
    i=i.replace('30190','Monocyte percentage')
    i=i.replace('30180','Lymphocyte percentage')
    i=i.replace('30170','Nucleated red blood cell count')
    i=i.replace('30160','Basophill count')
    i=i.replace('30150','Eosinophill count')
    i=i.replace('30140','Neutrophill count')
    i=i.replace('30130','Monocyte count')
    i=i.replace('30120','Lymphocyte count')
    i=i.replace('30110','Platelet distribution width')
    i=i.replace('30100','Mean platelet (thrombocyte) volume')
    i=i.replace('30090','Platelet crit')
    i=i.replace('30080','Platelet count')
    i=i.replace('30070','Red blood cell (erythrocyte) distribution width')
    i=i.replace('30060','Mean corpuscular haemoglobin concentration')
    i=i.replace('30050','Mean corpuscular haemoglobin')
    i=i.replace('30040','Mean corpuscular volume')
    i=i.replace('30030','Haematocrit percentage')
    i=i.replace('30020','Haemoglobin concentration')
    i=i.replace('30010','Red blood cell (erythrocyte) count')
    i=i.replace('30000','White blood cell (leukocyte) count')
    i=i.replace('30530','Sodium in urine')
    i=i.replace('30520','Potassium in urine')
    i=i.replace('30510','Creatinine (enzymatic) in urine')
    i=i.replace('30500','Microalbumin in urine')
    d.append(i)
df.columns=d
#For the smooth running of MICE
df['High light scatter reticulocyte count-0.0']=df['High light scatter reticulocyte count-0.0']*100
#Correction of imputation illegibility
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
df[['eid','Nucleated red blood cell count-0.0','Nucleated red blood cell percentage-0.0']].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['eid']
del df['Nucleated red blood cell percentage-0.0']
del df['Nucleated red blood cell count-0.0']
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Bone-densitometry of heel
j=3
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('4147','Speed of sound through heel, manual entry (right)')
    i=i.replace('4146','Heel broadband ultrasound attenuation (BUA), manual entry (right)')
    i=i.replace('4145','Heel bone mineral density (BMD), manual entry (right)')
    i=i.replace('4144','Heel quantitative ultrasound index (QUI), manual entry (right)')
    i=i.replace('4143','Heel bone mineral density (BMD) T-score, manual entry (right)')
    i=i.replace('4142','Speed of sound through heel, manual entry (left)')
    i=i.replace('4141','Heel broadband ultrasound attenuation (BUA), manual entry (left)')
    i=i.replace('4140','Heel bone mineral density (BMD), manual entry (left)')
    i=i.replace('4139','Heel quantitative ultrasound index (QUI), manual entry (left)')
    i=i.replace('4138','Heel bone mineral density (BMD) T-score, manual entry (left)')
    i=i.replace('4125','Heel bone mineral density (BMD) T-score, automated (right)')
    i=i.replace('4124','Heel bone mineral density (BMD) (right)')
    i=i.replace('4123','Heel quantitative ultrasound index (QUI), direct entry (right)')
    i=i.replace('4122','Speed of sound through heel (right)')
    i=i.replace('4120','Heel broadband ultrasound attenuation (right)')
    i=i.replace('4119','Ankle spacing width (right)')
    i=i.replace('4106','Heel bone mineral density (BMD) T-score, automated (left)')
    i=i.replace('4105','Heel bone mineral density (BMD) (left)')
    i=i.replace('4104','Heel quantitative ultrasound index (QUI), direct entry (left)')
    i=i.replace('4103','Speed of sound through heel (left)')
    i=i.replace('4101','Heel broadband ultrasound attenuation (left)')
    i=i.replace('4100','Ankle spacing width (left)')
    i=i.replace('4096','Fractured heel (right)')
    i=i.replace('4093','Fractured heel (left)')
    i=i.replace('3148','Heel bone mineral density (BMD)')
    i=i.replace('3147','Heel quantitative ultrasound index (QUI), direct entry')
    i=i.replace('3146','Speed of sound through heel')
    i=i.replace('3144','Heel Broadband ultrasound attenuation, direct entry')
    i=i.replace('3143','Ankle spacing width')
    i=i.replace('3086','Speed of sound through heel, manual entry')
    i=i.replace('3085','Heel Broadband ultrasound attenuation (BUA), manual entry')
    i=i.replace('3084','Heel bone mineral density (BMD), manual entry')
    i=i.replace('3083','Heel quantitative ultrasound index (QUI), manual entry')
    i=i.replace('3082','Fractured heel')
    i=i.replace('3081','Foot measured for bone density')
    i=i.replace('78-','Heel bone mineral density (BMD) T-score, automated-')
    i=i.replace('77-','Heel bone ultrasound T-score, manual entry-')
    d.append(i)
df.columns=d
df['Heel Broadband ultrasound attenuation, direct entry-0.0'][df['Heel Broadband ultrasound attenuation, direct entry-0.0'].isna()]=df['Heel Broadband ultrasound attenuation (BUA), manual entry-0.0'][df['Heel Broadband ultrasound attenuation, direct entry-0.0'].isna()]
del df['Heel Broadband ultrasound attenuation (BUA), manual entry-0.0']
df['Speed of sound through heel-0.0'][df['Speed of sound through heel-0.0'].isna()]=df['Speed of sound through heel, manual entry-0.0'][df['Speed of sound through heel-0.0'].isna()]
del df['Speed of sound through heel, manual entry-0.0']
df['Heel quantitative ultrasound index (QUI), direct entry-0.0'][df['Heel quantitative ultrasound index (QUI), direct entry-0.0'].isna()]=df['Heel quantitative ultrasound index (QUI), manual entry-0.0'][df['Heel quantitative ultrasound index (QUI), direct entry-0.0'].isna()]
del df['Heel quantitative ultrasound index (QUI), manual entry-0.0']
df['Heel bone mineral density (BMD)-0.0'][df['Heel bone mineral density (BMD)-0.0'].isna()]=df['Heel bone mineral density (BMD), manual entry-0.0'][df['Heel bone mineral density (BMD)-0.0'].isna()]
del df['Heel bone mineral density (BMD), manual entry-0.0']
df['Heel bone mineral density (BMD) T-score, automated-0.0'][df['Heel bone mineral density (BMD) T-score, automated-0.0'].isna()]=df['Heel bone ultrasound T-score, manual entry-0.0'][df['Heel bone mineral density (BMD) T-score, automated-0.0'].isna()]
del df['Heel bone ultrasound T-score, manual entry-0.0']
df['Fractured heel-0.0'][(df['Fractured heel (right)-0.0']==0)&(df['Fractured heel (left)-0.0']==0)]=0
df['Fractured heel-0.0'][(df['Fractured heel (right)-0.0']==1)|(df['Fractured heel (left)-0.0']==1)]=1
del df['Fractured heel (right)-0.0']
del df['Fractured heel (left)-0.0']
df['Ankle spacing width-0.0'][(df['Ankle spacing width (left)-0.0'].notna())&(df['Ankle spacing width (right)-0.0'].notna())]=(df['Ankle spacing width (left)-0.0']+df['Ankle spacing width (left)-0.0'])/2
df['Ankle spacing width-0.0'][(df['Ankle spacing width (left)-0.0'].notna())&(df['Ankle spacing width (right)-0.0'].isna())]=df['Ankle spacing width (left)-0.0']
df['Ankle spacing width-0.0'][(df['Ankle spacing width (left)-0.0'].isna())&(df['Ankle spacing width (right)-0.0'].notna())]=df['Ankle spacing width (right)-0.0']
del df['Ankle spacing width (left)-0.0']
del df['Ankle spacing width (right)-0.0']
df['Heel bone mineral density (BMD) (left)-0.0'][df['Heel bone mineral density (BMD) (left)-0.0'].isna()]=df['Heel bone mineral density (BMD), manual entry (left)-0.0'][df['Heel bone mineral density (BMD) (left)-0.0'].isna()]
del df['Heel bone mineral density (BMD), manual entry (left)-0.0']
df['Heel bone mineral density (BMD) T-score, automated (left)-0.0'][df['Heel bone mineral density (BMD) T-score, automated (left)-0.0'].isna()]=df['Heel bone mineral density (BMD) T-score, manual entry (left)-0.0'][df['Heel bone mineral density (BMD) T-score, automated (left)-0.0'].isna()]
del df['Heel bone mineral density (BMD) T-score, manual entry (left)-0.0']
df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0'][df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0'].isna()]=df['Heel quantitative ultrasound index (QUI), manual entry (left)-0.0'][df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0'].isna()]
del df['Heel quantitative ultrasound index (QUI), manual entry (left)-0.0']
df['Heel broadband ultrasound attenuation (left)-0.0'][df['Heel broadband ultrasound attenuation (left)-0.0'].isna()]=df['Heel broadband ultrasound attenuation (BUA), manual entry (left)-0.0'][df['Heel broadband ultrasound attenuation (left)-0.0'].isna()]
del df['Heel broadband ultrasound attenuation (BUA), manual entry (left)-0.0']
df['Speed of sound through heel (left)-0.0'][df['Speed of sound through heel (left)-0.0'].isna()]=df['Speed of sound through heel, manual entry (left)-0.0'][df['Speed of sound through heel (left)-0.0'].isna()]
del df['Speed of sound through heel, manual entry (left)-0.0']
df['Heel bone mineral density (BMD) T-score, automated (right)-0.0'][df['Heel bone mineral density (BMD) T-score, automated (right)-0.0'].isna()]=df['Heel bone mineral density (BMD) T-score, manual entry (right)-0.0'][df['Heel bone mineral density (BMD) T-score, automated (right)-0.0'].isna()]
del df['Heel bone mineral density (BMD) T-score, manual entry (right)-0.0']
df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0'][df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0'].isna()]=df['Heel quantitative ultrasound index (QUI), manual entry (right)-0.0'][df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0'].isna()]
del df['Heel quantitative ultrasound index (QUI), manual entry (right)-0.0']
df['Heel bone mineral density (BMD) (right)-0.0'][df['Heel bone mineral density (BMD) (right)-0.0'].isna()]=df['Heel bone mineral density (BMD), manual entry (right)-0.0'][df['Heel bone mineral density (BMD) (right)-0.0'].isna()]
del df['Heel bone mineral density (BMD), manual entry (right)-0.0']
df['Heel broadband ultrasound attenuation (right)-0.0'][df['Heel broadband ultrasound attenuation (right)-0.0'].isna()]=df['Heel broadband ultrasound attenuation (BUA), manual entry (right)-0.0'][df['Heel broadband ultrasound attenuation (right)-0.0'].isna()]
del df['Heel broadband ultrasound attenuation (BUA), manual entry (right)-0.0']
df['Speed of sound through heel (right)-0.0'][df['Speed of sound through heel (right)-0.0'].isna()]=df['Speed of sound through heel, manual entry (right)-0.0'][df['Speed of sound through heel (right)-0.0'].isna()]
del df['Speed of sound through heel, manual entry (right)-0.0']
df['Heel bone mineral density (BMD) T-score, automated-0.0'][(df['Heel bone mineral density (BMD) T-score, automated-0.0'].isna())&(df['Heel bone mineral density (BMD) T-score, automated (left)-0.0'].notna())&(df['Heel bone mineral density (BMD) T-score, automated (right)-0.0'].notna())]=(df['Heel bone mineral density (BMD) T-score, automated (left)-0.0']+df['Heel bone mineral density (BMD) T-score, automated (right)-0.0'])/2
df['Heel bone mineral density (BMD) T-score, automated-0.0'][(df['Heel bone mineral density (BMD) T-score, automated-0.0'].isna())&(df['Heel bone mineral density (BMD) T-score, automated (left)-0.0'].isna())&(df['Heel bone mineral density (BMD) T-score, automated (right)-0.0'].notna())]=df['Heel bone mineral density (BMD) T-score, automated (right)-0.0']
df['Heel bone mineral density (BMD) T-score, automated-0.0'][(df['Heel bone mineral density (BMD) T-score, automated-0.0'].isna())&(df['Heel bone mineral density (BMD) T-score, automated (left)-0.0'].notna())&(df['Heel bone mineral density (BMD) T-score, automated (right)-0.0'].isna())]=df['Heel bone mineral density (BMD) T-score, automated (left)-0.0']
del df['Heel bone mineral density (BMD) T-score, automated (left)-0.0']
del df['Heel bone mineral density (BMD) T-score, automated (right)-0.0']
df['Heel Broadband ultrasound attenuation, direct entry-0.0'][(df['Heel Broadband ultrasound attenuation, direct entry-0.0'].isna())&(df['Heel broadband ultrasound attenuation (left)-0.0'].notna())&(df['Heel broadband ultrasound attenuation (right)-0.0'].notna())]=(df['Heel broadband ultrasound attenuation (right)-0.0']+df['Heel broadband ultrasound attenuation (left)-0.0'])/2
df['Heel Broadband ultrasound attenuation, direct entry-0.0'][(df['Heel Broadband ultrasound attenuation, direct entry-0.0'].isna())&(df['Heel broadband ultrasound attenuation (left)-0.0'].isna())&(df['Heel broadband ultrasound attenuation (right)-0.0'].notna())]=df['Heel broadband ultrasound attenuation (right)-0.0']
df['Heel Broadband ultrasound attenuation, direct entry-0.0'][(df['Heel Broadband ultrasound attenuation, direct entry-0.0'].isna())&(df['Heel broadband ultrasound attenuation (left)-0.0'].notna())&(df['Heel broadband ultrasound attenuation (right)-0.0'].isna())]=df['Heel broadband ultrasound attenuation (left)-0.0']
del df['Heel broadband ultrasound attenuation (right)-0.0']
del df['Heel broadband ultrasound attenuation (left)-0.0']
df['Speed of sound through heel-0.0'][(df['Speed of sound through heel-0.0'].isna())&(df['Speed of sound through heel (left)-0.0'].notna())&(df['Speed of sound through heel (right)-0.0'].notna())]=(df['Speed of sound through heel (left)-0.0']+df['Speed of sound through heel (right)-0.0'])/2
df['Speed of sound through heel-0.0'][(df['Speed of sound through heel-0.0'].isna())&(df['Speed of sound through heel (left)-0.0'].isna())&(df['Speed of sound through heel (right)-0.0'].notna())]=df['Speed of sound through heel (right)-0.0']
df['Speed of sound through heel-0.0'][(df['Speed of sound through heel-0.0'].isna())&(df['Speed of sound through heel (left)-0.0'].notna())&(df['Speed of sound through heel (right)-0.0'].isna())]=df['Speed of sound through heel (left)-0.0']
del df['Speed of sound through heel (left)-0.0']
del df['Speed of sound through heel (right)-0.0']
df['Heel quantitative ultrasound index (QUI), direct entry-0.0'][(df['Heel quantitative ultrasound index (QUI), direct entry-0.0'].isna())&(df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0'].notna())&(df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0'].notna())]=(df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0']+df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0'])/2
df['Heel quantitative ultrasound index (QUI), direct entry-0.0'][(df['Heel quantitative ultrasound index (QUI), direct entry-0.0'].isna())&(df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0'].isna())&(df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0'].notna())]=df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0']
df['Heel quantitative ultrasound index (QUI), direct entry-0.0'][(df['Heel quantitative ultrasound index (QUI), direct entry-0.0'].isna())&(df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0'].notna())&(df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0'].isna())]=df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0']
del df['Heel quantitative ultrasound index (QUI), direct entry (right)-0.0']
del df['Heel quantitative ultrasound index (QUI), direct entry (left)-0.0']
df['Heel bone mineral density (BMD)-0.0'][(df['Heel bone mineral density (BMD)-0.0'].isna())&(df['Heel bone mineral density (BMD) (left)-0.0'].notna())&(df['Heel bone mineral density (BMD) (right)-0.0'].notna())]=(df['Heel bone mineral density (BMD) (right)-0.0']+df['Heel bone mineral density (BMD) (left)-0.0'])/2
df['Heel bone mineral density (BMD)-0.0'][(df['Heel bone mineral density (BMD)-0.0'].isna())&(df['Heel bone mineral density (BMD) (left)-0.0'].isna())&(df['Heel bone mineral density (BMD) (right)-0.0'].notna())]=df['Heel bone mineral density (BMD) (right)-0.0']
df['Heel bone mineral density (BMD)-0.0'][(df['Heel bone mineral density (BMD)-0.0'].isna())&(df['Heel bone mineral density (BMD) (left)-0.0'].notna())&(df['Heel bone mineral density (BMD) (right)-0.0'].isna())]=df['Heel bone mineral density (BMD) (left)-0.0']
del df['Heel bone mineral density (BMD) (right)-0.0']
del df['Heel bone mineral density (BMD) (left)-0.0']
#Correction of imputation illegibility
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(1)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(1,inplace=True)
df[['eid','Heel quantitative ultrasound index (QUI), direct entry-0.0','Heel bone mineral density (BMD) T-score, automated-0.0','Fractured heel-0.0','Foot measured for bone density-0.0']].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['Heel quantitative ultrasound index (QUI), direct entry-0.0']
del df['Heel bone mineral density (BMD) T-score, automated-0.0']
del df['Foot measured for bone density-0.0']
del df['Fractured heel-0.0']
del df['eid']
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Cognitive
j=4
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('20129','Number of columns displayed in round')
    i=i.replace('20130','Number of rows displayed in round')
    i=i.replace('20131','Number of correct matches in round')
    i=i.replace('20132','Number of incorrect matches in round')
    i=i.replace('20133','Time to complete round')
    i=i.replace('20147','Errors before selecting correct item in numeric path (trail #1)')
    i=i.replace('20148','Errors before selecting correct item in alphanumeric path (trail #2)')
    i=i.replace('20149','Interval between previous point and current one in numeric path (trail #1)')
    i=i.replace('20155','Interval between previous point and current one in alphanumeric path (trail #2)')
    i=i.replace('20156','Duration to complete numeric path (trail #1)')
    i=i.replace('20157','Duration to complete alphanumeric path (trail #2)')
    i=i.replace('20159','Number of symbol digit matches made correctly')
    i=i.replace('20165','FI1 : numeric addition test')
    i=i.replace('20167','FI2 : identify largest number')
    i=i.replace('20169','FI3 : word interpolation')
    i=i.replace('20171','FI4 : positional arithmetic')
    i=i.replace('20173','FI5 : family relationship calculation')
    i=i.replace('20175','FI6 : conditional arithmetic')
    i=i.replace('20177','FI7 : synonym')
    i=i.replace('20179','FI8 : chained arithmetic')
    i=i.replace('20181','FI9 : concept interpolation')
    i=i.replace('20183','FI10 : arithmetic sequence recognition')
    i=i.replace('20185','FI11 : antonym')
    i=i.replace('20187','FI12 : square sequence recognition')
    i=i.replace('20189','FI13 : subset inclusion logic')
    i=i.replace('20193','FI14 : alphanumeric substitution')
    i=i.replace('20191','Fluid intelligence score')
    i=i.replace('20195','Number of symbol digit matches attempted')
    i=i.replace('20196','First code array presented')
    i=i.replace('20200','Values wanted')
    i=i.replace('20229','Values entered')
    i=i.replace('20230','Duration to entering value')
    i=i.replace('20240','Maximum digits remembered correctly')
    i=i.replace('20242','Fluid intelligence completion status')
    i=i.replace('20244','Pairs matching completion status')
    i=i.replace('20245','Symbol digit completion status')
    i=i.replace('20246','Trail making completion status')
    i=i.replace('20247','Total errors traversing numeric path (trail #1)')
    i=i.replace('20248','Total errors traversing alphanumeric path (trail #2)')
    d.append(i)
df.columns=d
for i in range(1,26):
    df['Errors before selecting correct item in numeric path (trail #1)-0.'+str(i)][(df['Interval between previous point and current one in numeric path (trail #1)-0.'+str(i)].notnull())&(df['Errors before selecting correct item in numeric path (trail #1)-0.'+str(i)].isna())]=0
    df['Errors before selecting correct item in alphanumeric path (trail #2)-0.'+str(i)][(df['Interval between previous point and current one in alphanumeric path (trail #2)-0.'+str(i)].notnull())&(df['Errors before selecting correct item in alphanumeric path (trail #2)-0.'+str(i)].isna())]=0
for i in range(1,26):
    df['Errors before selecting correct item in numeric path (trail #1)-0.'+str(i)].fillna(0,inplace=True)
    df['Errors before selecting correct item in alphanumeric path (trail #2)-0.'+str(i)].fillna(0,inplace=True)
df[df<0]=np.nan
df['Total errors traversing alphanumeric path (trail #2)-0.0'][df['Trail making completion status-0.0']==1]=np.nan
df['Total errors traversing alphanumeric path (trail #2)-0.0'][df['Trail making completion status-0.0']==3]=np.nan
df['Duration to complete alphanumeric path (trail #2)-0.0'][df['Trail making completion status-0.0']==1]=np.nan
df['Duration to complete alphanumeric path (trail #2)-0.0'][df['Trail making completion status-0.0']==3]=300
df['Duration to complete numeric path (trail #1)-0.0'][df['Trail making completion status-0.0']==3]=300
df['Total errors traversing numeric path (trail #1)-0.0'][(df.iloc[:,40:65].T.isna().sum() ==0) & (df['Total errors traversing numeric path (trail #1)-0.0'].isna())]=df.iloc[:,40:65][(df.iloc[:,40:65].T.isna().sum() ==0) & (df['Total errors traversing numeric path (trail #1)-0.0'].isna())].T.sum()
df['Total errors traversing alphanumeric path (trail #2)-0.0'][(df.iloc[:,65:90].T.isna().sum() ==0) &(df['Total errors traversing alphanumeric path (trail #2)-0.0'].isna())]=df.iloc[:,65:90][(df.iloc[:,65:90].T.isna().sum() ==0) &(df['Total errors traversing alphanumeric path (trail #2)-0.0'].isna())].T.sum()
df['Duration to complete numeric path (trail #1)-0.0'][(df.iloc[:,90:115].T.isna().sum() ==0)&(df['Duration to complete numeric path (trail #1)-0.0'].isna())]=df.iloc[:,90:115][(df.iloc[:,90:115].T.isna().sum()==0)&(df['Duration to complete numeric path (trail #1)-0.0'].isna())].T.sum()/1000
df['Duration to complete alphanumeric path (trail #2)-0.0'][(df.iloc[:,115:140].T.isna().sum() ==0)&(df['Duration to complete alphanumeric path (trail #2)-0.0'].isna())]=df.iloc[:,115:140][(df.iloc[:,115:140].T.isna().sum() ==0)&(df['Duration to complete alphanumeric path (trail #2)-0.0'].isna())].T.sum()/1000
df['Number of symbol digit matches made correctly-0.0'][df['Symbol digit completion status-0.0']==1]=np.nan
df['Number of symbol digit matches attempted-0.0'][df['Symbol digit completion status-0.0']==1]=np.nan
df['Fluid intelligence score-0.0'][df['Fluid intelligence completion status-0.0']==1]=np.nan
df['Number of correct matches in round-0.0'][(df['Pairs matching completion status-0.0']==1)& (df['Time to complete round-0.0'].isna())]=np.nan
df['Number of correct matches in round-0.1'][(df['Pairs matching completion status-0.0']==1)& (df['Time to complete round-0.1'].isna())]=np.nan
df['Number of incorrect matches in round-0.0'][(df['Pairs matching completion status-0.0']==1)& (df['Time to complete round-0.0'].isna())]=np.nan
df['Number of incorrect matches in round-0.1'][(df['Pairs matching completion status-0.0']==1)& (df['Time to complete round-0.1'].isna())]=np.nan
dict={0:8,1:6,2:3,3:np.nan}
a=list(df.loc[:,['Number of correct matches in round-0.0','Number of correct matches in round-0.1','Number of correct matches in round-0.2']].T.isna().sum())
num=[]
for i in range(df.shape[0]):
    num.append(dict[a[i]])
df['Number of grade']=num
#Correction of imputation illegibility
df['FI1 : numeric addition test-0.0'].fillna(3,inplace=True)
df['FI2 : identify largest number-0.0'].fillna(3,inplace=True)
df['Values wanted-0.0'].fillna(7,inplace=True)
df['Values wanted-0.1'].fillna(4,inplace=True)
df['Values wanted-0.2'].fillna(6,inplace=True)
df['Values wanted-0.3'].fillna(2,inplace=True)
df['Values wanted-0.4'].fillna(3,inplace=True)
df['Values wanted-0.5'].fillna(8,inplace=True)
df['Values wanted-0.6'].fillna(5,inplace=True)
df['Values wanted-0.7'].fillna(1,inplace=True)
df['Number of correct matches in round-0.0'].fillna(3,inplace=True)
df['Number of correct matches in round-0.1'].fillna(6,inplace=True)
df[['eid','Number of correct matches in round-0.0','FI7 : synonym-0.0','Number of correct matches in round-0.1','Errors before selecting correct item in numeric path (trail #1)-0.1','Errors before selecting correct item in numeric path (trail #1)-0.2','Errors before selecting correct item in numeric path (trail #1)-0.3','Errors before selecting correct item in numeric path (trail #1)-0.4','Errors before selecting correct item in numeric path (trail #1)-0.5','Errors before selecting correct item in numeric path (trail #1)-0.6','Errors before selecting correct item in numeric path (trail #1)-0.7','Errors before selecting correct item in numeric path (trail #1)-0.8','Errors before selecting correct item in numeric path (trail #1)-0.9','Errors before selecting correct item in numeric path (trail #1)-0.10','Errors before selecting correct item in numeric path (trail #1)-0.11','Errors before selecting correct item in numeric path (trail #1)-0.12','Errors before selecting correct item in numeric path (trail #1)-0.13','Errors before selecting correct item in numeric path (trail #1)-0.14','Errors before selecting correct item in numeric path (trail #1)-0.15','Errors before selecting correct item in numeric path (trail #1)-0.16','Errors before selecting correct item in numeric path (trail #1)-0.17','Errors before selecting correct item in numeric path (trail #1)-0.18','Errors before selecting correct item in numeric path (trail #1)-0.19','Errors before selecting correct item in numeric path (trail #1)-0.20','Errors before selecting correct item in numeric path (trail #1)-0.21','Errors before selecting correct item in numeric path (trail #1)-0.22','Errors before selecting correct item in numeric path (trail #1)-0.23','Errors before selecting correct item in numeric path (trail #1)-0.24','Errors before selecting correct item in numeric path (trail #1)-0.25','Errors before selecting correct item in alphanumeric path (trail #2)-0.1','Errors before selecting correct item in alphanumeric path (trail #2)-0.2','Errors before selecting correct item in alphanumeric path (trail #2)-0.3','Errors before selecting correct item in alphanumeric path (trail #2)-0.4','Errors before selecting correct item in alphanumeric path (trail #2)-0.5','Errors before selecting correct item in alphanumeric path (trail #2)-0.6','Errors before selecting correct item in alphanumeric path (trail #2)-0.7','Errors before selecting correct item in alphanumeric path (trail #2)-0.8','Errors before selecting correct item in alphanumeric path (trail #2)-0.9','Errors before selecting correct item in alphanumeric path (trail #2)-0.10','Errors before selecting correct item in alphanumeric path (trail #2)-0.11','Errors before selecting correct item in alphanumeric path (trail #2)-0.12','Errors before selecting correct item in alphanumeric path (trail #2)-0.13','Errors before selecting correct item in alphanumeric path (trail #2)-0.14','Errors before selecting correct item in alphanumeric path (trail #2)-0.15','Errors before selecting correct item in alphanumeric path (trail #2)-0.16','Errors before selecting correct item in alphanumeric path (trail #2)-0.17','Errors before selecting correct item in alphanumeric path (trail #2)-0.18','Errors before selecting correct item in alphanumeric path (trail #2)-0.19','Errors before selecting correct item in alphanumeric path (trail #2)-0.20','Errors before selecting correct item in alphanumeric path (trail #2)-0.21','Errors before selecting correct item in alphanumeric path (trail #2)-0.22','Errors before selecting correct item in alphanumeric path (trail #2)-0.23','Errors before selecting correct item in alphanumeric path (trail #2)-0.24','Errors before selecting correct item in alphanumeric path (trail #2)-0.25','Values wanted-0.0','Values wanted-0.1','Values wanted-0.2','Values wanted-0.3','Values wanted-0.4','Values wanted-0.5','Values wanted-0.6','Values wanted-0.7','Number of symbol digit matches made correctly-0.0','Values entered-0.1','Values entered-0.2','Values entered-0.3','Values entered-0.4','Values entered-0.5','Values entered-0.6','Values entered-0.7','FI1 : numeric addition test-0.0','FI2 : identify largest number-0.0','Values wanted-0.9','Values wanted-0.10','Values wanted-0.11','Values wanted-0.12','Values wanted-0.13','Values wanted-0.14','Values wanted-0.15','Values wanted-0.16','Values wanted-0.17','Values wanted-0.18','Values wanted-0.19','Values wanted-0.20','Values wanted-0.21','Values wanted-0.22','Values wanted-0.23','Values wanted-0.24','Values wanted-0.25','Values wanted-0.26','Values wanted-0.27','Values wanted-0.28','Values wanted-0.29','Values wanted-0.30','Values wanted-0.31']].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df.drop(['eid','Number of correct matches in round-0.2','FI7 : synonym-0.0','Time to complete round-0.2','Fluid intelligence completion status-0.0','Pairs matching completion status-0.0','Symbol digit completion status-0.0','Trail making completion status-0.0','Number of correct matches in round-0.0','Number of incorrect matches in round-0.2','Number of correct matches in round-0.1','Errors before selecting correct item in numeric path (trail #1)-0.1','Errors before selecting correct item in numeric path (trail #1)-0.2','Errors before selecting correct item in numeric path (trail #1)-0.3','Errors before selecting correct item in numeric path (trail #1)-0.4','Errors before selecting correct item in numeric path (trail #1)-0.5','Errors before selecting correct item in numeric path (trail #1)-0.6','Errors before selecting correct item in numeric path (trail #1)-0.7','Errors before selecting correct item in numeric path (trail #1)-0.8','Errors before selecting correct item in numeric path (trail #1)-0.9','Errors before selecting correct item in numeric path (trail #1)-0.10','Errors before selecting correct item in numeric path (trail #1)-0.11','Errors before selecting correct item in numeric path (trail #1)-0.12','Errors before selecting correct item in numeric path (trail #1)-0.13','Errors before selecting correct item in numeric path (trail #1)-0.14','Errors before selecting correct item in numeric path (trail #1)-0.15','Errors before selecting correct item in numeric path (trail #1)-0.16','Errors before selecting correct item in numeric path (trail #1)-0.17','Errors before selecting correct item in numeric path (trail #1)-0.18','Errors before selecting correct item in numeric path (trail #1)-0.19','Errors before selecting correct item in numeric path (trail #1)-0.20','Errors before selecting correct item in numeric path (trail #1)-0.21','Errors before selecting correct item in numeric path (trail #1)-0.22','Errors before selecting correct item in numeric path (trail #1)-0.23','Errors before selecting correct item in numeric path (trail #1)-0.24','Errors before selecting correct item in numeric path (trail #1)-0.25','Errors before selecting correct item in alphanumeric path (trail #2)-0.1','Errors before selecting correct item in alphanumeric path (trail #2)-0.2','Errors before selecting correct item in alphanumeric path (trail #2)-0.3','Errors before selecting correct item in alphanumeric path (trail #2)-0.4','Errors before selecting correct item in alphanumeric path (trail #2)-0.5','Errors before selecting correct item in alphanumeric path (trail #2)-0.6','Errors before selecting correct item in alphanumeric path (trail #2)-0.7','Errors before selecting correct item in alphanumeric path (trail #2)-0.8','Errors before selecting correct item in alphanumeric path (trail #2)-0.9','Errors before selecting correct item in alphanumeric path (trail #2)-0.10','Errors before selecting correct item in alphanumeric path (trail #2)-0.11','Errors before selecting correct item in alphanumeric path (trail #2)-0.12','Errors before selecting correct item in alphanumeric path (trail #2)-0.13','Errors before selecting correct item in alphanumeric path (trail #2)-0.14','Errors before selecting correct item in alphanumeric path (trail #2)-0.15','Errors before selecting correct item in alphanumeric path (trail #2)-0.16','Errors before selecting correct item in alphanumeric path (trail #2)-0.17','Errors before selecting correct item in alphanumeric path (trail #2)-0.18','Errors before selecting correct item in alphanumeric path (trail #2)-0.19','Errors before selecting correct item in alphanumeric path (trail #2)-0.20','Errors before selecting correct item in alphanumeric path (trail #2)-0.21','Errors before selecting correct item in alphanumeric path (trail #2)-0.22','Errors before selecting correct item in alphanumeric path (trail #2)-0.23','Errors before selecting correct item in alphanumeric path (trail #2)-0.24','Errors before selecting correct item in alphanumeric path (trail #2)-0.25','Values wanted-0.0','Values wanted-0.1','Values wanted-0.2','Values wanted-0.3','Values wanted-0.4','Values wanted-0.5','Values wanted-0.6','Values wanted-0.7','Number of symbol digit matches made correctly-0.0','Values entered-0.1','Values entered-0.2','Values entered-0.3','Values entered-0.4','Values entered-0.5','Values entered-0.6','Values entered-0.7','FI1 : numeric addition test-0.0','FI2 : identify largest number-0.0','Values wanted-0.9','Values wanted-0.10','Values wanted-0.11','Values wanted-0.12','Values wanted-0.13','Values wanted-0.14','Values wanted-0.15','Values wanted-0.16','Values wanted-0.17','Values wanted-0.18','Values wanted-0.19','Values wanted-0.20','Values wanted-0.21','Values wanted-0.22','Values wanted-0.23','Values wanted-0.24','Values wanted-0.25','Values wanted-0.26','Values wanted-0.27','Values wanted-0.28','Values wanted-0.29','Values wanted-0.30','Values wanted-0.31'],axis=1,inplace=True)
#High Pearson correlation coefficient variables
col=list(df)
corr=np.array(df.corr())
for i in range(df.shape[1]):
    for k in range(i):
        if corr[i,j]>=0.95:
            df[col[i]][df[col[i]].isnull()] = df[col[k]][df[col[i]].isnull()]
            df[col[k]][df[col[k]].isnull()] = df[col[i]][df[col[k]].isnull()]
#remove outliers
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Carotid ultrasound
j=5
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('22681','Maximum carotid IMT (intima-medial thickness) at 240 degrees')
    i=i.replace('22680','Mean carotid IMT (intima-medial thickness) at 240 degrees')
    i=i.replace('22679','Minimum carotid IMT (intima-medial thickness) at 240 degrees')
    i=i.replace('22678','Maximum carotid IMT (intima-medial thickness) at 210 degrees')
    i=i.replace('22677','Mean carotid IMT (intima-medial thickness) at 210 degrees')
    i=i.replace('22676','Minimum carotid IMT (intima-medial thickness) at 210 degrees')
    i=i.replace('22675','Maximum carotid IMT (intima-medial thickness) at 150 degrees')
    i=i.replace('22674','Mean carotid IMT (intima-medial thickness) at 150 degrees')
    i=i.replace('22673','Minimum carotid IMT (intima-medial thickness) at 150 degrees')
    i=i.replace('22672','Maximum carotid IMT (intima-medial thickness) at 120 degrees')
    i=i.replace('22671','Mean carotid IMT (intima-medial thickness) at 120 degrees')
    i=i.replace('22670','Minimum carotid IMT (intima-medial thickness) at 120 degrees')
    i=i.replace('12292','Carotid ultrasound measurement completed')
    d.append(i)
df.columns=d
df=df[df['Age when attended assessment centre-2.0'].notna()]
df['eid'].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['eid']
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-ECG at rest
j=6
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('22338','QRS num')
    i=i.replace('22337','T axis')
    i=i.replace('22336','R axis')
    i=i.replace('22335','P axis')
    i=i.replace('22334','PP interval')
    i=i.replace('22333','RR interval')
    i=i.replace('22332','QTC interval')
    i=i.replace('22331','QT interval')
    i=i.replace('22330','PQ interval')
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('12340','QRS duration')
    i=i.replace('12338','P duration')
    i=i.replace('12336','Ventricular rate')
    d.append(i)
df.columns=d
df=df[df['Age when attended assessment centre-2.0'].notna()]
df['eid'].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['eid']
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-ECG during exercise
j=7
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('6016','Chest pain felt outside physical activity')
    i=i.replace('6015','Chest pain felt during physical activity')
    i=i.replace('6014','Doctor restricts physical activity due to heart condition')
    i=i.replace('6039','Duration of fitness test')
    i=i.replace('6038','Number of trend entries')
    i=i.replace('6034','Target heart rate achieved')
    i=i.replace('6033','Maximum heart rate during fitness test')
    i=i.replace('6032','Maximum workload during fitness test')
    i=i.replace('6019','ECG/bike method for fitness test')
    i=i.replace('6017','Able to walk or cycle unaided for 10 minutes')
    i=i.replace('5993','ECG, number of stages in a phase')
    i=i.replace('5992','ECG, phase duration')
    i=i.replace('5986','ECG, phase time')
    i=i.replace('5985','Bicycle speed')
    i=i.replace('5984','ECG, load')
    i=i.replace('5983','ECG, heart rate')
    d.append(i)
df.columns=d
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(1)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(1,inplace=True)
#correction of imputation illegibility and remove of high correlation variables
var=[2,3,5,6,7,14,15,16,17,18,19,20,30,66,80,81,106,122,140,154,166,182,197,204,205,206,207,224,254,255,256,257]+[i for i in range(22,30)]+[i for i in range(216,224)]+[i for i in range(32,66)]+[i for i in range(70,80)]+[i for i in range(86,106)]+[i for i in range(109,122)]+[i for i in range(129,139)]+[i for i in range(150,154)]+[i for i in range(156,166)]+[i for i in range(170,182)]+[i for i in range(186,197)]
df.iloc[:,var].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var+[8]))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Eyesight
j=8
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('5074','Number of letters shown in round (left)')
    i=i.replace('5075','Number of letters shown in round (right)')
    i=i.replace('5076','Number of letters correct in round (right)')
    i=i.replace('5077','Number of letters correct in round (left)')
    i=i.replace('5078','logMAR in round (left)')
    i=i.replace('5079','logMAR in round (right)')
    i=i.replace('5084','Spherical power (right)')
    i=i.replace('5085','Spherical power (left)')
    i=i.replace('5086','Cylindrical power (left)')
    i=i.replace('5087','Cylindrical power (right)')
    i=i.replace('5088','Astigmatism angle (right)')
    i=i.replace('5089','Astigmatism angle (left)')
    i=i.replace('5090','Refractometry result unreliable (left)')
    i=i.replace('5091','Refractometry result unreliable (right)')
    i=i.replace('5096','3mm weak meridian (left)')
    i=i.replace('5097','6mm weak meridian (left)')
    i=i.replace('5098','6mm weak meridian (right)')
    i=i.replace('5099','3mm weak meridian (right)')
    i=i.replace('5100','3mm weak meridian angle (right)')
    i=i.replace('5101','6mm weak meridian angle (right)')
    i=i.replace('5102','6mm weak meridian angle (left)')
    i=i.replace('5103','3mm weak meridian angle (left)')
    i=i.replace('5104','3mm strong meridian angle (left)')
    i=i.replace('5106','6mm strong meridian angle (right)')
    i=i.replace('5107','3mm strong meridian angle (right)')
    i=i.replace('5108','3mm asymmetry angle (right)')
    i=i.replace('5109','6mm asymmetry angle (right)')
    i=i.replace('5110','6mm asymmetry angle (left)')
    i=i.replace('5111','3mm asymmetry angle (left)')
    i=i.replace('5112','3mm cylindrical power angle (left)')
    i=i.replace('5113','6mm cylindrical power angle (left)')
    i=i.replace('5114','6mm cylindrical power angle (right)')
    i=i.replace('5115','3mm cylindrical power angle (right)')
    i=i.replace('5116','3mm cylindrical power (right)')
    i=i.replace('5117','6mm cylindrical power (right)')
    i=i.replace('5118','6mm cylindrical power (left)')
    i=i.replace('5119','3mm cylindrical power (left)')
    i=i.replace('5132','3mm strong meridian (right)')
    i=i.replace('5133','6mm strong meridian (right)')
    i=i.replace('5134','6mm strong meridian (left)')
    i=i.replace('5135','3mm strong meridian (left)')
    i=i.replace('5136','3mm keratometry result unreliable (left)')
    i=i.replace('5138','6mm keratometry result unreliable (left)')
    i=i.replace('5139','6mm keratometry result unreliable (right)')
    i=i.replace('5140','3mm keratometry result unreliable (right)')
    i=i.replace('5141','3mm asymmetry index unreliable (left)')
    i=i.replace('5142','6mm asymmetry index unreliable (left)')
    i=i.replace('5143','6mm asymmetry index unreliable (right)')
    i=i.replace('5144','3mm asymmetry index unreliable (right)')
    i=i.replace('5145','3mm regularity index unreliable (right)')
    i=i.replace('5146','6mm regularity index unreliable (right)')
    i=i.replace('5147','6mm regularity index unreliable (left)')
    i=i.replace('5148','3mm regularity index unreliable (left)')
    i=i.replace('5149','3mm regularity index for irregular astigmatism level (left)')
    i=i.replace('5152','3mm asymmetry index for irregular astigmatism level (right)')
    i=i.replace('5155','3mm asymmetry index for irregular astigmatism level (left)')
    i=i.replace('5156','3mm asymmetry index (left)')
    i=i.replace('5157','6mm asymmetry index (left)')
    i=i.replace('5158','6mm asymmetry index (right)')
    i=i.replace('5159','3mm asymmetry index (right)')
    i=i.replace('5160','3mm regularity index (right)')
    i=i.replace('5161','6mm regularity index (right)')
    i=i.replace('5162','6mm regularity index (left)')
    i=i.replace('5163','3mm regularity index (left)')
    i=i.replace('5164','3mm regularity index for irregular astigmatism level (right)')
    i=i.replace('5185','Visual acuity measured (right)')
    i=i.replace('5186','Duration visual-acuity screen displayed (right)')
    i=i.replace('5187','Visual acuity measured (left)')
    i=i.replace('5188','Duration visual-acuity screen displayed (left)')
    i=i.replace('5189','Auto-refraction method (right)')
    i=i.replace('5190','Duration at which refractometer first shown (right)')
    i=i.replace('5191','Auto-refraction method (left)')
    i=i.replace('5193','Duration at which refractometer first shown (left)')
    i=i.replace('5199','logMAR, initial (right)')
    i=i.replace('5200','Final number of letters displayed (right)')
    i=i.replace('5201','logMAR, final (right)')
    i=i.replace('5202','Number of rounds to result (right)')
    i=i.replace('5204','Distance of viewer to screen (right)')
    i=i.replace('5205','Direct or mirror view (right)')
    i=i.replace('5206','logMAR, initial (left)')
    i=i.replace('5207','Final number of letters displayed (left)')
    i=i.replace('5208','logMAR, final (left)')
    i=i.replace('5209','Number of rounds to result (left)')
    i=i.replace('5211','Distance of viewer to screen (left)')
    i=i.replace('5215','Vertex distance (right)')
    i=i.replace('5212','Direct or mirror view (left)')
    i=i.replace('5221','Index of best refractometry result (right)')
    i=i.replace('5237','3mm index of best keratometry results (right)')
    i=i.replace('5251','6mm index of best keratometry results (right)')
    i=i.replace('5254','Intra-ocular pressure, corneal-compensated (right)')
    i=i.replace('5255','Intra-ocular pressure, Goldmann-correlated (right)')
    i=i.replace('5256','Corneal hysteresis (right)')
    i=i.replace('5257','Corneal resistance factor (right)')
    i=i.replace('5262','Intra-ocular pressure, corneal-compensated (left)')
    i=i.replace('5263','Intra-ocular pressure, Goldmann-correlated (left)')
    i=i.replace('5264','Corneal hysteresis (left)')
    i=i.replace('5265','Corneal resistance factor (left)')
    i=i.replace('5274','Vertex distance (left)')
    i=i.replace('5276','Index of best refractometry result (left)')
    i=i.replace('5292','3mm index of best keratometry results (left)')
    i=i.replace('5306','6mm index of best keratometry results (left)')
    i=i.replace('6074','Glasses worn/required (right)')
    i=i.replace('6075','Glasses worn/required (left)')
    i=i.replace('20261','avMSE')
    i=i.replace('20262','Myopia diagnosis')
    d.append(i)
df.columns=d
for i in range(3):
    df.loc[:,['Index of best refractometry result (left)-0.0']+['Spherical power (left)-0.'+str(i)]+['Cylindrical power (left)-0.'+str(i)]+['Astigmatism angle (left)-0.'+str(i)]][df['Refractometry result unreliable (left)-0.'+str(i)].notna()]=np.nan
for i in range(3):
    df.loc[:,['Index of best refractometry result (right)-0.0']+['Spherical power (right)-0.'+str(i)]+['Cylindrical power (right)-0.'+str(i)]+['Astigmatism angle (right)-0.'+str(i)]][df['Refractometry result unreliable (right)-0.'+str(i)].notna()]=np.nan
for i in range(3):
    df.loc[:,['3mm asymmetry index (left)-0.'+str(i)]][df['3mm asymmetry index unreliable (left)-0.'+str(i)].notna()]=np.nan
    df.loc[:,['6mm asymmetry index (left)-0.'+str(i)]][df['6mm asymmetry index unreliable (left)-0.'+str(i)].notna()]=np.nan
    df.loc[:,['3mm asymmetry index (right)-0.'+str(i)]][df['3mm asymmetry index unreliable (right)-0.'+str(i)].notna()]=np.nan
    df.loc[:,['6mm asymmetry index (right)-0.'+str(i)]][df['6mm asymmetry index unreliable (right)-0.'+str(i)].notna()]=np.nan
    df.loc[:,['3mm regularity index (right)-0.'+str(i)]][df['3mm regularity index unreliable (right)-0.'+str(i)].notna()]=np.nan
    df.loc[:,['6mm regularity index (right)-0.'+str(i)]][df['6mm regularity index unreliable (right)-0.'+str(i)].notna()]=np.nan
    df.loc[:,['6mm regularity index (left)-0.'+str(i)]][df['6mm regularity index unreliable (left)-0.'+str(i)].notna()]=np.nan
    df.loc[:,['3mm regularity index (left)-0.'+str(i)]][df['3mm regularity index unreliable (left)-0.'+str(i)].notna()]=np.nan
df = df.drop(df.columns[[5,17,37,38,264,212,213,204,205]+[i for i in range(66,78)]+[i for i in range(269,281)]+[i for i in range(282,293)]], axis = 1)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(1)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(1,inplace=True)
df['Spherical power (right)-0.0']=df.loc[:,['Spherical power (right)-0.0','Spherical power (right)-0.1','Spherical power (right)-0.2']].T.mean().T
df['Spherical power (left)-0.0']=df.loc[:,['Spherical power (left)-0.0','Spherical power (left)-0.1','Spherical power (left)-0.2']].T.mean().T
df['Cylindrical power (left)-0.0']=df.loc[:,['Cylindrical power (left)-0.0','Cylindrical power (left)-0.1','Cylindrical power (left)-0.2']].T.mean().T
df['Cylindrical power (right)-0.0']=df.loc[:,['Cylindrical power (right)-0.0','Cylindrical power (right)-0.1','Cylindrical power (right)-0.2']].T.mean().T
df['Astigmatism angle (right)-0.0']=df.loc[:,['Astigmatism angle (right)-0.0','Astigmatism angle (right)-0.1','Astigmatism angle (right)-0.2']].T.mean().T
df['Astigmatism angle (left)-0.0']=df.loc[:,['Astigmatism angle (left)-0.0','Astigmatism angle (left)-0.1','Astigmatism angle (left)-0.2']].T.mean().T
df['3mm weak meridian (right)-0.0']=df.loc[:,['3mm weak meridian (right)-0.0','3mm weak meridian (right)-0.1','3mm weak meridian (right)-0.2']].T.mean().T
df['3mm weak meridian (left)-0.0']=df.loc[:,['3mm weak meridian (left)-0.0','3mm weak meridian (left)-0.1','3mm weak meridian (left)-0.2']].T.mean().T
df['6mm weak meridian (right)-0.0']=df.loc[:,['6mm weak meridian (right)-0.0','6mm weak meridian (right)-0.1','6mm weak meridian (right)-0.2']].T.mean().T
df['6mm weak meridian (left)-0.0']=df.loc[:,['6mm weak meridian (left)-0.0','6mm weak meridian (left)-0.1','6mm weak meridian (left)-0.2']].T.mean().T
df['3mm strong meridian (right)-0.0']=df.loc[:,['3mm strong meridian (right)-0.0','3mm strong meridian (right)-0.1','3mm strong meridian (right)-0.2']].T.mean().T
df['3mm strong meridian (left)-0.0']=df.loc[:,['3mm strong meridian (left)-0.0','3mm strong meridian (left)-0.1','3mm strong meridian (left)-0.2']].T.mean().T
df['6mm strong meridian (right)-0.0']=df.loc[:,['6mm strong meridian (right)-0.0','6mm strong meridian (right)-0.1','6mm strong meridian (right)-0.2']].T.mean().T
df['6mm strong meridian (left)-0.0']=df.loc[:,['6mm strong meridian (left)-0.0','6mm strong meridian (left)-0.1','6mm strong meridian (left)-0.2']].T.mean().T
df['3mm cylindrical power (right)-0.0']=df.loc[:,['3mm cylindrical power (right)-0.0','3mm cylindrical power (right)-0.1','3mm cylindrical power (right)-0.2']].T.mean().T
df['3mm cylindrical power (left)-0.0']=df.loc[:,['3mm cylindrical power (left)-0.0','3mm cylindrical power (left)-0.1','3mm cylindrical power (left)-0.2']].T.mean().T
df['6mm cylindrical power (right)-0.0']=df.loc[:,['6mm cylindrical power (right)-0.0','6mm cylindrical power (right)-0.1','6mm cylindrical power (right)-0.2']].T.mean().T
df['6mm cylindrical power (left)-0.0']=df.loc[:,['6mm cylindrical power (left)-0.0','6mm cylindrical power (left)-0.1','6mm cylindrical power (left)-0.2']].T.mean().T
df['6mm asymmetry index (right)-0.0']=df.loc[:,['6mm asymmetry index (right)-0.0','6mm asymmetry index (right)-0.1','6mm asymmetry index (right)-0.2']].T.mean().T
df['6mm asymmetry index (left)-0.0']=df.loc[:,['6mm asymmetry index (left)-0.0','6mm asymmetry index (left)-0.1','6mm asymmetry index (left)-0.2']].T.mean().T
#correction of imputation illegibility
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(5)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(5,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(1)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(1,inplace=True)
df['Final number of letters displayed (right)-0.0'].fillna(5,inplace=True)
df['Distance of viewer to screen (right)-0.0'].fillna(4,inplace=True)
df['Direct or mirror view (right)-0.0'].fillna(0,inplace=True)
df['Distance of viewer to screen (left)-0.0'].fillna(4,inplace=True)
df['Direct or mirror view (left)-0.0'].fillna(0,inplace=True)
#correction of imputation illegibility and remove of high correlation variables
var=[1,2,3,4,19,23,24,27,28,35,36,37,50,51,52,53,58,59,61,73,75,77,78,79,81,84,85,87,203,204,205,206,218,219,220,221,232,233,234,235,252,253,262,263,62,63,72,90,91,248,249,250,259,260,269,270]+[i for i in range(92,122)]+[i for i in range(139,182)]+[i for i in range(124,137)]+[i for i in range(182,198)]+[i for i in range(236,248)]+[i for i in range(222,226)]
df.iloc[:,var].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Food-24 hours
j=9
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('105010','When diet questionnaire completed')
    i=i.replace('100001','Food weight')
    i=i.replace('100002','Energy')
    i=i.replace('100003','Protein')
    i=i.replace('100004','Fat')
    i=i.replace('100005','Carbohydrate')
    i=i.replace('100006','Saturated fat')
    i=i.replace('100007','Polyunsaturated fat')
    i=i.replace('100008','Total sugars')
    i=i.replace('100009','Englyst dietary fibre')
    i=i.replace('100011','Iron')
    i=i.replace('100012','Vitamin B6')
    i=i.replace('100013','Vitamin B12')
    i=i.replace('100014','Folate')
    i=i.replace('100015','Vitamin C')
    i=i.replace('100016','Potassium')
    i=i.replace('100017','Magnesium')
    i=i.replace('100018','Retinol')
    i=i.replace('100019','Carotene')
    i=i.replace('100021','Vitamin D')
    i=i.replace('100022','Alcohol')
    i=i.replace('100023','Starch')
    i=i.replace('100024','Calcium')
    i=i.replace('100025','Vitamin E')
    i=i.replace('104900','Time spent doing vigorous physical activity')
    i=i.replace('104910','Time spent doing moderate physical activity')
    i=i.replace('104920','Time spent doing light physical activity')
    i=i.replace('34','Year of birth')
    d.append(i)
df.columns=d
df['When diet questionnaire completed-3.0']=df['When diet questionnaire completed-3.0'].str[:10]
df['Year of diet questionnaire completed-3.0']=df['When diet questionnaire completed-3.0'].str.split('-',expand=True)[0]
df['Age of diet questionnaire completed-3.0']=df['Year of diet questionnaire completed-3.0'].astype(int)-df['Year of birth-0.0']
del df['Year of diet questionnaire completed-3.0']
del df['Year of birth-0.0']
del df['When diet questionnaire completed-3.0']
del df['31-0.0']
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
        print(list(df)[i])
df['eid'].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['eid']
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Hearing
j=10
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('4230','Signal-to-noise-ratio (SNR) of triplet (left)')
    i=i.replace('4232','Triplet correct (left)')
    i=i.replace('4233','Mean signal-to-noise ratio (SNR), (left)')
    i=i.replace('4234','Time to press first digit (left)')
    i=i.replace('4235','Time to press last digit (left)')
    i=i.replace('4237','Time to press next (left)')
    i=i.replace('4239','Number of times clear was pressed (left)')
    i=i.replace('4241','Signal-to-noise-ratio (SNR) of triplet (right)')
    i=i.replace('4243','Triplet correct (right)')
    i=i.replace('4244','Mean signal-to-noise ratio (SNR), (right)')
    i=i.replace('4245','Time to press first digit (right)')
    i=i.replace('4246','Time to press last digit (right)')
    i=i.replace('4247','Time to press next (right)')
    i=i.replace('4249','Number of times clear was pressed (right)')
    i=i.replace('4268','Completion status (left)')
    i=i.replace('4269','Number of triplets attempted (left)')
    i=i.replace('4270','Volume level set by participant (left)')
    i=i.replace('4272','Duration of hearing test (left)')
    i=i.replace('4275','Completion status (right)')
    i=i.replace('4276','Number of triplets attempted (right)')
    i=i.replace('4277','Volume level set by participant (right)')
    i=i.replace('4279','Duration of hearing test (right)')
    i=i.replace('4849','Hearing test done')
    i=i.replace('20019','Speech-reception-threshold (SRT) estimate (left)')
    i=i.replace('20021','Speech-reception-threshold (SRT) estimate (right)')
    i=i.replace('21003','Age when attended assessment centre')
    d.append(i)
df.columns=d
df.iloc[:,[2,5,6,7]+[i for i in range(12,117)]][df['Completion status (left)-0.0']==-1]=np.nan
df.iloc[:,[3,9,10,11]+[i for i in range(117,222)]][df['Completion status (right)-0.0']==-1]=np.nan
df = df.drop(df.columns[[i for i in range(42,49)]+[i for i in range(147,154)]], axis = 1)
del df['Completion status (left)-0.0']
del df['Completion status (right)-0.0']
df.iloc[:,[2,3]+[i for i in range(10,25)]+[i for i in range(40,48)]+[i for i in range(108,123)]+[i for i in range(138,146)]][(df['Hearing test done-0.0']==0)|(df['Hearing test done-0.0']==11)]=-15
df.iloc[:,[i for i in range(25,40)]+[i for i in range(123,138)]][(df['Hearing test done-0.0']==0)|(df['Hearing test done-0.0']==11)]=0
df.iloc[:,[5,8]][(df['Hearing test done-0.0']==0)|(df['Hearing test done-0.0']==11)]=100
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(2)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(2,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(-2)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(-2,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(1)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(1,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(15)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(15,inplace=True)
#correction of imputation illegibility and remove of high correlation variables
var=[4,7,93,94,191,192]+[i for i in range(40,48)]+[i for i in range(138,146)]+[i for i in range(97,108)]+[i for i in range(195,207)]
df.iloc[:,var].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var+[1]))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Lifestyle
j=11
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('22039','MET minutes per week for vigorous activity')
    i=i.replace('22038','MET minutes per week for moderate activity')
    i=i.replace('22037','MET minutes per week for walking')
    i=i.replace('22036','Above moderate/vigorous/walking recommendation')
    i=i.replace('22035','Above moderate/vigorous recommendation')
    i=i.replace('22034','Summed minutes activity')
    i=i.replace('22033','Summed days activity')
    i=i.replace('22032','IPAQ activity group')
    i=i.replace('20116','Smoking status')
    i=i.replace('6164','Types of physical activity in last 4 weeks')
    i=i.replace('6162','Types of transport used (excluding work)')
    i=i.replace('6144','Never eat eggs, dairy, wheat, sugar')
    i=i.replace('5364','Average weekly intake of other alcoholic drinks')
    i=i.replace('4462','Average monthly intake of other alcoholic drinks')
    i=i.replace('4451','Average monthly fortified wine intake')
    i=i.replace('4440','Average monthly spirits intake')
    i=i.replace('4429','Average monthly beer plus cider intake')
    i=i.replace('4418','Average monthly champagne plus white wine intake')
    i=i.replace('4407','Average monthly red wine intake')
    i=i.replace('3731','Former alcohol drinker')
    i=i.replace('3680','Age when last ate meat')
    i=i.replace('3669','Lifetime number of same-sex sexual partners')
    i=i.replace('3647','Duration of other exercises')
    i=i.replace('3637','Frequency of other exercises in last 4 weeks')
    i=i.replace('2654','Non-butter spread type details')
    i=i.replace('2634','Duration of heavy DIY')
    i=i.replace('2624','Frequency of heavy DIY in last 4 weeks')
    i=i.replace('2237','Plays computer games')
    i=i.replace('2159','Ever had same-sex intercourse')
    i=i.replace('2149','Lifetime number of sexual partners')
    i=i.replace('2139','Age first had sexual intercourse')
    i=i.replace('1757','Facial ageing')
    i=i.replace('1608','Average weekly fortified wine intake')
    i=i.replace('1598','Average weekly spirits intake')
    i=i.replace('1588','Average weekly beer plus cider intake')
    i=i.replace('1578','Average weekly champagne plus white wine intake')
    i=i.replace('1568','Average weekly red wine intake')
    i=i.replace('1558','Alcohol intake frequency')
    i=i.replace('1548','Variation in diet')
    i=i.replace('1538','Major dietary changes in the last 5 years')
    i=i.replace('1528','Water intake')
    i=i.replace('1518','Hot drink temperature')
    i=i.replace('1508','Coffee type')
    i=i.replace('1488','Tea intake')
    i=i.replace('1478','Salt added to food')
    i=i.replace('1468','Cereal type')
    i=i.replace('1458','Cereal intake')
    i=i.replace('1448','Bread type')
    i=i.replace('1438','Bread intake')
    i=i.replace('1428','Spread type')
    i=i.replace('1418','Milk type used')
    i=i.replace('1408','Cheese intake')
    i=i.replace('1389','Pork intake')
    i=i.replace('1379','Lamb or mutton intake')
    i=i.replace('1369','Beef intake')
    i=i.replace('1359','Poultry intake')
    i=i.replace('1349','Processed meat intake')
    i=i.replace('1339','Non-oily fish intake')
    i=i.replace('1329','Oily fish intake')
    i=i.replace('1319','Dried fruit intake')
    i=i.replace('1309','Fresh fruit intake')
    i=i.replace('1299','Salad or raw vegetable intake')
    i=i.replace('1289','Cooked vegetable intake')
    i=i.replace('1279','Exposure to tobacco smoke outside home')
    i=i.replace('1269','Exposure to tobacco smoke at home')
    i=i.replace('1249','Past tobacco smoking')
    i=i.replace('1239','Current tobacco smoking')
    i=i.replace('1220','Daytime dozing / sleeping (narcolepsy)')
    i=i.replace('1210','Snoring')
    i=i.replace('1200','Sleeplessness or insomnia')
    i=i.replace('1190','Nap during day')
    i=i.replace('1180','Morning/evening person (chronotype)')
    i=i.replace('1170','Getting up in morning')
    i=i.replace('1160','Sleep duration')
    i=i.replace('1140','Difference in mobile phone use compared to two years previously')
    i=i.replace('1120','Weekly usage of mobile phone in last 3 months')
    i=i.replace('1110','Length of mobile phone use')
    i=i.replace('1100','Drive faster than motorway speed limit')
    i=i.replace('1090','Time spent driving')
    i=i.replace('1080','Time spent using computer')
    i=i.replace('1070','Time spent watching television (TV)')
    i=i.replace('1060','Time spent outdoors in winter')
    i=i.replace('1050','Time spend outdoors in summer')
    i=i.replace('1021','Duration of light DIY')
    i=i.replace('1011','Frequency of light DIY in last 4 weeks')
    i=i.replace('1001','Duration of strenuous sports')
    i=i.replace('991','Frequency of strenuous sports in last 4 weeks')
    i=i.replace('981','Duration walking for pleasure')
    i=i.replace('971','Frequency of walking for pleasure in last 4 weeks')
    i=i.replace('943','Frequency of stair climbing in last 4 weeks')
    i=i.replace('924','Usual walking pace')
    i=i.replace('914','Duration of vigorous activity')
    i=i.replace('904','Number of days/week of vigorous physical activity 10+ minutes')
    i=i.replace('894','Duration of moderate activity')
    i=i.replace('884','Number of days/week of moderate physical activity 10+ minutes')
    i=i.replace('874','Duration of walks')
    i=i.replace('864','Number of days/week walked 10+ minutes')
    d.append(i)
df.columns=d
df['Lifetime number of sexual partners-0.0'][df['Age first had sexual intercourse-0.0']==-2]=0
df['Lifetime number of same-sex sexual partners-0.0'][df['Ever had same-sex intercourse-0.0']==0]=0
df['Age first had sexual intercourse-0.0'][df['Age first had sexual intercourse-0.0']==-2]=80
df['Time spend outdoors in summer-0.0'][df['Time spend outdoors in summer-0.0']==-10]=0.5
df['Time spent outdoors in winter-0.0'][df['Time spent outdoors in winter-0.0']==-10]=0.5
df['Average monthly red wine intake-0.0']=df['Average monthly red wine intake-0.0']/4.3
df['Average monthly champagne plus white wine intake-0.0']=df['Average monthly champagne plus white wine intake-0.0']/4.3
df['Average monthly beer plus cider intake-0.0']=df['Average monthly beer plus cider intake-0.0']/4.3
df['Average monthly spirits intake-0.0']=df['Average monthly spirits intake-0.0']/4.3
df['Average monthly fortified wine intake-0.0']=df['Average monthly fortified wine intake-0.0']/4.3
df['Average monthly intake of other alcoholic drinks-0.0']=df['Average monthly intake of other alcoholic drinks-0.0']/4.3
df['Average weekly red wine intake-0.0'][df['Average monthly red wine intake-0.0'].notna()]=df['Average monthly red wine intake-0.0']
df['Average weekly champagne plus white wine intake-0.0'][df['Average monthly champagne plus white wine intake-0.0'].notna()]=df['Average monthly champagne plus white wine intake-0.0']
df['Average weekly beer plus cider intake-0.0'][df['Average monthly beer plus cider intake-0.0'].notna()]=df['Average monthly beer plus cider intake-0.0']
df['Average weekly spirits intake-0.0'][df['Average monthly spirits intake-0.0'].notna()]=df['Average monthly spirits intake-0.0']
df['Average weekly fortified wine intake-0.0'][df['Average monthly fortified wine intake-0.0'].notna()]=df['Average monthly fortified wine intake-0.0']
df['Average weekly intake of other alcoholic drinks-0.0'][df['Average monthly intake of other alcoholic drinks-0.0'].notna()]=df['Average monthly intake of other alcoholic drinks-0.0']
df['Former alcohol drinker-0.0'][(df['Alcohol intake frequency-0.0']==1)|(df['Alcohol intake frequency-0.0']==2)|(df['Alcohol intake frequency-0.0']==3)|(df['Alcohol intake frequency-0.0']==4)|(df['Alcohol intake frequency-0.0']==5)]=1
del df['Average monthly red wine intake-0.0']
del df['Average monthly champagne plus white wine intake-0.0']
del df['Average monthly beer plus cider intake-0.0']
del df['Average monthly spirits intake-0.0']
del df['Average monthly fortified wine intake-0.0']
del df['Average monthly intake of other alcoholic drinks-0.0']
df['Cooked vegetable intake-0.0'][df['Cooked vegetable intake-0.0']==-10]=0.5
df['Salad or raw vegetable intake-0.0'][df['Salad or raw vegetable intake-0.0']==-10]=0.5
df['Fresh fruit intake-0.0'][df['Fresh fruit intake-0.0']==-10]=0.5
df['Dried fruit intake-0.0'][df['Dried fruit intake-0.0']==-10]=0.5
df['Bread intake-0.0'][df['Bread intake-0.0']==-10]=0.5
df['Cereal intake-0.0'][df['Cereal intake-0.0']==-10]=0.5
df['Tea intake-0.0'][df['Tea intake-0.0']==-10]=0.5
df['Coffee type-0.0'][df['Coffee type-0.0']==-10]=0.5
df['Water intake-0.0'][df['Water intake-0.0']==-10]=0.5
df['Never eat eggs, dairy, wheat, sugar-0.0'][df['Never eat eggs, dairy, wheat, sugar-0.0']<0]=np.nan
df['Never eat eggs, dairy, wheat, sugar-0.1'][df['Never eat eggs, dairy, wheat, sugar-0.1']<0]=np.nan
df['Never eat eggs, dairy, wheat, sugar-0.2'][df['Never eat eggs, dairy, wheat, sugar-0.2']<0]=np.nan
df['Never eat eggs, dairy, wheat, sugar-0.3'][df['Never eat eggs, dairy, wheat, sugar-0.3']<0]=np.nan
df['Eggs or foods containing eggs-0.0']=np.nan
df['Dairy products-0.0']=np.nan
df['Wheat products-0.0']=np.nan
df['Sugar or foods/drinks containing sugar-0.0']=np.nan
df['Eggs or foods containing eggs-0.0'][((df['Never eat eggs, dairy, wheat, sugar-0.0']==5)|(df['Never eat eggs, dairy, wheat, sugar-0.0']!=1))&(df['Never eat eggs, dairy, wheat, sugar-0.0'].notna())]=0
df['Eggs or foods containing eggs-0.0'][df['Never eat eggs, dairy, wheat, sugar-0.0']==1]=1
df['Dairy products-0.0'][((df['Never eat eggs, dairy, wheat, sugar-0.0']==5)|(df['Never eat eggs, dairy, wheat, sugar-0.0']!=2)&(df['Never eat eggs, dairy, wheat, sugar-0.1']!=2))&(df['Never eat eggs, dairy, wheat, sugar-0.0'].notna())]=0
df['Dairy products-0.0'][(df['Never eat eggs, dairy, wheat, sugar-0.0']==2)|(df['Never eat eggs, dairy, wheat, sugar-0.1']==2)]=1
df['Wheat products-0.0'][((df['Never eat eggs, dairy, wheat, sugar-0.0']==5)|((df['Never eat eggs, dairy, wheat, sugar-0.0']!=3)&(df['Never eat eggs, dairy, wheat, sugar-0.1']!=3)&(df['Never eat eggs, dairy, wheat, sugar-0.2']!=3)))&(df['Never eat eggs, dairy, wheat, sugar-0.0'].notna())]=0
df['Wheat products-0.0'][(df['Never eat eggs, dairy, wheat, sugar-0.0']==3)|(df['Never eat eggs, dairy, wheat, sugar-0.1']==3)|(df['Never eat eggs, dairy, wheat, sugar-0.2']==3)]=1
df['Sugar or foods/drinks containing sugar-0.0'][((df['Never eat eggs, dairy, wheat, sugar-0.0']==5)|((df['Never eat eggs, dairy, wheat, sugar-0.0']!=4)&(df['Never eat eggs, dairy, wheat, sugar-0.1']!=4)&(df['Never eat eggs, dairy, wheat, sugar-0.2']!=4)&(df['Never eat eggs, dairy, wheat, sugar-0.3']!=4)))&(df['Never eat eggs, dairy, wheat, sugar-0.0'].notna())]=0
df['Sugar or foods/drinks containing sugar-0.0'][(df['Never eat eggs, dairy, wheat, sugar-0.0']==4)|(df['Never eat eggs, dairy, wheat, sugar-0.1']==4)|(df['Never eat eggs, dairy, wheat, sugar-0.2']==4)|(df['Never eat eggs, dairy, wheat, sugar-0.3']==4)]=1
df['Cheese intake-0.0'][df['Dairy products-0.0']==0]=0
df['Non-butter spread type details-0.0'][(df['Non-butter spread type details-0.0'].notna())&(df['Non-butter spread type details-0.0']!=2)]=df['Non-butter spread type details-0.0']-1
df['Spread type-0.0'][df['Spread type-0.0']==3]=df['Non-butter spread type details-0.0']
del df['Non-butter spread type details-0.0']
df['Current tobacco smoking-0.0'][df['Smoking status-0.0']==0]=0
df['Difference in mobile phone use compared to two years previously-0.0'][df['Length of mobile phone use-0.0']==0]=0
df['Weekly usage of mobile phone in last 3 months-0.0'][df['Length of mobile phone use-0.0']==0]=0
df['Types of physical activity in last 4 weeks-0.0'][df['Types of physical activity in last 4 weeks-0.0']==-3]=np.nan
df['Types of physical activity in last 4 weeks-0.1'][df['Types of physical activity in last 4 weeks-0.1']==-3]=np.nan
df['Types of physical activity in last 4 weeks-0.2'][df['Types of physical activity in last 4 weeks-0.2']==-3]=np.nan
df['Types of physical activity in last 4 weeks-0.3'][df['Types of physical activity in last 4 weeks-0.3']==-3]=np.nan
df['Types of physical activity in last 4 weeks-0.4'][df['Types of physical activity in last 4 weeks-0.4']==-3]=np.nan
df['Walking for pleasure-0.0']=np.nan
df['Other exercises-0.0']=np.nan
df['Strenuous sports-0.0']=np.nan
df['Light DIY-0.0']=np.nan
df['Heavy DIY-0.0']=np.nan
df['Walking for pleasure-0.0'][(((df['Types of physical activity in last 4 weeks-0.0']==-7)|(df['Types of physical activity in last 4 weeks-0.0']!=5))&(df['Types of physical activity in last 4 weeks-0.0'].notna()))&(df['Types of physical activity in last 4 weeks-0.0'].notna())]=0
df['Walking for pleasure-0.0'][df['Types of physical activity in last 4 weeks-0.0']==5]=1
df['Other exercises-0.0'][((df['Types of physical activity in last 4 weeks-0.0']==-7)|((df['Types of physical activity in last 4 weeks-0.0']!=6)&(df['Types of physical activity in last 4 weeks-0.1']!=6)&(df['Types of physical activity in last 4 weeks-0.2']!=6)))&(df['Types of physical activity in last 4 weeks-0.0'].notna())]=0
df['Other exercises-0.0'][(df['Types of physical activity in last 4 weeks-0.0']==6)|(df['Types of physical activity in last 4 weeks-0.1']==6)|(df['Types of physical activity in last 4 weeks-0.2']==6)]=1
df['Strenuous sports-0.0'][((df['Types of physical activity in last 4 weeks-0.0']==-7)|((df['Types of physical activity in last 4 weeks-0.0']!=7)&(df['Types of physical activity in last 4 weeks-0.1']!=7)))&(df['Types of physical activity in last 4 weeks-0.0'].notna())]=0
df['Strenuous sports-0.0'][(df['Types of physical activity in last 4 weeks-0.0']==7)|(df['Types of physical activity in last 4 weeks-0.1']==7)]=1
df['Light DIY-0.0'][((df['Types of physical activity in last 4 weeks-0.0']==-7)|((df['Types of physical activity in last 4 weeks-0.0']!=8)&(df['Types of physical activity in last 4 weeks-0.1']!=8)&(df['Types of physical activity in last 4 weeks-0.2']!=8)&(df['Types of physical activity in last 4 weeks-0.3']!=8)))&(df['Types of physical activity in last 4 weeks-0.0'].notna())]=0
df['Light DIY-0.0'][(df['Types of physical activity in last 4 weeks-0.0']==8)|(df['Types of physical activity in last 4 weeks-0.1']==8)|(df['Types of physical activity in last 4 weeks-0.2']==8)|(df['Types of physical activity in last 4 weeks-0.3']==8)]=1
df['Heavy DIY-0.0'][((df['Types of physical activity in last 4 weeks-0.0']==-7)|((df['Types of physical activity in last 4 weeks-0.0']!=9)&(df['Types of physical activity in last 4 weeks-0.1']!=9)&(df['Types of physical activity in last 4 weeks-0.2']!=9)&(df['Types of physical activity in last 4 weeks-0.3']!=9)))&(df['Types of physical activity in last 4 weeks-0.0'].notna())]=0
df['Heavy DIY-0.0'][(df['Types of physical activity in last 4 weeks-0.0']==9)|(df['Types of physical activity in last 4 weeks-0.1']==9)|(df['Types of physical activity in last 4 weeks-0.2']==9)|(df['Types of physical activity in last 4 weeks-0.3']==9)|(df['Types of physical activity in last 4 weeks-0.4']==9)]=1
df['Duration walking for pleasure-0.0'][df['Walking for pleasure-0.0']==0]=0
df['Duration of light DIY-0.0'][df['Light DIY-0.0']==0]=0
df['Duration of heavy DIY-0.0'][df['Heavy DIY-0.0']==0]=0
df['Duration of strenuous sports-0.0'][df['Strenuous sports-0.0']==0]=0
df['Duration of other exercises-0.0'][df['Other exercises-0.0']==0]=0
df['Frequency of walking for pleasure in last 4 weeks-0.0'][df['Walking for pleasure-0.0']==0]=0
df['Frequency of light DIY in last 4 weeks-0.0'][df['Light DIY-0.0']==0]=0
df['Frequency of heavy DIY in last 4 weeks-0.0'][df['Heavy DIY-0.0']==0]=0
df['Frequency of strenuous sports in last 4 weeks-0.0'][df['Strenuous sports-0.0']==0]=0
df['Frequency of other exercises in last 4 weeks-0.0'][df['Other exercises-0.0']==0]=0
df['Duration of moderate activity-0.0'][df['Number of days/week of moderate physical activity 10+ minutes-0.0']==0]=0
df['Duration of vigorous activity-0.0'][df['Number of days/week of vigorous physical activity 10+ minutes-0.0']==0]=0
df['Time spent driving-0.0'][df['Time spent driving-0.0']==-10]=0.5
df['Time spent using computer-0.0'][df['Time spent using computer-0.0']==-10]=0.5
df['Time spent watching television (TV)-0.0'][df['Time spent watching television (TV)-0.0']==-10]=0.5
df['Types of transport used (excluding work)-0.0'][df['Types of transport used (excluding work)-0.0']==-3]=np.nan
df['Types of transport used (excluding work)-0.1'][df['Types of transport used (excluding work)-0.1']==-3]=np.nan
df['Types of transport used (excluding work)-0.2'][df['Types of transport used (excluding work)-0.2']==-3]=np.nan
df['Types of transport used (excluding work)-0.3'][df['Types of transport used (excluding work)-0.3']==-3]=np.nan
df['Car or motor vehicle-0.0']=np.nan
df['Walk-0.0']=np.nan
df['Public transport-0.0']=np.nan
df['Cycle-0.0']=np.nan
df['Car or motor vehicle-0.0'][((df['Types of transport used (excluding work)-0.0']==-7)|(df['Types of transport used (excluding work)-0.0']!=1))&(df['Types of transport used (excluding work)-0.0'].notna())]=0
df['Car or motor vehicle-0.0'][df['Types of transport used (excluding work)-0.0']==1]=1
df['Walk-0.0'][((df['Types of transport used (excluding work)-0.0']==-7)|(df['Types of transport used (excluding work)-0.0']!=2)&(df['Types of transport used (excluding work)-0.1']!=2))&(df['Types of transport used (excluding work)-0.0'].notna())]=0
df['Walk-0.0'][(df['Types of transport used (excluding work)-0.0']==2)|(df['Types of transport used (excluding work)-0.1']==2)]=1
df['Public transport-0.0'][((df['Types of transport used (excluding work)-0.0']==-7)|((df['Types of transport used (excluding work)-0.0']!=3)&(df['Types of transport used (excluding work)-0.1']!=3)&(df['Types of transport used (excluding work)-0.2']!=3)))&(df['Types of transport used (excluding work)-0.0'].notna())]=0
df['Public transport-0.0'][(df['Types of transport used (excluding work)-0.0']==3)|(df['Types of transport used (excluding work)-0.1']==3)|(df['Types of transport used (excluding work)-0.2']==3)]=1
df['Cycle-0.0'][((df['Types of transport used (excluding work)-0.0']==-7)|((df['Types of transport used (excluding work)-0.0']!=4)&(df['Types of transport used (excluding work)-0.1']!=4)&(df['Types of transport used (excluding work)-0.2']!=4)&(df['Types of transport used (excluding work)-0.3']!=4)))&(df['Types of transport used (excluding work)-0.0'].notna())]=0
df['Cycle-0.0'][(df['Types of transport used (excluding work)-0.0']==4)|(df['Types of transport used (excluding work)-0.1']==4)|(df['Types of transport used (excluding work)-0.2']==4)|(df['Types of transport used (excluding work)-0.3']==4)]=1
df[df<0]=np.nan
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(1)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(1,inplace=True)
del df['Never eat eggs, dairy, wheat, sugar-0.0']
del df['Never eat eggs, dairy, wheat, sugar-0.1']
del df['Never eat eggs, dairy, wheat, sugar-0.2']
del df['Never eat eggs, dairy, wheat, sugar-0.3']
del df['Types of transport used (excluding work)-0.0']
del df['Types of transport used (excluding work)-0.1']
del df['Types of transport used (excluding work)-0.2']
del df['Types of transport used (excluding work)-0.3']
del df['Types of physical activity in last 4 weeks-0.0']
del df['Types of physical activity in last 4 weeks-0.1']
del df['Types of physical activity in last 4 weeks-0.2']
del df['Types of physical activity in last 4 weeks-0.3']
del df['Types of physical activity in last 4 weeks-0.4']
#correction of imputation illegibility and remove of high correlation variables
var=[2,9,17,18,27,28,29,30,31,88,47,60,79,89,90,91,101]+[i for i in range(11,16)]+[i for i in range(93,98)]
df.iloc[:,var].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var+[16]))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Physical activity
j=12
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('90012','Overall acceleration average')
    i=i.replace('90013','Standard deviation of acceleration')
    i=i.replace('90019','Monday average acceleration')
    i=i.replace('90020','Tuesday average acceleration')
    i=i.replace('90021','Wednesday average acceleration')
    i=i.replace('90022','Thursday average acceleration')
    i=i.replace('90023','Friday average acceleration')
    i=i.replace('90024','Saturday average acceleration')
    i=i.replace('90025','Sunday average acceleration')
    i=i.replace('90027','Average acceleration 00:00 - 00:59')
    i=i.replace('90028','Average acceleration 01:00 - 01:59')
    i=i.replace('90029','Average acceleration 02:00 - 02:59')
    i=i.replace('90030','Average acceleration 03:00 - 03:59')
    i=i.replace('90031','Average acceleration 04:00 - 04:59')
    i=i.replace('90032','Average acceleration 05:00 - 05:59')
    i=i.replace('90033','Average acceleration 06:00 - 06:59')
    i=i.replace('90034','Average acceleration 07:00 - 07:59')
    i=i.replace('90035','Average acceleration 08:00 - 08:59')
    i=i.replace('90036','Average acceleration 09:00 - 09:59')
    i=i.replace('90037','Average acceleration 10:00 - 10:59')
    i=i.replace('90038','Average acceleration 11:00 - 11:59')
    i=i.replace('90039','Average acceleration 12:00 - 12:59')
    i=i.replace('90040','Average acceleration 13:00 - 13:59')
    i=i.replace('90041','Average acceleration 14:00 - 14:59')
    i=i.replace('90042','Average acceleration 15:00 - 15:59')
    i=i.replace('90043','Average acceleration 16:00 - 16:59')
    i=i.replace('90044','Average acceleration 17:00 - 17:59')
    i=i.replace('90045','Average acceleration 18:00 - 18:59')
    i=i.replace('90046','Average acceleration 19:00 - 19:59')
    i=i.replace('90047','Average acceleration 20:00 - 20:59')
    i=i.replace('90048','Average acceleration 21:00 - 21:59')
    i=i.replace('90049','Average acceleration 22:00 - 22:59')
    i=i.replace('90050','Average acceleration 23:00 - 23:59')
    i=i.replace('90087','No-wear time bias adjusted average acceleration')
    i=i.replace('90088','No-wear time bias adjusted acceleration standard deviation')
    i=i.replace('90089','No-wear time bias adjusted acceleration median')
    i=i.replace('90090','No-wear time bias adjusted acceleration minimum')
    i=i.replace('90091','No-wear time bias adjusted acceleration maximum')
    i=i.replace('110006','Invitation to physical activity study, date sent')
    i=i.replace('34-','Year of birth-')
    d.append(i)
df.columns=d
df=df[df['Invitation to physical activity study, date sent-0.0'].notna()]
df['Year of invitation to physical activity study-0.0']=df['Invitation to physical activity study, date sent-0.0'].str.split('-',expand=True)[0]
df['Age of physical activity study-0.0']=df['Year of invitation to physical activity study-0.0'].astype(int)-df['Year of birth-0.0']
del df['Year of birth-0.0']
del df['Year of invitation to physical activity study-0.0']
del df['Invitation to physical activity study, date sent-0.0']
del df['31-0.0']
df=df.set_index('eid')
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-all.csv')
df[['No-wear time bias adjusted average acceleration-0.0','No-wear time bias adjusted acceleration standard deviation-0.0','No-wear time bias adjusted acceleration median-0.0','No-wear time bias adjusted acceleration maximum-0.0','Age of physical activity study-0.0']].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-final-important.csv')

# %%
#Cleaning-Male-specific factors
j=13
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('2375','Relative age of first facial hair')
    i=i.replace('2385','Relative age voice broke')
    i=i.replace('2395','Hair/balding pattern')
    i=i.replace('2405','Number of children fathered')
    i=i.replace('21003','Age when attended assessment centre')
    d.append(i)
df.columns=d
df[df<0]=np.nan
df['eid'].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['eid']
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Mental-web-based questionnaire
j=14
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('20400','Date of completing mental health questionnaire')
    i=i.replace('20401','Ever addicted to any substance or behaviour')
    i=i.replace('20403','Amount of alcohol drunk on a typical drinking day')
    i=i.replace('20404','Ever physically dependent on alcohol')
    i=i.replace('20405','Ever had known person concerned about, or recommend reduction of, alcohol consumption')
    i=i.replace('20406','Ever addicted to alcohol')
    i=i.replace('20407','Frequency of failure to fulfil normal expectations due to drinking alcohol in last year')
    i=i.replace('20408','Frequency of memory loss due to drinking alcohol in last year')
    i=i.replace('20409','Frequency of feeling guilt or remorse after drinking alcohol in last year')
    i=i.replace('20410','Age when known person last commented about drinking habits')
    i=i.replace('20411','Ever been injured or injured someone else through drinking alcohol')
    i=i.replace('20412','Frequency of needing morning drink of alcohol after heavy drinking session in last year')
    i=i.replace('20414','Frequency of drinking alcohol')
    i=i.replace('20415','Ongoing addiction to alcohol')
    i=i.replace('20416','Frequency of consuming six or more units of alcohol')
    i=i.replace('20417','Tense, sore, or aching muscles during worst period of anxiety')
    i=i.replace('20418','Impact on normal roles during worst period of anxiety')
    i=i.replace('20419','Difficulty concentrating during worst period of anxiety')
    i=i.replace('20420','Longest period spent worried or anxious')
    i=i.replace('20421','Ever felt worried, tense, or anxious for most of a month or longer')
    i=i.replace('20422','More irritable than usual during worst period of anxiety')
    i=i.replace('20423','Keyed up or on edge during worst period of anxiety')
    i=i.replace('20425','Ever worried more than most people would in similar situation')
    i=i.replace('20426','Restless during period of worst anxiety')
    i=i.replace('20427','Frequent trouble falling or staying asleep during worst period of anxiety')
    i=i.replace('20428','Professional informed about anxiety')
    i=i.replace('20429','Easily tired during worst period of anxiety')
    i=i.replace('20431','Ever addicted to a behaviour or miscellanous')
    i=i.replace('20432','Ongoing behavioural or miscellanous addiction')
    i=i.replace('20433','Age at first episode of depression')
    i=i.replace('20434','Age at last episode of depression')
    i=i.replace('20435','Difficulty concentrating during worst depression')
    i=i.replace('20436','Fraction of day affected during worst episode of depression')
    i=i.replace('20437','Thoughts of death during worst depression')
    i=i.replace('20438','Duration of worst depression')
    i=i.replace('20439','Frequency of depressed days during worst episode of depression')
    i=i.replace('20440','Impact on normal roles during worst period of depression')
    i=i.replace('20441','Ever had prolonged loss of interest in normal activities')
    i=i.replace('20442','Lifetime number of depressed periods')
    i=i.replace('20445','Depression possibly related to childbirth')
    i=i.replace('20446','Ever had prolonged feelings of sadness or depression')
    i=i.replace('20447','Depression possibly related to stressful or traumatic event')
    i=i.replace('20448','Professional informed about depression')
    i=i.replace('20449','Feelings of tiredness during worst episode of depression')
    i=i.replace('20450','Feelings of worthlessness during worst period of depression')
    i=i.replace('20453','Ever taken cannabis')
    i=i.replace('20454','Maximum frequency of taking cannabis')
    i=i.replace('20455','Age when last took cannabis')
    i=i.replace('20456','Ever addicted to illicit or recreational drugs')
    i=i.replace('20457','Ongoing addiction or dependence on illicit or recreational drugs')
    i=i.replace('20458','General happiness')
    i=i.replace('20459','General happiness with own health')
    i=i.replace('20460','Belief that own life is meaningful')
    i=i.replace('20463','Ever heard an un-real voice')
    i=i.replace('20465','Number of times heard an un-real voice')
    i=i.replace('20466','Ever prescribed a medication for unusual or psychotic experiences')
    i=i.replace('20467','Frequency of unusual or psychotic experiences in past year')
    i=i.replace('20468','Ever believed in an un-real conspiracy against self')
    i=i.replace('20470','Number of times believed in an un-real conspiracy against self')
    i=i.replace('20471','Ever seen an un-real vision')
    i=i.replace('20473','Number of times seen an un-real vision')
    i=i.replace('20474','Ever believed in un-real communications or signs')
    i=i.replace('20476','Number of times believed in un-real communications or signs')
    i=i.replace('20477','Ever talked to a health professional about unusual or psychotic experiences')
    i=i.replace('20479','Ever thought that life not worth living')
    i=i.replace('20480','Ever self-harmed')
    i=i.replace('20481','Self-harmed in past year')
    i=i.replace('20482','Number of times self-harmed')
    i=i.replace('20483','Ever attempted suicide')
    i=i.replace('20484','Attempted suicide in past year')
    i=i.replace('20485','Ever contemplated self-harm')
    i=i.replace('20486','Contemplated self-harm in past year')
    i=i.replace('20487','Felt hated by family member as a child')
    i=i.replace('20488','Physically abused by family as a child')
    i=i.replace('20489','Felt loved as a child')
    i=i.replace('20490','Sexually molested as a child')
    i=i.replace('20491','Someone to take to doctor when needed as a child')
    i=i.replace('20492','Longest period of mania or irritability')
    i=i.replace('20493','Severity of problems due to mania or irritability')
    i=i.replace('20494','Felt irritable or had angry outbursts in past month')
    i=i.replace('20495','Avoided activities or situations because of previous stressful experience in past month')
    i=i.replace('20496','Felt distant from other people in past month')
    i=i.replace('20497','Repeated disturbing thoughts of stressful experience in past month')
    i=i.replace('20498','Felt very upset when reminded of stressful experience in past month')
    i=i.replace('20499','Ever sought or received professional help for mental distress')
    i=i.replace('20500','Ever suffered mental distress preventing usual activities')
    i=i.replace('20501','Ever had period of mania / excitability')
    i=i.replace('20502','Ever had period extreme irritability')
    i=i.replace('20505','Recent easy annoyance or irritability')
    i=i.replace('20506','Recent feelings or nervousness or anxiety')
    i=i.replace('20507','Recent feelings of inadequacy')
    i=i.replace('20508','Recent trouble concentrating on things')
    i=i.replace('20509','Recent inability to stop or control worrying')
    i=i.replace('20510','Recent feelings of depression')
    i=i.replace('20511','Recent poor appetite or overeating')
    i=i.replace('20512','Recent feelings of foreboding')
    i=i.replace('20513','Recent thoughts of suicide or self-harm')
    i=i.replace('20514','Recent lack of interest or pleasure in doing things')
    i=i.replace('20515','Recent trouble relaxing')
    i=i.replace('20516','Recent restlessness')
    i=i.replace('20517','Trouble falling or staying asleep, or sleeping too much')
    i=i.replace('20518','Recent changes in speed/amount of moving or speaking')
    i=i.replace('20519','Recent feelings of tiredness or low energy')
    i=i.replace('20520','Recent worrying too much about different things')
    i=i.replace('20521','Belittlement by partner or ex-partner as an adult')
    i=i.replace('20522','Been in a confiding relationship as an adult')
    i=i.replace('20523','Physical violence by partner or ex-partner as an adult')
    i=i.replace('20524','Sexual interference by partner or ex-partner without consent as an adult')
    i=i.replace('20525','Able to pay rent/mortgage as an adult')
    i=i.replace('20526','Been in serious accident believed to be life-threatening')
    i=i.replace('20527','Been involved in combat or exposed to war-zone')
    i=i.replace('20528','Diagnosed with life-threatening illness')
    i=i.replace('20529','Victim of physically violent crime')
    i=i.replace('20530','Witnessed sudden violent death')
    i=i.replace('20531','Victim of sexual assault')
    i=i.replace('20532','Did your sleep change?')
    i=i.replace('20533','Trouble falling asleep')
    i=i.replace('20534','Sleeping too much')
    i=i.replace('20535','Waking too early')
    i=i.replace('20536','Weight change during worst episode of depression')
    i=i.replace('20537','Frequency of difficulty controlling worry during worst period of anxiety')
    i=i.replace('20538','Worried most days during period of worst anxiety')
    i=i.replace('20539','Frequency of inability to stop worrying during worst period of anxiety')
    i=i.replace('20540','Multiple worries during worst period of anxiety')
    i=i.replace('20541','Difficulty stopping worrying during worst period of anxiety')
    i=i.replace('20542','Stronger worrying (than other people) during period of worst anxiety')
    i=i.replace('20543','Number of things worried about during worst period of anxiety')
    i=i.replace('20544','Mental health problems ever diagnosed by a professional')
    i=i.replace('20546','Substances taken for depression')
    i=i.replace('20547','Activities undertaken to treat depression')
    i=i.replace('20548','Manifestations of mania or irritability')
    i=i.replace('20549','Substances taken for anxiety')
    i=i.replace('20550','Activities undertaken to treat anxiety')
    i=i.replace('20551','Substance of prescription or over-the-counter medication addiction')
    i=i.replace('20553','Methods of self-harm used')
    i=i.replace('20554','Actions taken following self-harm')
    i=i.replace('20400','Date of completing mental health questionnaire')
    i=i.replace('34-','Year of birth-')
    d.append(i)
df.columns=d
df['Year of completing mental health questionnaire-0.0']=df['Date of completing mental health questionnaire-0.0'].str.split('-',expand=True)[0]
df['Age of completing mental health questionnaire-0.0']=df['Year of completing mental health questionnaire-0.0'].astype(int)-df['Year of birth-0.0']
del df['Year of birth-0.0']
del df['Year of completing mental health questionnaire-0.0']
del df['Date of completing mental health questionnaire-0.0']
del df['31-0.0']
df['Amount of alcohol drunk on a typical drinking day-0.0'][df['Frequency of drinking alcohol-0.0']==0]=0
df['Frequency of failure to fulfil normal expectations due to drinking alcohol in last year-0.0'][df['Frequency of drinking alcohol-0.0']==0]=0
df['Frequency of memory loss due to drinking alcohol in last year-0.0'][df['Frequency of drinking alcohol-0.0']==0]=0
df['Frequency of feeling guilt or remorse after drinking alcohol in last year-0.0'][df['Frequency of drinking alcohol-0.0']==0]=0
df['Frequency of needing morning drink of alcohol after heavy drinking session in last year-0.0'][df['Frequency of drinking alcohol-0.0']==0]=0
df['Frequency of consuming six or more units of alcohol-0.0'][df['Frequency of drinking alcohol-0.0']==0]=0
df['Age when known person last commented about drinking habits-0.0'][df['Ever had known person concerned about, or recommend reduction of, alcohol consumption-0.0']==0]=0
df['Longest period spent worried or anxious-0.0'][df['Longest period spent worried or anxious-0.0']==-999]=1000
df['Sum of substance taken for anxiety']=np.nan
df['Sum of activities taken for anxiety']=np.nan
df['Sum of substance taken for anxiety'][df['Number of things worried about during worst period of anxiety-0.0'].notna()]=0
df['Sum of activities taken for anxiety'][df['Number of things worried about during worst period of anxiety-0.0'].notna()]=0
df['Sum of substance taken for anxiety'][df['Substances taken for anxiety-0.1']==-818]=np.nan
df['Sum of activities taken for anxiety'][df['Activities undertaken to treat anxiety-0.1']==-818]=np.nan
df['Sum of substance taken for anxiety'][(df['Substances taken for anxiety-0.1'].notna())&(df['Sum of substance taken for anxiety'].notna())]=(df.iloc[:,[21,22,23]].notna()).T.sum()
df['Sum of activities taken for anxiety'][(df['Activities undertaken to treat anxiety-0.1'].notna())&(df['Sum of activities taken for anxiety'].notna())]=(df.iloc[:,[24,25]].notna()).T.sum()
df['Longest period spent worried or anxious-0.0'][df['Ever felt worried, tense, or anxious for most of a month or longer-0.0']==0]=0
df['Worried most days during period of worst anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Tense, sore, or aching muscles during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Stronger worrying (than other people) during period of worst anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Professional informed about anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Restless during period of worst anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Difficulty concentrating during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Keyed up or on edge during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Difficulty stopping worrying during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Easily tired during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Frequency of difficulty controlling worry during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Frequency of inability to stop worrying during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Frequent trouble falling or staying asleep during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Impact on normal roles during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Number of things worried about during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['More irritable than usual during worst period of anxiety-0.0'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Sum of substance taken for anxiety'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
df['Sum of activities taken for anxiety'][(df['Longest period spent worried or anxious-0.0']==0)&(df['Ever worried more than most people would in similar situation-0.0']==0)]=0
del df['Substances taken for anxiety-0.1']
del df['Substances taken for anxiety-0.2']
del df['Substances taken for anxiety-0.3']
del df['Activities undertaken to treat anxiety-0.1']
del df['Activities undertaken to treat anxiety-0.2']
df['Maximum frequency of taking cannabis-0.0'][df['Ever taken cannabis-0.0']==0]=0
df['Age when last took cannabis-0.0'][df['Ever taken cannabis-0.0']==0]=0
df['Sum of substance taken for depression']=np.nan
df['Sum of activities taken for depression']=np.nan
df['Sum of substance taken for depression'][df['Feelings of worthlessness during worst period of depression-0.0'].notna()]=0
df['Sum of activities taken for depression'][df['Feelings of worthlessness during worst period of depression-0.0'].notna()]=0
df['Sum of substance taken for depression'][df['Substances taken for depression-0.1']==-818]=np.nan
df['Sum of activities taken for depression'][df['Activities undertaken to treat depression-0.1']==-818]=np.nan
df['Sum of substance taken for depression'][(df['Substances taken for depression-0.1'].notna())&(df['Sum of substance taken for depression'].notna())]=(df.iloc[:,[30,31,32]].notna()).T.sum()
df['Sum of activities taken for depression'][(df['Activities undertaken to treat depression-0.1'].notna())&(df['Sum of activities taken for depression'].notna())]=(df.iloc[:,[33,34]].notna()).T.sum()
df['Age at first episode of depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Age at last episode of depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Depression possibly related to childbirth-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Depression possibly related to stressful or traumatic event-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Difficulty concentrating during worst depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Fraction of day affected during worst episode of depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Thoughts of death during worst depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Duration of worst depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Frequency of depressed days during worst episode of depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Impact on normal roles during worst period of depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Lifetime number of depressed periods-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Depression possibly related to childbirth-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Professional informed about depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Feelings of tiredness during worst episode of depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Feelings of worthlessness during worst period of depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Did your sleep change?-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Weight change during worst episode of depression-0.0'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Sum of substance taken for depression'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Sum of activities taken for depression'][(df['Ever had prolonged loss of interest in normal activities-0.0']==0)&(df['Ever had prolonged feelings of sadness or depression-0.0']==0)]=0
df['Trouble falling asleep-0.0'][df['Did your sleep change?-0.0']==0]=0
df['Sleeping too much-0.0'][df['Did your sleep change?-0.0']==0]=0
df['Waking too early-0.0'][df['Did your sleep change?-0.0']==0]=0
del df['Substances taken for depression-0.1']
del df['Substances taken for depression-0.2']
del df['Substances taken for depression-0.3']
del df['Activities undertaken to treat depression-0.1']
del df['Activities undertaken to treat depression-0.2']
df['Sum of manifestations of mania or irritability']=np.nan
df['Sum of manifestations of mania or irritability'][df['Manifestations of mania or irritability-0.1'].notna()]=0
df['Sum of manifestations of mania or irritability'][df['Manifestations of mania or irritability-0.1']==-818]=np.nan
df['Sum of manifestations of mania or irritability'][(df['Manifestations of mania or irritability-0.1'].notna())&(df['Sum of manifestations of mania or irritability'].notna())]=(df.loc[:,['Manifestations of mania or irritability-0.1','Manifestations of mania or irritability-0.2','Manifestations of mania or irritability-0.3','Manifestations of mania or irritability-0.4','Manifestations of mania or irritability-0.5','Manifestations of mania or irritability-0.6','Manifestations of mania or irritability-0.7','Manifestations of mania or irritability-0.8']].notna()).T.sum()
df['Sum of manifestations of mania or irritability'][(df['Ever had period of mania / excitability-0.0']==0)&(df['Ever had period extreme irritability-0.0']==0)]=0
df['Longest period of mania or irritability-0.0'][(df['Ever had period of mania / excitability-0.0']==0)&(df['Ever had period extreme irritability-0.0']==0)]=0
df['Severity of problems due to mania or irritability-0.0'][(df['Ever had period of mania / excitability-0.0']==0)&(df['Ever had period extreme irritability-0.0']==0)]=0
df['Severity of problems due to mania or irritability-0.0'].fillna(0,inplace=True)
df['Ever had period of mania / excitability-0.0'].fillna(0,inplace=True)
del df['Manifestations of mania or irritability-0.1']
del df['Manifestations of mania or irritability-0.2']
del df['Manifestations of mania or irritability-0.3']
del df['Manifestations of mania or irritability-0.4']
del df['Manifestations of mania or irritability-0.5']
del df['Manifestations of mania or irritability-0.6']
del df['Manifestations of mania or irritability-0.7']
del df['Manifestations of mania or irritability-0.8']
df['Sum of Mental health problems ever diagnosed by a professional']=(df.loc[:,['Mental health problems ever diagnosed by a professional-0.1','Mental health problems ever diagnosed by a professional-0.2','Mental health problems ever diagnosed by a professional-0.3','Mental health problems ever diagnosed by a professional-0.4','Mental health problems ever diagnosed by a professional-0.5','Mental health problems ever diagnosed by a professional-0.6','Mental health problems ever diagnosed by a professional-0.7','Mental health problems ever diagnosed by a professional-0.8','Mental health problems ever diagnosed by a professional-0.9','Mental health problems ever diagnosed by a professional-0.10','Mental health problems ever diagnosed by a professional-0.11','Mental health problems ever diagnosed by a professional-0.12','Mental health problems ever diagnosed by a professional-0.13','Mental health problems ever diagnosed by a professional-0.14','Mental health problems ever diagnosed by a professional-0.15','Mental health problems ever diagnosed by a professional-0.16']].notna()).T.sum()
df['Sum of Mental health problems ever diagnosed by a professional'].replace(0,np.nan,inplace=True)
df['Sum of Mental health problems ever diagnosed by a professional'][(df['Ever suffered mental distress preventing usual activities-0.0']==0)&(df['Ever sought or received professional help for mental distress-0.0']==0)&(df['Sum of Mental health problems ever diagnosed by a professional'].isna())]=0
del df['Mental health problems ever diagnosed by a professional-0.1']
del df['Mental health problems ever diagnosed by a professional-0.2']
del df['Mental health problems ever diagnosed by a professional-0.3']
del df['Mental health problems ever diagnosed by a professional-0.4']
del df['Mental health problems ever diagnosed by a professional-0.5']
del df['Mental health problems ever diagnosed by a professional-0.6']
del df['Mental health problems ever diagnosed by a professional-0.7']
del df['Mental health problems ever diagnosed by a professional-0.8']
del df['Mental health problems ever diagnosed by a professional-0.9']
del df['Mental health problems ever diagnosed by a professional-0.10']
del df['Mental health problems ever diagnosed by a professional-0.11']
del df['Mental health problems ever diagnosed by a professional-0.12']
del df['Mental health problems ever diagnosed by a professional-0.13']
del df['Mental health problems ever diagnosed by a professional-0.14']
del df['Mental health problems ever diagnosed by a professional-0.15']
del df['Mental health problems ever diagnosed by a professional-0.16']
df['whether taken actions after suicide-0.0']=np.nan
df['Sum of methods taken for self-harm-0.0']=np.nan
df['Sum of methods taken for self-harm-0.0'][(df['Methods of self-harm used-0.1'].notna())&(df['Sum of methods taken for self-harm-0.0'].isna())]=df.loc[:,['Methods of self-harm used-0.1','Methods of self-harm used-0.2','Methods of self-harm used-0.3','Methods of self-harm used-0.4','Methods of self-harm used-0.5','Methods of self-harm used-0.6']].notna().T.sum()
df['whether taken actions after suicide-0.0'][(df.loc[:,['Actions taken following self-harm-0.1','Actions taken following self-harm-0.2','Actions taken following self-harm-0.3','Actions taken following self-harm-0.4','Actions taken following self-harm-0.5']].notna()).T.sum()>0]=2
df['whether taken actions after suicide-0.0'][(df['Ever self-harmed-0.0']==1)&(df['whether taken actions after suicide-0.0'].isna())]=1
df['Ever attempted suicide-0.0'][df['Ever self-harmed-0.0']==0]=0
df['Number of times self-harmed-0.0'][df['Ever self-harmed-0.0']==0]=0
df['Self-harmed in past year-0.0'][df['Ever self-harmed-0.0']==0]=0
df['whether taken actions after suicide-0.0'][df['Ever self-harmed-0.0']==0]=0
df['Sum of methods taken for self-harm-0.0'][df['Ever self-harmed-0.0']==0]=0
df['Attempted suicide in past year-0.0'][df['Ever attempted suicide-0.0']==0]=0
df['Contemplated self-harm in past year-0.0'][df['Ever contemplated self-harm-0.0']==0]=0
del df['Actions taken following self-harm-0.1']
del df['Actions taken following self-harm-0.2']
del df['Actions taken following self-harm-0.3']
del df['Actions taken following self-harm-0.4']
del df['Actions taken following self-harm-0.5']
del df['Methods of self-harm used-0.1']
del df['Methods of self-harm used-0.2']
del df['Methods of self-harm used-0.3']
del df['Methods of self-harm used-0.4']
del df['Methods of self-harm used-0.5']
del df['Methods of self-harm used-0.6']
df['Felt irritable or had angry outbursts in past month-0.0'][(df['Felt very upset when reminded of stressful experience in past month-0.0']==0)&(df['Repeated disturbing thoughts of stressful experience in past month-0.0']==0)&(df['Avoided activities or situations because of previous stressful experience in past month-0.0']==0)]=0
df['Felt distant from other people in past month-0.0'][(df['Felt very upset when reminded of stressful experience in past month-0.0']==0)&(df['Repeated disturbing thoughts of stressful experience in past month-0.0']==0)&(df['Avoided activities or situations because of previous stressful experience in past month-0.0']==0)]=0
df['Number of times believed in an un-real conspiracy against self-0.0'][df['Ever believed in an un-real conspiracy against self-0.0']==0]=0
df['Number of times heard an un-real voice-0.0'][df['Ever heard an un-real voice-0.0']==0]=0
df['Number of times seen an un-real vision-0.0'][df['Ever seen an un-real vision-0.0']==0]=0
df['Number of times believed in un-real communications or signs-0.0'][df['Ever believed in un-real communications or signs-0.0']==0]=0
df['Ever talked to a health professional about unusual or psychotic experiences-0.0'][(df['Ever believed in an un-real conspiracy against self-0.0']==0)&(df['Ever believed in un-real communications or signs-0.0']==0)&(df['Ever seen an un-real vision-0.0']==0)&(df['Ever heard an un-real voice-0.0']==0)]=0
df['Frequency of unusual or psychotic experiences in past year-0.0'][(df['Ever believed in an un-real conspiracy against self-0.0']==0)&(df['Ever believed in un-real communications or signs-0.0']==0)&(df['Ever seen an un-real vision-0.0']==0)&(df['Ever heard an un-real voice-0.0']==0)]=0
df['Ever prescribed a medication for unusual or psychotic experiences-0.0'][(df['Ever believed in an un-real conspiracy against self-0.0']==0)&(df['Ever believed in un-real communications or signs-0.0']==0)&(df['Ever seen an un-real vision-0.0']==0)&(df['Ever heard an un-real voice-0.0']==0)]=0
df['Sum of Substance of prescription or over-the-counter medication addiction-0.0']=np.nan
df['Sum of Substance of prescription or over-the-counter medication addiction-0.0'][(df['Substance of prescription or over-the-counter medication addiction-0.1'].notna())]=(df.loc[:,['Substance of prescription or over-the-counter medication addiction-0.1','Substance of prescription or over-the-counter medication addiction-0.2','Substance of prescription or over-the-counter medication addiction-0.3']].notna()).T.sum()
df['Ever addicted to a behaviour or miscellanous-0.0'][df['Ever addicted to any substance or behaviour-0.0']==0]=0
df['Ever addicted to alcohol-0.0'][df['Ever addicted to any substance or behaviour-0.0']==0]=0
df['Ever addicted to illicit or recreational drugs-0.0'][df['Ever addicted to any substance or behaviour-0.0']==0]=0
df['Ongoing behavioural or miscellanous addiction-0.0'][df['Ever addicted to a behaviour or miscellanous-0.0']==0]=0
df['Ever physically dependent on alcohol-0.0'][df['Ever addicted to alcohol-0.0']==0]=0
df['Ongoing addiction to alcohol-0.0'][df['Ever addicted to alcohol-0.0']==0]=0
df['Ongoing addiction or dependence on illicit or recreational drugs-0.0'][df['Ever addicted to illicit or recreational drugs-0.0']==0]=0
df['Sum of Substance of prescription or over-the-counter medication addiction-0.0'][df['Ever addicted to illicit or recreational drugs-0.0']==0]=0
del df['Substance of prescription or over-the-counter medication addiction-0.1']
del df['Substance of prescription or over-the-counter medication addiction-0.2']
del df['Substance of prescription or over-the-counter medication addiction-0.3']
df[df<0]=np.nan
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(1)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(1,inplace=True)
#Correction of imputation illegibility
var=[0,1,3,4,5,9,10,13,27,28,39,48,49,70,74,77,85,95,100,106,108,109,126,134,135,136]+[i for i in range(53,63)]+[i for i in range(64,69)]
df.iloc[:,var].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Mental-assessment-center questionnaire
j=15
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age of attending assessment centre')
    i=i.replace('20122','Bipolar disorder status')
    i=i.replace('20123','Single episode of probable major depression')
    i=i.replace('20124','Probable recurrent major depression (moderate)')
    i=i.replace('20125','Probable recurrent major depression (severe)')
    i=i.replace('20126','Bipolar and major depression status')
    i=i.replace('20127','Neuroticism score')
    i=i.replace('1920','Mood swings')
    i=i.replace('1930','Miserableness')
    i=i.replace('1940','Irritability')
    i=i.replace('1950','Sensitivity / hurt feelings')
    i=i.replace('1960','Fed-up feelings')
    i=i.replace('1970','Nervous feelings')
    i=i.replace('1980','Worrier / anxious feelings')
    i=i.replace('1990','Tense / highly strung')
    i=i.replace('2000','Worry too long after embarrassment')
    i=i.replace('2010','Suffer from nerves')
    i=i.replace('2020','Loneliness, isolation')
    i=i.replace('2030','Guilty feelings')
    i=i.replace('2040','Risk taking')
    i=i.replace('2050','Frequency of depressed mood in last 2 weeks')
    i=i.replace('2060','Frequency of unenthusiasm / disinterest in last 2 weeks')
    i=i.replace('2070','Frequency of tenseness / restlessness in last 2 weeks')
    i=i.replace('2080','Frequency of tiredness / lethargy in last 2 weeks')
    i=i.replace('2090','Seen doctor (GP) for nerves, anxiety, tension or depression')
    i=i.replace('2100','Seen a psychiatrist for nerves, anxiety, tension or depression')
    i=i.replace('4598','Ever depressed for a whole week')
    i=i.replace('4609','Longest period of depression')
    i=i.replace('4620','Number of depression episodes')
    i=i.replace('4631','Ever unenthusiastic/disinterested for a whole week')
    i=i.replace('4642','Ever manic/hyper for 2 days')
    i=i.replace('4653','Ever highly irritable/argumentative for 2 days')
    i=i.replace('5375','Longest period of unenthusiasm / disinterest')
    i=i.replace('5386','Number of unenthusiastic/disinterested episodes')
    i=i.replace('5663','Length of longest manic/irritable episode')
    i=i.replace('5674','Severity of manic/irritable episodes')
    i=i.replace('6145','Illness, injury, bereavement, stress in last 2 years')
    i=i.replace('6156','Manic/hyper symptoms')
    d.append(i)
df.columns=d
df['Illness, injury, bereavement, stress in last 2 years-0.0'].replace(-7,0,inplace=True)
df['Illness, injury, bereavement, stress in last 2 years-0.1'].replace(-7,0,inplace=True)
df['Illness, injury, bereavement, stress in last 2 years-0.2'].replace(-7,0,inplace=True)
df['Illness, injury, bereavement, stress in last 2 years-0.3'].replace(-7,0,inplace=True)
df['Illness, injury, bereavement, stress in last 2 years-0.4'].replace(-7,0,inplace=True)
df['Illness, injury, bereavement, stress in last 2 years-0.5'].replace(-7,0,inplace=True)
df[df<0]=np.nan
df['Number of Manic/hyper symptoms-0.0']=np.nan
df['Number of Manic/hyper symptoms-0.0'][df['Manic/hyper symptoms-0.0']==0]=0
df['Number of Manic/hyper symptoms-0.0'][df['Manic/hyper symptoms-0.0']==15]=4
df['Number of Manic/hyper symptoms-0.0'][(df['Manic/hyper symptoms-0.0']!=0)&(df['Manic/hyper symptoms-0.0']!=15)&(df['Manic/hyper symptoms-0.0'].notna())]=(df.loc[:,['Manic/hyper symptoms-0.0','Manic/hyper symptoms-0.1','Manic/hyper symptoms-0.2','Manic/hyper symptoms-0.3']].notna()).T.sum()
df['Longest period of depression-0.0'][df['Ever depressed for a whole week-0.0']==0]=0
df['Number of depression episodes-0.0'][df['Ever depressed for a whole week-0.0']==0]=0
df['Longest period of unenthusiasm / disinterest-0.0'][df['Ever unenthusiastic/disinterested for a whole week-0.0']==0]=0
df['Number of unenthusiastic/disinterested episodes-0.0'][df['Ever unenthusiastic/disinterested for a whole week-0.0']==0]=0
df['Length of longest manic/irritable episode-0.0'][(df['Ever highly irritable/argumentative for 2 days-0.0']==0)&(df['Ever manic/hyper for 2 days-0.0']==0)]=0
df['Severity of manic/irritable episodes-0.0'][(df['Ever highly irritable/argumentative for 2 days-0.0']==0)&(df['Ever manic/hyper for 2 days-0.0']==0)]=11
df['Number of Manic/hyper symptoms-0.0'][(df['Ever highly irritable/argumentative for 2 days-0.0']==0)&(df['Ever manic/hyper for 2 days-0.0']==0)]=0
df['Neuroticism score-0.0'][(df['Neuroticism score-0.0'].isna())&(df['Mood swings-0.0'].notna())&(df['Miserableness-0.0'].notna())&(df['Irritability-0.0'].notna())&(df['Sensitivity / hurt feelings-0.0'].notna())&(df['Fed-up feelings-0.0'].notna())&(df['Worrier / anxious feelings-0.0'].notna())&(df['Tense / highly strung-0.0'].notna())&(df['Worry too long after embarrassment-0.0'].notna())&(df['Suffer from nerves-0.0'].notna())&(df['Loneliness, isolation-0.0'].notna())&(df['Guilty feelings-0.0'].notna())&(df['Nervous feelings-0.0'].notna())]=(df.loc[:,['Mood swings-0.0','Miserableness-0.0','Irritability-0.0','Sensitivity / hurt feelings-0.0','Fed-up feelings-0.0','Nervous feelings-0.0','Worrier / anxious feelings-0.0','Tense / highly strung-0.0','Worry too long after embarrassment-0.0','Suffer from nerves-0.0','Loneliness, isolation-0.0','Guilty feelings-0.0','Risk taking-0.0']]).T.sum()
df['Sum of illness, injury, bereavement, stress in last 2 years-0.0']=np.nan
df['Sum of illness, injury, bereavement, stress in last 2 years-0.0'][df['Illness, injury, bereavement, stress in last 2 years-0.0']==0]=0
df['Sum of illness, injury, bereavement, stress in last 2 years-0.0'][(df['Illness, injury, bereavement, stress in last 2 years-0.0']!=0)&(df['Illness, injury, bereavement, stress in last 2 years-0.0'].notna())]=(df.loc[:,['Illness, injury, bereavement, stress in last 2 years-0.0','Illness, injury, bereavement, stress in last 2 years-0.1','Illness, injury, bereavement, stress in last 2 years-0.2','Illness, injury, bereavement, stress in last 2 years-0.3','Illness, injury, bereavement, stress in last 2 years-0.4','Illness, injury, bereavement, stress in last 2 years-0.5']].notna()).T.sum()
df['Bipolar disorder status-0.0'][(df['Bipolar and major depression status-0.0'].notna())&(df['Bipolar disorder status-0.0'].isna())]=0
df['Single episode of probable major depression-0.0'][(df['Bipolar and major depression status-0.0'].notna())&(df['Single episode of probable major depression-0.0'].isna())]=0
df['Probable recurrent major depression (moderate)-0.0'][(df['Bipolar and major depression status-0.0'].notna())&(df['Probable recurrent major depression (moderate)-0.0'].isna())]=0
df['Probable recurrent major depression (severe)-0.0'][(df['Bipolar and major depression status-0.0'].notna())&(df['Probable recurrent major depression (severe)-0.0'].isna())]=0
df['Number of Manic/hyper symptoms-0.0'].fillna(0,inplace=True)
df['Severity of manic/irritable episodes-0.0'].fillna(11,inplace=True)
df['Bipolar disorder status-0.0'].fillna(0,inplace=True)
df['Single episode of probable major depression-0.0'].fillna(0,inplace=True)
df['Probable recurrent major depression (severe)-0.0'].fillna(0,inplace=True)
df['Ever manic/hyper for 2 days-0.0'].fillna(0,inplace=True)
del df['Illness, injury, bereavement, stress in last 2 years-0.0']
del df['Illness, injury, bereavement, stress in last 2 years-0.1']
del df['Illness, injury, bereavement, stress in last 2 years-0.2']
del df['Illness, injury, bereavement, stress in last 2 years-0.3']
del df['Illness, injury, bereavement, stress in last 2 years-0.4']
del df['Illness, injury, bereavement, stress in last 2 years-0.5']
del df['Manic/hyper symptoms-0.0']
del df['Manic/hyper symptoms-0.1']
del df['Manic/hyper symptoms-0.2']
del df['Manic/hyper symptoms-0.3']
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(10)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(10,inplace=True)
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(11)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(11,inplace=True)
df[['eid','Bipolar disorder status-0.0','Ever manic/hyper for 2 days-0.0','Number of Manic/hyper symptoms-0.0','Probable recurrent major depression (severe)-0.0','Severity of manic/irritable episodes-0.0','Single episode of probable major depression-0.0']].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
del df['eid']
del df['Single episode of probable major depression-0.0']
del df['Severity of manic/irritable episodes-0.0']
del df['Probable recurrent major depression (severe)-0.0']
del df['Number of Manic/hyper symptoms-0.0']
del df['Ever manic/hyper for 2 days-0.0']
del df['Bipolar disorder status-0.0']
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Sociodemographics
j=16
Country1='England'
Country2='Scotland'
if not os.path.exists(file_Pwd+'/'+Category_Name[j]+'/'+Country1):
        os.mkdir(file_Pwd+'/'+Category_Name[j]+'/'+Country1)
if not os.path.exists(file_Pwd+'/'+Category_Name[j]+'/'+Country2):
        os.mkdir(file_Pwd+'/'+Category_Name[j]+'/'+Country2)
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('26434','Crime score (Scotland)')
    i=i.replace('26433','Access to services score (Scotland)')
    i=i.replace('26432','Housing score (Scotland)')
    i=i.replace('26431','Education score (Scotland)')
    i=i.replace('26430','Health score (Scotland)')
    i=i.replace('26428','Income score (Scotland)')
    i=i.replace('26427','Index of Multiple Deprivation (Scotland)')
    i=i.replace('26417','Living environment score (England)')
    i=i.replace('26416','Crime score (England)')
    i=i.replace('26415','Housing score (England)')
    i=i.replace('26414','Education score (England)')
    i=i.replace('26413','Health score (England)')
    i=i.replace('26412','Employment score (England)')
    i=i.replace('26411','Income score (England)')
    i=i.replace('26410','Index of Multiple Deprivation (England)')
    i=i.replace('24508','Distance (Euclidean) to coast')
    i=i.replace('24507','Natural environment percentage, buffer 300m')
    i=i.replace('24506','Natural environment percentage, buffer 1000m')
    i=i.replace('24505','Water percentage, buffer 300m')
    i=i.replace('24504','Domestic garden percentage, buffer 300m')
    i=i.replace('24503','Greenspace percentage, buffer 300m')
    i=i.replace('24502','Water percentage, buffer 1000m')
    i=i.replace('24501','Domestic garden percentage, buffer 1000m')
    i=i.replace('24500','Greenspace percentage, buffer 1000m')
    i=i.replace('24022','Average night-time sound level of noise pollution')
    i=i.replace('24021','Average evening sound level of noise pollution')
    i=i.replace('24020','Average daytime sound level of noise pollution')
    i=i.replace('24019','Particulate matter air pollution (pm10); 2007')
    i=i.replace('24018','Nitrogen dioxide air pollution; 2007')
    i=i.replace('24017','Nitrogen dioxide air pollution; 2006')
    i=i.replace('24016','Nitrogen dioxide air pollution; 2005')
    i=i.replace('24011','Traffic intensity on the nearest major road')
    i=i.replace('24008','Particulate matter air pollution 2.5-10um; 2010')
    i=i.replace('24007','Particulate matter air pollution (pm2.5) absorbance; 2010')
    i=i.replace('24006','Particulate matter air pollution (pm2.5); 2010')
    i=i.replace('24005','Particulate matter air pollution (pm10); 2010')
    i=i.replace('24004','Nitrogen oxides air pollution; 2010')
    i=i.replace('24003','Nitrogen dioxide air pollution; 2010')
    i=i.replace('22661','Number of gap periods')
    i=i.replace('22599','Number of jobs held')
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('21000','Ethnic background')
    i=i.replace('20119','Current employment status - corrected')
    i=i.replace('20118','Home area population density - urban or rural')
    i=i.replace('6146','Attendance/disability/mobility allowance')
    i=i.replace('6142','Current employment status')
    i=i.replace('6138','Qualifications')
    i=i.replace('3659','Year immigrated to UK (United Kingdom)')
    i=i.replace('1647','Country of birth (UK/elsewhere)')
    i=i.replace('845-','Age completed full time education-')
    i=i.replace('767-','Length of working week for main job-')
    i=i.replace('738-','Average total household income before tax-')
    i=i.replace('728-','Number of vehicles in household-')
    i=i.replace('709-','Number in household-')
    i=i.replace('670-','Type of accommodation lived in-')
    i=i.replace('189-','Townsend deprivation index at recruitment-')
    i=i.replace('34-','Year of birth-')
    d.append(i)
df.columns=d
df['Age completed full time education-0.0'][df['Age completed full time education-0.0']==-2]=80
df['Current employment status-0.0'][df['Current employment status - corrected-0.0'].notna()]=df['Current employment status - corrected-0.0']
#del df['Current employment status - corrected-0.0']
df[df==-7]=0
df['In paid employment or self-employed-0.0']=np.nan
df['Retired-0.0']=np.nan
df['Looking after home and/or family-0.0']=np.nan
df['Unable to work because of sickness or disability-0.0']=np.nan
df['Unemployed-0.0']=np.nan
df['Doing unpaid or voluntary work-0.0']=np.nan
df['Full or part-time student-0.0']=np.nan
df['In paid employment or self-employed-0.0'][((df['Current employment status-0.0']==0)|((df['Current employment status-0.0']!=1)))&(df['Current employment status-0.0'].notna())]=0
df['In paid employment or self-employed-0.0'][df['Current employment status-0.0']==1]=1
df['Retired-0.0'][((df['Current employment status-0.0']==0)|((df['Current employment status-0.0']!=2)&(df['Current employment status-0.1']!=2)))&(df['Current employment status-0.0'].notna())]=0
df['Retired-0.0'][(df['Current employment status-0.0']==2)|(df['Current employment status-0.1']==2)]=1
df['Looking after home and/or family-0.0'][((df['Current employment status-0.0']==0)|((df['Current employment status-0.0']!=3)&(df['Current employment status-0.1']!=3)&(df['Current employment status-0.2']!=3)))&(df['Current employment status-0.0'].notna())]=0
df['Looking after home and/or family-0.0'][(df['Current employment status-0.0']==3)|(df['Current employment status-0.1']==3)|(df['Current employment status-0.2']==3)]=1
df['Unable to work because of sickness or disability-0.0'][((df['Current employment status-0.0']==0)|((df['Current employment status-0.0']!=4)&(df['Current employment status-0.1']!=4)&(df['Current employment status-0.2']!=4)&(df['Current employment status-0.3']!=4)))&(df['Current employment status-0.0'].notna())]=0
df['Unable to work because of sickness or disability-0.0'][(df['Current employment status-0.0']==4)|(df['Current employment status-0.1']==4)|(df['Current employment status-0.2']==4)|(df['Current employment status-0.3']==4)]=1
df['Unemployed-0.0'][((df['Current employment status-0.0']==0)|((df['Current employment status-0.0']!=5)&(df['Current employment status-0.1']!=5)&(df['Current employment status-0.2']!=5)&(df['Current employment status-0.3']!=5)&(df['Current employment status-0.4']!=5)))&(df['Current employment status-0.0'].notna())]=0
df['Unemployed-0.0'][(df['Current employment status-0.0']==5)|(df['Current employment status-0.1']==5)|(df['Current employment status-0.2']==5)|(df['Current employment status-0.3']==5)|(df['Current employment status-0.4']==5)]=1
df['Doing unpaid or voluntary work-0.0'][((df['Current employment status-0.0']==0)|((df['Current employment status-0.0']!=6)&(df['Current employment status-0.1']!=6)&(df['Current employment status-0.2']!=6)&(df['Current employment status-0.3']!=6)&(df['Current employment status-0.4']!=6)&(df['Current employment status-0.5']!=6)))&(df['Current employment status-0.0'].notna())]=0
df['Doing unpaid or voluntary work-0.0'][(df['Current employment status-0.0']==6)|(df['Current employment status-0.1']==6)|(df['Current employment status-0.2']==6)|(df['Current employment status-0.3']==6)|(df['Current employment status-0.4']==6)|(df['Current employment status-0.5']==6)]=1
df['Full or part-time student-0.0'][((df['Current employment status-0.0']==0)|((df['Current employment status-0.0']!=7)&(df['Current employment status-0.1']!=7)&(df['Current employment status-0.2']!=7)&(df['Current employment status-0.3']!=7)&(df['Current employment status-0.4']!=7)&(df['Current employment status-0.5']!=7)&(df['Current employment status-0.6']!=7)))&(df['Current employment status-0.0'].notna())]=0
df['Full or part-time student-0.0'][(df['Current employment status-0.0']==7)|(df['Current employment status-0.1']==7)|(df['Current employment status-0.2']==7)|(df['Current employment status-0.3']==7)|(df['Current employment status-0.4']==7)|(df['Current employment status-0.5']==7)|(df['Current employment status-0.6']==7)]=1
df['Attendance allowance-0.0']=np.nan
df['Disability living allowance-0.0']=np.nan
df['Blue badge-0.0']=np.nan
df['Attendance allowance-0.0'][((df['Attendance/disability/mobility allowance-0.0']==0)|((df['Attendance/disability/mobility allowance-0.0']!=1)))&(df['Attendance/disability/mobility allowance-0.0'].notna())]=0
df['Attendance allowance-0.0'][df['Attendance/disability/mobility allowance-0.0']==1]=1
df['Disability living allowance-0.0'][((df['Attendance/disability/mobility allowance-0.0']==0)|((df['Attendance/disability/mobility allowance-0.0']!=2)&(df['Attendance/disability/mobility allowance-0.1']!=2)))&(df['Attendance/disability/mobility allowance-0.0'].notna())]=0
df['Disability living allowance-0.0'][(df['Attendance/disability/mobility allowance-0.0']==2)|(df['Attendance/disability/mobility allowance-0.1']==2)]=1
df['Blue badge-0.0'][((df['Attendance/disability/mobility allowance-0.0']==0)|((df['Attendance/disability/mobility allowance-0.0']!=3)&(df['Attendance/disability/mobility allowance-0.1']!=3)&(df['Attendance/disability/mobility allowance-0.2']!=3)))&(df['Attendance/disability/mobility allowance-0.0'].notna())]=0
df['Blue badge-0.0'][(df['Attendance/disability/mobility allowance-0.0']==3)|(df['Attendance/disability/mobility allowance-0.1']==3)|(df['Attendance/disability/mobility allowance-0.2']==3)]=1
df['College or University degree-0.0']=np.nan
df['A levels/AS levels or equivalent-0.0']=np.nan
df['O levels/GCSEs or equivalent-0.0']=np.nan
df['CSEs or equivalent-0.0']=np.nan
df['NVQ or HND or HNC or equivalent-0.0']=np.nan
df['Other professional qualifications eg: nursing, teaching-0.0']=np.nan
df['College or University degree-0.0'][((df['Qualifications-0.0']==0)|((df['Qualifications-0.0']!=1)))&(df['Qualifications-0.0'].notna())]=0
df['College or University degree-0.0'][df['Qualifications-0.0']==1]=1
df['A levels/AS levels or equivalent-0.0'][((df['Qualifications-0.0']==0)|((df['Qualifications-0.0']!=2)&(df['Qualifications-0.1']!=2)))&(df['Qualifications-0.0'].notna())]=0
df['A levels/AS levels or equivalent-0.0'][(df['Qualifications-0.0']==2)|(df['Qualifications-0.1']==2)]=1
df['O levels/GCSEs or equivalent-0.0'][((df['Qualifications-0.0']==0)|((df['Qualifications-0.0']!=3)&(df['Qualifications-0.1']!=3)&(df['Qualifications-0.2']!=3)))&(df['Qualifications-0.0'].notna())]=0
df['O levels/GCSEs or equivalent-0.0'][(df['Qualifications-0.0']==3)|(df['Qualifications-0.1']==3)|(df['Qualifications-0.2']==3)]=1
df['CSEs or equivalent-0.0'][((df['Qualifications-0.0']==0)|((df['Qualifications-0.0']!=4)&(df['Qualifications-0.1']!=4)&(df['Qualifications-0.2']!=4)&(df['Qualifications-0.3']!=4)))&(df['Qualifications-0.0'].notna())]=0
df['CSEs or equivalent-0.0'][(df['Qualifications-0.0']==4)|(df['Qualifications-0.1']==4)|(df['Qualifications-0.2']==4)|(df['Qualifications-0.3']==4)]=1
df['NVQ or HND or HNC or equivalent-0.0'][((df['Qualifications-0.0']==0)|((df['Qualifications-0.0']!=5)&(df['Qualifications-0.1']!=5)&(df['Qualifications-0.2']!=5)&(df['Qualifications-0.3']!=5)&(df['Qualifications-0.4']!=5)))&(df['Qualifications-0.0'].notna())]=0
df['NVQ or HND or HNC or equivalent-0.0'][(df['Qualifications-0.0']==5)|(df['Qualifications-0.1']==5)|(df['Qualifications-0.2']==5)|(df['Qualifications-0.3']==5)|(df['Qualifications-0.4']==5)]=1
df['Other professional qualifications eg: nursing, teaching-0.0'][((df['Qualifications-0.0']==0)|((df['Qualifications-0.0']!=6)&(df['Qualifications-0.1']!=6)&(df['Qualifications-0.2']!=6)&(df['Qualifications-0.3']!=6)&(df['Qualifications-0.4']!=6)&(df['Qualifications-0.5']!=6)))&(df['Qualifications-0.0'].notna())]=0
df['Other professional qualifications eg: nursing, teaching-0.0'][(df['Qualifications-0.0']==6)|(df['Qualifications-0.1']==6)|(df['Qualifications-0.2']==6)|(df['Qualifications-0.3']==6)|(df['Qualifications-0.4']==6)|(df['Qualifications-0.5']==6)]=1
df['Degree level-0.0']=np.nan
df['Degree level-0.0'][df['O levels/GCSEs or equivalent-0.0']==1]=1
df['Degree level-0.0'][df['A levels/AS levels or equivalent-0.0']==1]=2
df['Degree level-0.0'][df['College or University degree-0.0']==1]=3
df['Degree level-0.0'][(df['College or University degree-0.0']==0)&(df['O levels/GCSEs or equivalent-0.0']==0)&(df['A levels/AS levels or equivalent-0.0']==0)]=0
df['Number of vocational certificate-0.0']=np.nan
df['Number of vocational certificate-0.0']=df['CSEs or equivalent-0.0']+df['NVQ or HND or HNC or equivalent-0.0']
df['Number in household-0.0'][(df['Type of accommodation lived in-0.0']==4)|(df['Type of accommodation lived in-0.0']==5)]=0
df['Number of vehicles in household-0.0'][(df['Type of accommodation lived in-0.0']==4)|(df['Type of accommodation lived in-0.0']==5)]=0
df['Average total household income before tax-0.0'][(df['Type of accommodation lived in-0.0']==4)|(df['Type of accommodation lived in-0.0']==5)]=0
del df['Type of accommodation lived in-0.0']
df['Age completed full time education-0.0'][df['Degree level-0.0']==3]=21
del df['Qualifications-0.0']
del df['Qualifications-0.1']
del df['Qualifications-0.2']
del df['Qualifications-0.3']
del df['Qualifications-0.4']
del df['Qualifications-0.5']
del df['Current employment status-0.0']
del df['Current employment status-0.1']
del df['Current employment status-0.2']
del df['Current employment status-0.3']
del df['Current employment status-0.4']
del df['Current employment status-0.5']
del df['Current employment status-0.6']
del df['Attendance/disability/mobility allowance-0.0']
del df['Attendance/disability/mobility allowance-0.1']
del df['Attendance/disability/mobility allowance-0.2']
del df['Current employment status - corrected-0.0']
df = df[df['Age when attended assessment centre-0.0'].notna()]
df['Age of immigrated to UK (United Kingdom)']=np.nan
df['Age of immigrated to UK (United Kingdom)']=df['Year immigrated to UK (United Kingdom)-0.0']-df['Year of birth-0.0']
del df['Year immigrated to UK (United Kingdom)-0.0']
del df['Year of birth-0.0']
df['Ethnic background-0.0'].replace(1001,1,inplace=True)
df['Ethnic background-0.0'].replace(1002,1,inplace=True)
df['Ethnic background-0.0'].replace(1003,1,inplace=True)
df['Ethnic background-0.0'].replace(2001,2,inplace=True)
df['Ethnic background-0.0'].replace(2002,2,inplace=True)
df['Ethnic background-0.0'].replace(2003,2,inplace=True)
df['Ethnic background-0.0'].replace(2004,2,inplace=True)
df['Ethnic background-0.0'].replace(3001,2,inplace=True)
df['Ethnic background-0.0'].replace(3002,2,inplace=True)
df['Ethnic background-0.0'].replace(3003,2,inplace=True)
df['Ethnic background-0.0'].replace(3004,2,inplace=True)
df['Ethnic background-0.0'].replace(4001,4,inplace=True)
df['Ethnic background-0.0'].replace(4002,4,inplace=True)
df['Ethnic background-0.0'].replace(4003,4,inplace=True)
df['Length of working week for main job-0.0'][df['In paid employment or self-employed-0.0']==0]=0
df['Age of immigrated to UK (United Kingdom)'][(df['Country of birth (UK/elsewhere)-0.0']==1)|(df['Country of birth (UK/elsewhere)-0.0']==2)|(df['Country of birth (UK/elsewhere)-0.0']==3)|(df['Country of birth (UK/elsewhere)-0.0']==4)|(df['Country of birth (UK/elsewhere)-0.0']==-3)|(df['Country of birth (UK/elsewhere)-0.0']==-1)]=0
del df['Country of birth (UK/elsewhere)-0.0']
df[df.iloc[:,[i for i in range(2,34)]+[i for i in range(50,69)]]<0]=np.nan
del df['O levels/GCSEs or equivalent-0.0']
del df['A levels/AS levels or equivalent-0.0']
del df['College or University degree-0.0']
del df['CSEs or equivalent-0.0']
del df['NVQ or HND or HNC or equivalent-0.0']
dfEngland=df.iloc[:,[i for i in range(0,42)]+[ i for i in range(49,64)]][df['Living environment score (England)-0.0'].notna()]
for i in range(dfEngland.shape[1]):
    if list(dfEngland[list(dfEngland)[i]]).count(0)/dfEngland[list(dfEngland)[i]].notna().sum()>0.9:
        dfEngland[list(dfEngland)[i]].fillna(0,inplace=True)
for i in range(dfEngland.shape[1]):
    if list(dfEngland[list(dfEngland)[i]]).count(3)/dfEngland[list(dfEngland)[i]].notna().sum()>0.9:
        dfEngland[list(dfEngland)[i]].fillna(3,inplace=True)
for i in range(dfEngland.shape[1]):
    if list(dfEngland[list(dfEngland)[i]]).count(1)/dfEngland[list(dfEngland)[i]].notna().sum()>0.9:
        dfEngland[list(dfEngland)[i]].fillna(1,inplace=True)
for i in range(dfEngland.shape[1]):
    if list(dfEngland[list(dfEngland)[i]]).count(500)/dfEngland[list(dfEngland)[i]].notna().sum()>0.9:
        dfEngland[list(dfEngland)[i]].fillna(500,inplace=True)
corr=np.array(dfEngland.corr())
col=list(dfEngland)
for i in range(dfEngland.shape[1]):
    for k in range(i+1,35):
        if corr[i,k]>=0.95:
            dfEngland[col[i]][dfEngland[col[i]].isnull()] = dfEngland[col[k]][dfEngland[col[i]].isnull()]
            dfEngland[col[k]][dfEngland[col[k]].isnull()] = dfEngland[col[i]][dfEngland[col[k]].isnull()]
varEngland=[42,8,18,19,23,24,25,56]+[i for i in range(45,53)]
dfEngland.iloc[:,varEngland].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country1+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
dfEngland=dfEngland.iloc[:,list(set([i for i in range(dfEngland.shape[1])]) - set(varEngland))]
#remove outliers
col=list(dfEngland)
max=dfEngland.mean()+6*dfEngland.std()
min=dfEngland.mean()-6*dfEngland.std()
for i in range(1,len(col)):
    dfEngland.loc[(dfEngland[col[i]]<min[col[i]]) | (dfEngland[col[i]]>max[col[i]]),col[i]]=np.nan
dfEngland.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country1+'/'+Category_Name[j]+'-for_MICE.csv',index=False)
dfScotland=df.iloc[:,[i for i in range(0,34)]+[ i for i in range(42,64)]][df['Housing score (Scotland)-0.0'].notna()]
for i in range(dfScotland.shape[1]):
    if list(dfScotland[list(dfScotland)[i]]).count(0)/dfScotland[list(dfScotland)[i]].notna().sum()>0.9:
        df[list(dfScotland)[i]].fillna(0,inplace=True)
for i in range(dfScotland.shape[1]):
    if list(dfScotland[list(dfScotland)[i]]).count(3)/dfScotland[list(dfScotland)[i]].notna().sum()>0.9:
        df[list(dfScotland)[i]].fillna(3,inplace=True)
for i in range(dfScotland.shape[1]):
    if list(dfScotland[list(dfScotland)[i]]).count(1)/dfScotland[list(dfScotland)[i]].notna().sum()>0.9:
        df[list(dfScotland)[i]].fillna(1,inplace=True)
for i in range(dfScotland.shape[1]):
    if list(dfScotland[list(dfScotland)[i]]).count(500)/dfScotland[list(dfScotland)[i]].notna().sum()>0.9:
        df[list(dfScotland)[i]].fillna(500,inplace=True)
for i in range(dfScotland.shape[1]):
    if list(dfScotland[list(dfScotland)[i]]).count(11)/dfScotland[list(dfScotland)[i]].notna().sum()>0.9:
        df[list(dfScotland)[i]].fillna(11,inplace=True)
del dfScotland['Particulate matter air pollution (pm10); 2010-0.0']
del dfScotland['Particulate matter air pollution (pm2.5); 2010-0.0']
del dfScotland['Particulate matter air pollution (pm2.5) absorbance; 2010-0.0']
del dfScotland['Particulate matter air pollution 2.5-10um; 2010-0.0']
del dfScotland['Greenspace percentage, buffer 1000m-0.0']
del dfScotland['Domestic garden percentage, buffer 1000m-0.0']
del dfScotland['Water percentage, buffer 1000m-0.0']
del dfScotland['Greenspace percentage, buffer 300m-0.0']
del dfScotland['Domestic garden percentage, buffer 300m-0.0']
del dfScotland['Water percentage, buffer 300m-0.0']
varScotland=[14,15,19,20,31,8,45]+[i for i in range(34,42)]
dfScotland.iloc[:,varScotland].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country2+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
dfScotland=dfScotland.iloc[:,list(set([i for i in range(dfScotland.shape[1])]) - set(varScotland))]
#remove outliers
col=list(dfScotland)
max=dfScotland.mean()+6*dfScotland.std()
min=dfScotland.mean()-6*dfScotland.std()
for i in range(1,len(col)):
    dfScotland.loc[(dfScotland[col[i]]<min[col[i]]) | (dfScotland[col[i]]>max[col[i]]),col[i]]=np.nan
dfScotland.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Country2+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Spirometry
j=17
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('20258','FEV1/ FVC ratio Z-score')
    i=i.replace('20257','Forced vital capacity (FVC) Z-score')
    i=i.replace('20256','Forced expiratory volume in 1-second (FEV1) Z-score')
    i=i.replace('20154','Forced expiratory volume in 1-second (FEV1), predicted percentage')
    i=i.replace('20153','Forced expiratory volume in 1-second (FEV1), predicted')
    i=i.replace('20151','Forced vital capacity (FVC), Best measure')
    i=i.replace('20150','Forced expiratory volume in 1-second (FEV1), Best measure')
    i=i.replace('3159','Smoked cigarette or pipe within last hour')
    i=i.replace('3090','Used an inhaler for chest within last hour')
    i=i.replace('3089','Caffeine drink within last hour')
    i=i.replace('3065','Ordering of blows')
    i=i.replace('3064','Peak expiratory flow (PEF)')
    i=i.replace('3063','Forced expiratory volume in 1-second (FEV1)')
    i=i.replace('3062','Forced vital capacity (FVC)')
    i=i.replace('3061','Acceptability of each blow result')
    i=i.replace('21003','Age when attended assessment centre')
    d.append(i)
df.columns=d
df['Forced vital capacity (FVC)-0.0'][(df['Forced vital capacity (FVC)-0.0'].notna())&(df['Acceptability of each blow result-0.0']!=0)&(df['Acceptability of each blow result-0.0']!=32)]=np.nan
df['Forced expiratory volume in 1-second (FEV1)-0.0'][(df['Forced expiratory volume in 1-second (FEV1)-0.0'].notna())&(df['Acceptability of each blow result-0.0']!=0)&(df['Acceptability of each blow result-0.0']!=32)]=np.nan
df['Peak expiratory flow (PEF)-0.0'][(df['Peak expiratory flow (PEF)-0.0'].notna())&(df['Acceptability of each blow result-0.0']!=0)&(df['Acceptability of each blow result-0.0']!=32)]=np.nan
df['Forced vital capacity (FVC)-0.1'][(df['Forced vital capacity (FVC)-0.1'].notna())&(df['Acceptability of each blow result-0.1']!=0)&(df['Acceptability of each blow result-0.1']!=32)]=np.nan
df['Forced expiratory volume in 1-second (FEV1)-0.1'][(df['Forced expiratory volume in 1-second (FEV1)-0.1'].notna())&(df['Acceptability of each blow result-0.1']!=0)&(df['Acceptability of each blow result-0.1']!=32)]=np.nan
df['Peak expiratory flow (PEF)-0.1'][(df['Peak expiratory flow (PEF)-0.1'].notna())&(df['Acceptability of each blow result-0.1']!=0)&(df['Acceptability of each blow result-0.1']!=32)]=np.nan
df['Forced vital capacity (FVC)-0.2'][(df['Forced vital capacity (FVC)-0.2'].notna())&(df['Acceptability of each blow result-0.2']!=0)&(df['Acceptability of each blow result-0.2']!=32)]=np.nan
df['Forced expiratory volume in 1-second (FEV1)-0.2'][(df['Forced expiratory volume in 1-second (FEV1)-0.2'].notna())&(df['Acceptability of each blow result-0.2']!=0)&(df['Acceptability of each blow result-0.2']!=32)]=np.nan
df['Peak expiratory flow (PEF)-0.2'][(df['Peak expiratory flow (PEF)-0.2'].notna())&(df['Acceptability of each blow result-0.2']!=0)&(df['Acceptability of each blow result-0.2']!=32)]=np.nan
del df['Acceptability of each blow result-0.0']
del df['Acceptability of each blow result-0.1']
del df['Acceptability of each blow result-0.2']
df.iloc[:,[1,2,3,4,7,8,11,12,13,14,15,16,17,18,19]][(df['Smoked cigarette or pipe within last hour-0.0']==1)|(df['Used an inhaler for chest within last hour-0.0']==1)|(df['Caffeine drink within last hour-0.0']==1)]=np.nan
del df['Caffeine drink within last hour-0.0']
del df['Used an inhaler for chest within last hour-0.0']
del df['Smoked cigarette or pipe within last hour-0.0']
var=[17,1,2,11,12,14,15]
df.iloc[:,var].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Physical health
j=18
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('40001','Underlying (primary) cause of death: ICD10')
    i=i.replace('40006','Type of cancer: ICD10')
    i=i.replace('40007','Age at death')
    i=i.replace('40008','Age at cancer diagnosis')
    i=i.replace('41270','Diagnoses - ICD10')
    i=i.replace('22502','Cough on most days')
    i=i.replace('22505','Years of bringing up phlegm/sputum/mucus on most days')
    i=i.replace('22504','Bring up phlegm/sputum/mucus on most days')
    i=i.replace('22503','Years of cough on most days')
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('20114-','Illnesses of adopted siblings-')
    i=i.replace('20113-','Illnesses of adopted mother-')
    i=i.replace('20112-','Illnesses of adopted father-')
    i=i.replace('20111-','Illnesses of siblings-')
    i=i.replace('20110-','Illnesses of mother-')
    i=i.replace('20107-','Illnesses of father-')
    i=i.replace('20014','Method of recording time when operation occurred')
    i=i.replace('20011','Interpolated Age of participant when operation took place')
    i=i.replace('20010','Interpolated Year when operation took place')
    i=i.replace('20002','Non-cancer illness code, self-reported')
    i=i.replace('20001','Cancer code, self-reported')
    i=i.replace('6671','Number of antibiotics taken in last 3 months')
    i=i.replace('6205','Which eye(s) affected by strabismus (squint)')
    i=i.replace('6179','Mineral and other dietary supplements')
    i=i.replace('6177','Medication for cholesterol, blood pressure or diabetes')
    i=i.replace('6159','Pain type(s) experienced in last month')
    i=i.replace('6155','Vitamin and mineral supplements')
    i=i.replace('6154','Medication for pain relief, constipation, heartburn')
    i=i.replace('6153','Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones')
    i=i.replace('6152','Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor')
    i=i.replace('6151','Fractured bone site(s)')
    i=i.replace('6150','Vascular/heart problems diagnosed by doctor')
    i=i.replace('6149','Mouth/teeth dental problems')
    i=i.replace('6148','Eye problems/disorders')
    i=i.replace('6147','Reason for glasses/contact lenses')
    i=i.replace('6119','Which eye(s) affected by glaucoma')
    i=i.replace('6014','Doctor restricts physical activity due to heart condition')
    i=i.replace('5945','Age other serious eye condition diagnosed')
    i=i.replace('5934','Which eye(s) affected by other serious eye condition')
    i=i.replace('5923','Age macular degeneration diagnosed')
    i=i.replace('5912','Which eye(s) affected by macular degeneration')
    i=i.replace('5901','Age when diabetes-related eye disease diagnosed')
    i=i.replace('5890','Which eye(s) affected by diabetes-related eye disease')
    i=i.replace('5877','Which eye(s) affected by other eye condition')
    i=i.replace('5855','Which eye(s) affected by astigmatism')
    i=i.replace('5843','Which eye(s) affected by myopia (short sight)')
    i=i.replace('5832','Which eye(s) affected by hypermetropia (long sight)')
    i=i.replace('5610','Which eye(s) affected by presbyopia')
    i=i.replace('5441','Which eye(s) are affected by cataract')
    i=i.replace('5430','Age when loss of vision due to injury or trauma diagnosed')
    i=i.replace('5419','Which eye(s) affected by injury or trauma resulting in loss of vision')
    i=i.replace('5408','Which eye(s) affected by amblyopia (lazy eye)')
    i=i.replace('21003','age')
    i=i.replace('4728','Leg pain on walking')
    i=i.replace('4717','Shortness of breath walking on level ground')
    i=i.replace('4700','Age cataract diagnosed')
    i=i.replace('4689','Age glaucoma diagnosed')
    i=i.replace('4674','Private healthcare')
    i=i.replace('4067','Facial pains for 3+ months')
    i=i.replace('4056','Age stroke diagnosed')
    i=i.replace('4041','Gestational diabetes only')
    i=i.replace('4022','Age pulmonary embolism (blood clot in lung) diagnosed')
    i=i.replace('4012','Age deep-vein thrombosis (DVT, blood clot in leg) diagnosed')
    i=i.replace('3992','Age emphysema/chronic bronchitis diagnosed')
    i=i.replace('3894','Age heart attack diagnosed')
    i=i.replace('3799','Headaches for 3+ months')
    i=i.replace('3786','Age asthma diagnosed')
    i=i.replace('3773','Knee pain for 3+ months')
    i=i.replace('3761','Age hay fever, rhinitis or eczema diagnosed')
    i=i.replace('3741','Stomach/abdominal pain for 3+ months')
    i=i.replace('3627','Age angina diagnosed')
    i=i.replace('3571','Back pain for 3+ months')
    i=i.replace('3414','Hip pain for 3+ months')
    i=i.replace('3404','Neck/shoulder pain for 3+ months')
    i=i.replace('3393','Hearing aid user')
    i=i.replace('2257','Hearing difficulty/problems with background noise')
    i=i.replace('2247','Hearing difficulty/problems')
    i=i.replace('4814','Tinnitus severity/nuisance')
    i=i.replace('4803','Tinnitus')
    i=i.replace('4792','Cochlear implant')
    i=i.replace('3005','Fracture resulting from simple fall')
    i=i.replace('2976','Age diabetes diagnosed')
    i=i.replace('2966','Age high blood pressure diagnosed')
    i=i.replace('2956','General pain for 3+ months')
    i=i.replace('2844','Had other major operations')
    i=i.replace('2492','Taking other prescription medications')
    i=i.replace('2473','Other serious medical condition/disability diagnosed by doctor')
    i=i.replace('2463','Fractured/broken bones in last 5 years')
    i=i.replace('2453','Cancer diagnosed by doctor')
    i=i.replace('2443','Diabetes diagnosed by doctor')
    i=i.replace('2415','Had major operations')
    i=i.replace('2335','Chest pain or discomfort')
    i=i.replace('2316','Wheeze or whistling in the chest in last year')
    i=i.replace('2306','Weight change compared with 1 year ago')
    i=i.replace('2296','Falls in the last year')
    i=i.replace('2227','Other eye problems')
    i=i.replace('2217','Age started wearing glasses or contact lenses')
    i=i.replace('2207','Wears glasses or contact lenses')
    i=i.replace('2188','Long-standing illness, disability or infirmity')
    i=i.replace('2178','Overall health rating')
    i=i.replace('5057-','Number of older siblings-')
    i=i.replace('4501-','Non-accidental death in close genetic family-')
    i=i.replace('3982-','Number of adopted sisters-')
    i=i.replace('3972-','Number of adopted brothers-')
    i=i.replace('3942-','Adopted mother still alive-')
    i=i.replace('3912-','Adopted father still alive-')
    i=i.replace('3526-','Mothers age at death-')
    i=i.replace('2946-','Fathers age-')
    i=i.replace('1883-','Number of full sisters-')
    i=i.replace('1873-','Number of full brothers-')
    i=i.replace('1845-','Mothers age-')
    i=i.replace('1835-','Mother still alive-')
    i=i.replace('1807-','Fathers age at death-')
    i=i.replace('1797-','Father still alive-')
    i=i.replace('1787-','Maternal smoking around birth-')
    i=i.replace('1777-','Part of a multiple birth-')
    i=i.replace('1767-','Adopted as a child-')
    i=i.replace('1677-','Breastfed as a baby-')
    i=i.replace('137-','Number of treatments/medications taken-')
    i=i.replace('136-','Number of operations, self-reported-')
    i=i.replace('135-','Number of self-reported non-cancer illnesses-')
    i=i.replace('134-','Number of self-reported cancers-')
    i=i.replace('4080-','Systolic blood pressure, automated reading-')
    i=i.replace('4079-','Diastolic blood pressure, automated reading-')
    i=i.replace('102-','Pulse rate, automated reading-')
    i=i.replace('95-','Pulse rate (during blood-pressure measurement)-')
    i=i.replace('94-','Diastolic blood pressure, manual reading-')
    i=i.replace('93-','Systolic blood pressure, manual reading-')
    i=i.replace('92-','Operation year/age first occurred-')
    d.append(i)
df.columns=d
del df['Fractured bone site(s)-0.0']
del df['Fractured bone site(s)-0.1']
del df['Fractured bone site(s)-0.2']
del df['Fractured bone site(s)-0.3']
del df['Fractured bone site(s)-0.4']
del df['Fractured bone site(s)-0.5']
del df['Fractured bone site(s)-0.6']
del df['Fracture resulting from simple fall-0.0']
df[df==-7]=0
df['Lose weight-0.0']=np.nan
df['Gain weight-0.0']=np.nan
df['Lose weight-0.0'][(df['Weight change compared with 1 year ago-0.0']==0) |(df['Weight change compared with 1 year ago-0.0']==2)]=0
df['Lose weight-0.0'][df['Weight change compared with 1 year ago-0.0']==3]=1
df['Gain weight-0.0'][(df['Weight change compared with 1 year ago-0.0']==0) |(df['Weight change compared with 1 year ago-0.0']==3)]=0
df['Gain weight-0.0'][df['Weight change compared with 1 year ago-0.0']==2]=1
del df['Weight change compared with 1 year ago-0.0']
df['Fractured/broken bones in last 5 years-0.0'].fillna(0,inplace=True)
df['Shortness of breath walking on level ground-0.0'].fillna(0,inplace=True)
df['Age diabetes diagnosed-0.0'][df['Diabetes diagnosed by doctor-0.0']==0]=0
df['Vascular/heart problems diagnosed by doctor-0.0'][df['Vascular/heart problems diagnosed by doctor-0.0']==-3]=np.nan
df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0'][df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==-3]=np.nan
df['Blood clot in the leg (DVT)-0.0']=np.nan
df['Blood clot in the lung-0.0']=np.nan
df['Emphysema/chronic bronchitis-0.0']=np.nan
df['Asthma-0.0']=np.nan
df['Hayfever, allergic rhinitis or eczema-0.0']=np.nan
df['Blood clot in the leg (DVT)-0.0'][(((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==-7)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']!=5))&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0'].notna()))&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0'].notna())]=0
df['Blood clot in the leg (DVT)-0.0'][df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==5]=1
df['Blood clot in the lung-0.0'][((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==-7)|((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']!=6)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.1']!=6)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.2']!=6)))&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0'].notna())]=0
df['Blood clot in the lung-0.0'][(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==6)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.1']==6)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.2']==6)]=1
df['Emphysema/chronic bronchitis-0.0'][((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==-7)|((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']!=7)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.1']!=7)))&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0'].notna())]=0
df['Emphysema/chronic bronchitis-0.0'][(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==7)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.1']==7)]=1
df['Asthma-0.0'][((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==-7)|((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']!=8)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.1']!=8)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.2']!=8)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.3']!=8)))&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0'].notna())]=0
df['Asthma-0.0'][(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==8)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.1']==8)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.2']==8)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.3']==8)]=1
df['Hayfever, allergic rhinitis or eczema-0.0'][((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==-7)|((df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']!=9)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.1']!=9)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.2']!=9)&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.3']!=9)))&(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0'].notna())]=0
df['Hayfever, allergic rhinitis or eczema-0.0'][(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.0']==9)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.1']==9)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.2']==9)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.3']==9)|(df['Blood clot, DVT, bronchitis, emphysema, asthma, rhinitis, eczema, allergy diagnosed by doctor-0.4']==9)]=1
df['Heart attack-0.0']=np.nan
df['Angina-0.0']=np.nan
df['Stroke-0.0']=np.nan
df['High blood pressure-0.0']=np.nan
df['Heart attack-0.0'][((df['Vascular/heart problems diagnosed by doctor-0.0']==-7)|(df['Vascular/heart problems diagnosed by doctor-0.0']!=1))&(df['Vascular/heart problems diagnosed by doctor-0.0'].notna())]=0
df['Heart attack-0.0'][df['Vascular/heart problems diagnosed by doctor-0.0']==1]=1
df['Angina-0.0'][((df['Vascular/heart problems diagnosed by doctor-0.0']==-7)|(df['Vascular/heart problems diagnosed by doctor-0.0']!=2)&(df['Vascular/heart problems diagnosed by doctor-0.1']!=2))&(df['Vascular/heart problems diagnosed by doctor-0.0'].notna())]=0
df['Angina-0.0'][(df['Vascular/heart problems diagnosed by doctor-0.0']==2)|(df['Vascular/heart problems diagnosed by doctor-0.1']==2)]=1
df['Stroke-0.0'][((df['Vascular/heart problems diagnosed by doctor-0.0']==-7)|((df['Vascular/heart problems diagnosed by doctor-0.0']!=3)&(df['Vascular/heart problems diagnosed by doctor-0.1']!=3)&(df['Vascular/heart problems diagnosed by doctor-0.2']!=3)))&(df['Vascular/heart problems diagnosed by doctor-0.0'].notna())]=0
df['Stroke-0.0'][(df['Vascular/heart problems diagnosed by doctor-0.0']==3)|(df['Vascular/heart problems diagnosed by doctor-0.1']==3)|(df['Vascular/heart problems diagnosed by doctor-0.2']==3)]=1
df['High blood pressure-0.0'][((df['Vascular/heart problems diagnosed by doctor-0.0']==-7)|((df['Vascular/heart problems diagnosed by doctor-0.0']!=4)&(df['Vascular/heart problems diagnosed by doctor-0.1']!=4)&(df['Vascular/heart problems diagnosed by doctor-0.2']!=4)&(df['Vascular/heart problems diagnosed by doctor-0.3']!=4)))&(df['Vascular/heart problems diagnosed by doctor-0.0'].notna())]=0
df['High blood pressure-0.0'][(df['Vascular/heart problems diagnosed by doctor-0.0']==4)|(df['Vascular/heart problems diagnosed by doctor-0.1']==4)|(df['Vascular/heart problems diagnosed by doctor-0.2']==4)|(df['Vascular/heart problems diagnosed by doctor-0.3']==4)]=1
df['Years of cough on most days-0.0'][df['Cough on most days-0.0']==0]=0
df['Years of bringing up phlegm/sputum/mucus on most days-0.0'][df['Bring up phlegm/sputum/mucus on most days-0.0']==0]=0
df['Age high blood pressure diagnosed-0.0'][df['High blood pressure-0.0']==0]=0
df['Age angina diagnosed-0.0'][df['Angina-0.0']==0]=0
df['Age hay fever, rhinitis or eczema diagnosed-0.0'][df['Hayfever, allergic rhinitis or eczema-0.0']==0]=0
df['Age asthma diagnosed-0.0'][df['Asthma-0.0']==0]=0
df['Age heart attack diagnosed-0.0'][df['Heart attack-0.0']==0]=0
df['Age emphysema/chronic bronchitis diagnosed-0.0'][df['Emphysema/chronic bronchitis-0.0']==0]=0
df['Age deep-vein thrombosis (DVT, blood clot in leg) diagnosed-0.0'][df['Blood clot in the leg (DVT)-0.0']==0]=0
df['Age pulmonary embolism (blood clot in lung) diagnosed-0.0'][df['Blood clot in the lung-0.0']==0]=0
df['Age stroke diagnosed-0.0'][df['Stroke-0.0']==0]=0
df['Cholesterol lowering medication for female-0.0']=np.nan
df['Blood pressure medication for female-0.0']=np.nan
df['Insulin for female-0.0']=np.nan
df['Cholesterol lowering medication for female-0.0'][((df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']==0)|((df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']!=1)))&(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0'].notna())]=0
df['Cholesterol lowering medication for female-0.0'][df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']==1]=1
df['Blood pressure medication for female-0.0'][((df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']==0)|((df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']!=2)&(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.1']!=2)))&(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0'].notna())]=0
df['Blood pressure medication for female-0.0'][(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']==2)|(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.1']==2)]=1
df['Insulin for female-0.0'][((df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']==0)|((df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']!=3)&(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.1']!=3)&(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.2']!=3)))&(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0'].notna())]=0
df['Insulin for female-0.0'][(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.0']==3)|(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.1']==3)|(df['Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones-0.2']==3)]=1
df['Aspirin-0.0']=np.nan
df['Ibuprofen-0.0']=np.nan
df['Paracetamol-0.0']=np.nan
df['Ranitidine-0.0']=np.nan
df['Omeprazole-0.0']=np.nan
df['Laxatives-0.0']=np.nan
df['Aspirin-0.0'][((df['Medication for pain relief, constipation, heartburn-0.0']==0)|((df['Medication for pain relief, constipation, heartburn-0.0']!=1)))&(df['Medication for pain relief, constipation, heartburn-0.0'].notna())]=0
df['Aspirin-0.0'][df['Medication for pain relief, constipation, heartburn-0.0']==1]=1
df['Ibuprofen-0.0'][((df['Medication for pain relief, constipation, heartburn-0.0']==0)|((df['Medication for pain relief, constipation, heartburn-0.0']!=2)&(df['Medication for pain relief, constipation, heartburn-0.1']!=2)))&(df['Medication for pain relief, constipation, heartburn-0.0'].notna())]=0
df['Ibuprofen-0.0'][(df['Medication for pain relief, constipation, heartburn-0.0']==2)|(df['Medication for pain relief, constipation, heartburn-0.1']==2)]=1
df['Paracetamol-0.0'][((df['Medication for pain relief, constipation, heartburn-0.0']==0)|((df['Medication for pain relief, constipation, heartburn-0.0']!=3)&(df['Medication for pain relief, constipation, heartburn-0.1']!=3)&(df['Medication for pain relief, constipation, heartburn-0.2']!=3)))&(df['Medication for pain relief, constipation, heartburn-0.0'].notna())]=0
df['Paracetamol-0.0'][(df['Medication for pain relief, constipation, heartburn-0.0']==3)|(df['Medication for pain relief, constipation, heartburn-0.1']==3)|(df['Medication for pain relief, constipation, heartburn-0.2']==3)]=1
df['Ranitidine-0.0'][((df['Medication for pain relief, constipation, heartburn-0.0']==0)|((df['Medication for pain relief, constipation, heartburn-0.0']!=4)&(df['Medication for pain relief, constipation, heartburn-0.1']!=4)&(df['Medication for pain relief, constipation, heartburn-0.2']!=4)&(df['Medication for pain relief, constipation, heartburn-0.3']!=4)))&(df['Medication for pain relief, constipation, heartburn-0.0'].notna())]=0
df['Ranitidine-0.0'][(df['Medication for pain relief, constipation, heartburn-0.0']==4)|(df['Medication for pain relief, constipation, heartburn-0.1']==4)|(df['Medication for pain relief, constipation, heartburn-0.2']==4)|(df['Medication for pain relief, constipation, heartburn-0.3']==4)]=1
df['Omeprazole-0.0'][((df['Medication for pain relief, constipation, heartburn-0.0']==0)|((df['Medication for pain relief, constipation, heartburn-0.0']!=5)&(df['Medication for pain relief, constipation, heartburn-0.1']!=5)&(df['Medication for pain relief, constipation, heartburn-0.2']!=5)&(df['Medication for pain relief, constipation, heartburn-0.3']!=5)&(df['Medication for pain relief, constipation, heartburn-0.4']!=5)))&(df['Medication for pain relief, constipation, heartburn-0.0'].notna())]=0
df['Omeprazole-0.0'][(df['Medication for pain relief, constipation, heartburn-0.0']==5)|(df['Medication for pain relief, constipation, heartburn-0.1']==5)|(df['Medication for pain relief, constipation, heartburn-0.2']==5)|(df['Medication for pain relief, constipation, heartburn-0.3']==5)|(df['Medication for pain relief, constipation, heartburn-0.4']==5)]=1
df['Laxatives-0.0'][((df['Medication for pain relief, constipation, heartburn-0.0']==0)|((df['Medication for pain relief, constipation, heartburn-0.0']!=6)&(df['Medication for pain relief, constipation, heartburn-0.1']!=6)&(df['Medication for pain relief, constipation, heartburn-0.2']!=6)&(df['Medication for pain relief, constipation, heartburn-0.3']!=6)&(df['Medication for pain relief, constipation, heartburn-0.4']!=6)&(df['Medication for pain relief, constipation, heartburn-0.5']!=6)))&(df['Medication for pain relief, constipation, heartburn-0.0'].notna())]=0
df['Laxatives-0.0'][(df['Medication for pain relief, constipation, heartburn-0.0']==6)|(df['Medication for pain relief, constipation, heartburn-0.1']==6)|(df['Medication for pain relief, constipation, heartburn-0.2']==6)|(df['Medication for pain relief, constipation, heartburn-0.3']==6)|(df['Medication for pain relief, constipation, heartburn-0.4']==6)|(df['Medication for pain relief, constipation, heartburn-0.5']==6)]=1
df['Vitamin A-0.0']=np.nan
df['Vitamin B-0.0']=np.nan
df['Vitamin C-0.0']=np.nan
df['Vitamin D-0.0']=np.nan
df['Vitamin E-0.0']=np.nan
df['Folic acid or Folate-0.0']=np.nan
df['Multivitamins +/- minerals-0.0']=np.nan
df['Vitamin A-0.0'][((df['Vitamin and mineral supplements-0.0']==0)|((df['Vitamin and mineral supplements-0.0']!=1)))&(df['Vitamin and mineral supplements-0.0'].notna())]=0
df['Vitamin A-0.0'][df['Vitamin and mineral supplements-0.0']==1]=1
df['Vitamin B-0.0'][((df['Vitamin and mineral supplements-0.0']==0)|((df['Vitamin and mineral supplements-0.0']!=2)&(df['Vitamin and mineral supplements-0.1']!=2)))&(df['Vitamin and mineral supplements-0.0'].notna())]=0
df['Vitamin B-0.0'][(df['Vitamin and mineral supplements-0.0']==2)|(df['Vitamin and mineral supplements-0.1']==2)]=1
df['Vitamin C-0.0'][((df['Vitamin and mineral supplements-0.0']==0)|((df['Vitamin and mineral supplements-0.0']!=3)&(df['Vitamin and mineral supplements-0.1']!=3)&(df['Vitamin and mineral supplements-0.2']!=3)))&(df['Vitamin and mineral supplements-0.0'].notna())]=0
df['Vitamin C-0.0'][(df['Vitamin and mineral supplements-0.0']==3)|(df['Vitamin and mineral supplements-0.1']==3)|(df['Vitamin and mineral supplements-0.2']==3)]=1
df['Vitamin D-0.0'][((df['Vitamin and mineral supplements-0.0']==0)|((df['Vitamin and mineral supplements-0.0']!=4)&(df['Vitamin and mineral supplements-0.1']!=4)&(df['Vitamin and mineral supplements-0.2']!=4)&(df['Vitamin and mineral supplements-0.3']!=4)))&(df['Vitamin and mineral supplements-0.0'].notna())]=0
df['Vitamin D-0.0'][(df['Vitamin and mineral supplements-0.0']==4)|(df['Vitamin and mineral supplements-0.1']==4)|(df['Vitamin and mineral supplements-0.2']==4)|(df['Vitamin and mineral supplements-0.3']==4)]=1
df['Vitamin E-0.0'][((df['Vitamin and mineral supplements-0.0']==0)|((df['Vitamin and mineral supplements-0.0']!=5)&(df['Vitamin and mineral supplements-0.1']!=5)&(df['Vitamin and mineral supplements-0.2']!=5)&(df['Vitamin and mineral supplements-0.3']!=5)&(df['Vitamin and mineral supplements-0.4']!=5)))&(df['Vitamin and mineral supplements-0.0'].notna())]=0
df['Vitamin E-0.0'][(df['Vitamin and mineral supplements-0.0']==5)|(df['Vitamin and mineral supplements-0.1']==5)|(df['Vitamin and mineral supplements-0.2']==5)|(df['Vitamin and mineral supplements-0.3']==5)|(df['Vitamin and mineral supplements-0.4']==5)]=1
df['Folic acid or Folate-0.0'][((df['Vitamin and mineral supplements-0.0']==0)|((df['Vitamin and mineral supplements-0.0']!=6)&(df['Vitamin and mineral supplements-0.1']!=6)&(df['Vitamin and mineral supplements-0.2']!=6)&(df['Vitamin and mineral supplements-0.3']!=6)&(df['Vitamin and mineral supplements-0.4']!=6)&(df['Vitamin and mineral supplements-0.5']!=6)))&(df['Vitamin and mineral supplements-0.0'].notna())]=0
df['Folic acid or Folate-0.0'][(df['Vitamin and mineral supplements-0.0']==6)|(df['Vitamin and mineral supplements-0.1']==6)|(df['Vitamin and mineral supplements-0.2']==6)|(df['Vitamin and mineral supplements-0.3']==6)|(df['Vitamin and mineral supplements-0.4']==6)|(df['Vitamin and mineral supplements-0.5']==6)]=1
df['Multivitamins +/- minerals-0.0'][((df['Vitamin and mineral supplements-0.0']==0)|((df['Vitamin and mineral supplements-0.0']!=7)&(df['Vitamin and mineral supplements-0.1']!=7)&(df['Vitamin and mineral supplements-0.2']!=7)&(df['Vitamin and mineral supplements-0.3']!=7)&(df['Vitamin and mineral supplements-0.4']!=7)&(df['Vitamin and mineral supplements-0.5']!=7)&(df['Vitamin and mineral supplements-0.6']!=7)))&(df['Vitamin and mineral supplements-0.0'].notna())]=0
df['Multivitamins +/- minerals-0.0'][(df['Vitamin and mineral supplements-0.0']==7)|(df['Vitamin and mineral supplements-0.1']==7)|(df['Vitamin and mineral supplements-0.2']==7)|(df['Vitamin and mineral supplements-0.3']==7)|(df['Vitamin and mineral supplements-0.4']==7)|(df['Vitamin and mineral supplements-0.5']==7)|(df['Vitamin and mineral supplements-0.6']==7)]=1
df['Cholesterol lowering medication for male-0.0']=np.nan
df['Blood pressure medication for male-0.0']=np.nan
df['Insulin for male-0.0']=np.nan
df['Cholesterol lowering medication for male-0.0'][((df['Medication for cholesterol, blood pressure or diabetes-0.0']==0)|((df['Medication for cholesterol, blood pressure or diabetes-0.0']!=1)))&(df['Medication for cholesterol, blood pressure or diabetes-0.0'].notna())]=0
df['Cholesterol lowering medication for male-0.0'][df['Medication for cholesterol, blood pressure or diabetes-0.0']==1]=1
df['Blood pressure medication for male-0.0'][((df['Medication for cholesterol, blood pressure or diabetes-0.0']==0)|((df['Medication for cholesterol, blood pressure or diabetes-0.0']!=2)&(df['Medication for cholesterol, blood pressure or diabetes-0.1']!=2)))&(df['Medication for cholesterol, blood pressure or diabetes-0.0'].notna())]=0
df['Blood pressure medication for male-0.0'][(df['Medication for cholesterol, blood pressure or diabetes-0.0']==2)|(df['Medication for cholesterol, blood pressure or diabetes-0.1']==2)]=1
df['Insulin for male-0.0'][((df['Medication for cholesterol, blood pressure or diabetes-0.0']==0)|((df['Medication for cholesterol, blood pressure or diabetes-0.0']!=3)&(df['Medication for cholesterol, blood pressure or diabetes-0.1']!=3)&(df['Medication for cholesterol, blood pressure or diabetes-0.2']!=3)))&(df['Medication for cholesterol, blood pressure or diabetes-0.0'].notna())]=0
df['Insulin for male-0.0'][(df['Medication for cholesterol, blood pressure or diabetes-0.0']==3)|(df['Medication for cholesterol, blood pressure or diabetes-0.1']==3)|(df['Medication for cholesterol, blood pressure or diabetes-0.2']==3)]=1
df['Fish oil-0.0']=np.nan
df['Glucosamine-0.0']=np.nan
df['Calcium-0.0']=np.nan
df['Zinc-0.0']=np.nan
df['Iron-0.0']=np.nan
df['Selenium-0.0']=np.nan
df['Fish oil-0.0'][((df['Mineral and other dietary supplements-0.0']==0)|((df['Mineral and other dietary supplements-0.0']!=1)))&(df['Mineral and other dietary supplements-0.0'].notna())]=0
df['Fish oil-0.0'][df['Mineral and other dietary supplements-0.0']==1]=1
df['Glucosamine-0.0'][((df['Mineral and other dietary supplements-0.0']==0)|((df['Mineral and other dietary supplements-0.0']!=2)&(df['Mineral and other dietary supplements-0.1']!=2)))&(df['Mineral and other dietary supplements-0.0'].notna())]=0
df['Glucosamine-0.0'][(df['Mineral and other dietary supplements-0.0']==2)|(df['Mineral and other dietary supplements-0.1']==2)]=1
df['Calcium-0.0'][((df['Mineral and other dietary supplements-0.0']==0)|((df['Mineral and other dietary supplements-0.0']!=3)&(df['Mineral and other dietary supplements-0.1']!=3)&(df['Mineral and other dietary supplements-0.2']!=3)))&(df['Mineral and other dietary supplements-0.0'].notna())]=0
df['Calcium-0.0'][(df['Mineral and other dietary supplements-0.0']==3)|(df['Mineral and other dietary supplements-0.1']==3)|(df['Mineral and other dietary supplements-0.2']==3)]=1
df['Zinc-0.0'][((df['Mineral and other dietary supplements-0.0']==0)|((df['Mineral and other dietary supplements-0.0']!=4)&(df['Mineral and other dietary supplements-0.1']!=4)&(df['Mineral and other dietary supplements-0.2']!=4)&(df['Mineral and other dietary supplements-0.3']!=4)))&(df['Mineral and other dietary supplements-0.0'].notna())]=0
df['Zinc-0.0'][(df['Mineral and other dietary supplements-0.0']==4)|(df['Mineral and other dietary supplements-0.1']==4)|(df['Mineral and other dietary supplements-0.2']==4)|(df['Mineral and other dietary supplements-0.3']==4)]=1
df['Iron-0.0'][((df['Mineral and other dietary supplements-0.0']==0)|((df['Mineral and other dietary supplements-0.0']!=5)&(df['Mineral and other dietary supplements-0.1']!=5)&(df['Mineral and other dietary supplements-0.2']!=5)&(df['Mineral and other dietary supplements-0.3']!=5)&(df['Mineral and other dietary supplements-0.4']!=5)))&(df['Mineral and other dietary supplements-0.0'].notna())]=0
df['Iron-0.0'][(df['Mineral and other dietary supplements-0.0']==5)|(df['Mineral and other dietary supplements-0.1']==5)|(df['Mineral and other dietary supplements-0.2']==5)|(df['Mineral and other dietary supplements-0.3']==5)|(df['Mineral and other dietary supplements-0.4']==5)]=1
df['Selenium-0.0'][((df['Mineral and other dietary supplements-0.0']==0)|((df['Mineral and other dietary supplements-0.0']!=6)&(df['Mineral and other dietary supplements-0.1']!=6)&(df['Mineral and other dietary supplements-0.2']!=6)&(df['Mineral and other dietary supplements-0.3']!=6)&(df['Mineral and other dietary supplements-0.4']!=6)&(df['Mineral and other dietary supplements-0.5']!=6)))&(df['Mineral and other dietary supplements-0.0'].notna())]=0
df['Selenium-0.0'][(df['Mineral and other dietary supplements-0.0']==6)|(df['Mineral and other dietary supplements-0.1']==6)|(df['Mineral and other dietary supplements-0.2']==6)|(df['Mineral and other dietary supplements-0.3']==6)|(df['Mineral and other dietary supplements-0.4']==6)|(df['Mineral and other dietary supplements-0.5']==6)]=1
df['Cholesterol lowering medication-0.0']=df['Cholesterol lowering medication for female-0.0']
df['Cholesterol lowering medication-0.0'][df['Cholesterol lowering medication-0.0'].isna()]=df['Cholesterol lowering medication for male-0.0'][df['Cholesterol lowering medication-0.0'].isna()]
df['Blood pressure medication-0.0']=df['Blood pressure medication for female-0.0']
df['Blood pressure medication-0.0'][df['Blood pressure medication-0.0'].isna()]=df['Blood pressure medication for male-0.0'][df['Blood pressure medication-0.0'].isna()]
df['Insulin-0.0']=df['Insulin for female-0.0']
df['Insulin-0.0'][df['Insulin-0.0'].isna()]=df['Insulin for male-0.0'][df['Insulin-0.0'].isna()]
df['Mouth ulcers-0.0']=np.nan
df['Painful gums-0.0']=np.nan
df['Bleeding gums-0.0']=np.nan
df['Loose teeth-0.0']=np.nan
df['Toothache-0.0']=np.nan
df['Dentures-0.0']=np.nan
df['Mouth ulcers-0.0'][((df['Mouth/teeth dental problems-0.0']==0)|((df['Mouth/teeth dental problems-0.0']!=1)))&(df['Mouth/teeth dental problems-0.0'].notna())]=0
df['Mouth ulcers-0.0'][df['Mouth/teeth dental problems-0.0']==1]=1
df['Painful gums-0.0'][((df['Mouth/teeth dental problems-0.0']==0)|((df['Mouth/teeth dental problems-0.0']!=2)&(df['Mouth/teeth dental problems-0.1']!=2)))&(df['Mouth/teeth dental problems-0.0'].notna())]=0
df['Painful gums-0.0'][(df['Mouth/teeth dental problems-0.0']==2)|(df['Mouth/teeth dental problems-0.1']==2)]=1
df['Bleeding gums-0.0'][((df['Mouth/teeth dental problems-0.0']==0)|((df['Mouth/teeth dental problems-0.0']!=3)&(df['Mouth/teeth dental problems-0.1']!=3)&(df['Mouth/teeth dental problems-0.2']!=3)))&(df['Mouth/teeth dental problems-0.0'].notna())]=0
df['Bleeding gums-0.0'][(df['Mouth/teeth dental problems-0.0']==3)|(df['Mouth/teeth dental problems-0.1']==3)|(df['Mouth/teeth dental problems-0.2']==3)]=1
df['Loose teeth-0.0'][((df['Mouth/teeth dental problems-0.0']==0)|((df['Mouth/teeth dental problems-0.0']!=4)&(df['Mouth/teeth dental problems-0.1']!=4)&(df['Mouth/teeth dental problems-0.2']!=4)&(df['Mouth/teeth dental problems-0.3']!=4)))&(df['Mouth/teeth dental problems-0.0'].notna())]=0
df['Loose teeth-0.0'][(df['Mouth/teeth dental problems-0.0']==4)|(df['Mouth/teeth dental problems-0.1']==4)|(df['Mouth/teeth dental problems-0.2']==4)|(df['Mouth/teeth dental problems-0.3']==4)]=1
df['Toothache-0.0'][((df['Mouth/teeth dental problems-0.0']==0)|((df['Mouth/teeth dental problems-0.0']!=5)&(df['Mouth/teeth dental problems-0.1']!=5)&(df['Mouth/teeth dental problems-0.2']!=5)&(df['Mouth/teeth dental problems-0.3']!=5)&(df['Mouth/teeth dental problems-0.4']!=5)))&(df['Mouth/teeth dental problems-0.0'].notna())]=0
df['Toothache-0.0'][(df['Mouth/teeth dental problems-0.0']==5)|(df['Mouth/teeth dental problems-0.1']==5)|(df['Mouth/teeth dental problems-0.2']==5)|(df['Mouth/teeth dental problems-0.3']==5)|(df['Mouth/teeth dental problems-0.4']==5)]=1
df['Dentures-0.0'][((df['Mouth/teeth dental problems-0.0']==0)|((df['Mouth/teeth dental problems-0.0']!=6)&(df['Mouth/teeth dental problems-0.1']!=6)&(df['Mouth/teeth dental problems-0.2']!=6)&(df['Mouth/teeth dental problems-0.3']!=6)&(df['Mouth/teeth dental problems-0.4']!=6)&(df['Mouth/teeth dental problems-0.5']!=6)))&(df['Mouth/teeth dental problems-0.0'].notna())]=0
df['Dentures-0.0'][(df['Mouth/teeth dental problems-0.0']==6)|(df['Mouth/teeth dental problems-0.1']==6)|(df['Mouth/teeth dental problems-0.2']==6)|(df['Mouth/teeth dental problems-0.3']==6)|(df['Mouth/teeth dental problems-0.4']==6)|(df['Mouth/teeth dental problems-0.5']==6)]=1
df['Major operations-0.0']=df['Had major operations-0.0']
df['Major operations-0.0'][df['Major operations-0.0'].isna()]=df['Had other major operations-0.0'][df['Major operations-0.0'].isna()]
del df['Had major operations-0.0']
del df['Had other major operations-0.0']
df['Headache last month-0.0']=np.nan
df['Facial pain last month-0.0']=np.nan
df['Neck or shoulder pain last month-0.0']=np.nan
df['Back pain last month-0.0']=np.nan
df['Stomach or abdominal pain last month-0.0']=np.nan
df['Hip pain last month-0.0']=np.nan
df['Knee pain last month-0.0']=np.nan
df['Pain all over the body last month-0.0']=np.nan
df['Headache last month-0.0'][((df['Pain type(s) experienced in last month-0.0']==0)|((df['Pain type(s) experienced in last month-0.0']!=1)))&(df['Pain type(s) experienced in last month-0.0'].notna())]=0
df['Headache last month-0.0'][df['Pain type(s) experienced in last month-0.0']==1]=1
df['Facial pain last month-0.0'][((df['Pain type(s) experienced in last month-0.0']==0)|((df['Pain type(s) experienced in last month-0.0']!=2)&(df['Pain type(s) experienced in last month-0.1']!=2)))&(df['Pain type(s) experienced in last month-0.0'].notna())]=0
df['Facial pain last month-0.0'][(df['Pain type(s) experienced in last month-0.0']==2)|(df['Pain type(s) experienced in last month-0.1']==2)]=1
df['Neck or shoulder pain last month-0.0'][((df['Pain type(s) experienced in last month-0.0']==0)|((df['Pain type(s) experienced in last month-0.0']!=3)&(df['Pain type(s) experienced in last month-0.1']!=3)&(df['Pain type(s) experienced in last month-0.2']!=3)))&(df['Pain type(s) experienced in last month-0.0'].notna())]=0
df['Neck or shoulder pain last month-0.0'][(df['Pain type(s) experienced in last month-0.0']==3)|(df['Pain type(s) experienced in last month-0.1']==3)|(df['Pain type(s) experienced in last month-0.2']==3)]=1
df['Back pain last month-0.0'][((df['Pain type(s) experienced in last month-0.0']==0)|((df['Pain type(s) experienced in last month-0.0']!=4)&(df['Pain type(s) experienced in last month-0.1']!=4)&(df['Pain type(s) experienced in last month-0.2']!=4)&(df['Pain type(s) experienced in last month-0.3']!=4)))&(df['Pain type(s) experienced in last month-0.0'].notna())]=0
df['Back pain last month-0.0'][(df['Pain type(s) experienced in last month-0.0']==4)|(df['Pain type(s) experienced in last month-0.1']==4)|(df['Pain type(s) experienced in last month-0.2']==4)|(df['Pain type(s) experienced in last month-0.3']==4)]=1
df['Stomach or abdominal pain last month-0.0'][((df['Pain type(s) experienced in last month-0.0']==0)|((df['Pain type(s) experienced in last month-0.0']!=5)&(df['Pain type(s) experienced in last month-0.1']!=5)&(df['Pain type(s) experienced in last month-0.2']!=5)&(df['Pain type(s) experienced in last month-0.3']!=5)&(df['Pain type(s) experienced in last month-0.4']!=5)))&(df['Pain type(s) experienced in last month-0.0'].notna())]=0
df['Stomach or abdominal pain last month-0.0'][(df['Pain type(s) experienced in last month-0.0']==5)|(df['Pain type(s) experienced in last month-0.1']==5)|(df['Pain type(s) experienced in last month-0.2']==5)|(df['Pain type(s) experienced in last month-0.3']==5)|(df['Pain type(s) experienced in last month-0.4']==5)]=1
df['Hip pain last month-0.0'][((df['Pain type(s) experienced in last month-0.0']==0)|((df['Pain type(s) experienced in last month-0.0']!=6)&(df['Pain type(s) experienced in last month-0.1']!=6)&(df['Pain type(s) experienced in last month-0.2']!=6)&(df['Pain type(s) experienced in last month-0.3']!=6)&(df['Pain type(s) experienced in last month-0.4']!=6)&(df['Pain type(s) experienced in last month-0.5']!=6)))&(df['Pain type(s) experienced in last month-0.0'].notna())]=0
df['Hip pain last month-0.0'][(df['Pain type(s) experienced in last month-0.0']==6)|(df['Pain type(s) experienced in last month-0.1']==6)|(df['Pain type(s) experienced in last month-0.2']==6)|(df['Pain type(s) experienced in last month-0.3']==6)|(df['Pain type(s) experienced in last month-0.4']==6)|(df['Pain type(s) experienced in last month-0.5']==6)]=1
df['Knee pain last month-0.0'][((df['Pain type(s) experienced in last month-0.0']==0)|((df['Pain type(s) experienced in last month-0.0']!=7)&(df['Pain type(s) experienced in last month-0.1']!=7)&(df['Pain type(s) experienced in last month-0.2']!=7)&(df['Pain type(s) experienced in last month-0.3']!=7)&(df['Pain type(s) experienced in last month-0.4']!=7)&(df['Pain type(s) experienced in last month-0.5']!=7)&(df['Pain type(s) experienced in last month-0.6']!=7)))&(df['Pain type(s) experienced in last month-0.0'].notna())]=0
df['Knee pain last month-0.0'][(df['Pain type(s) experienced in last month-0.0']==7)|(df['Pain type(s) experienced in last month-0.1']==7)|(df['Pain type(s) experienced in last month-0.2']==7)|(df['Pain type(s) experienced in last month-0.3']==7)|(df['Pain type(s) experienced in last month-0.4']==7)|(df['Pain type(s) experienced in last month-0.5']==7)|(df['Pain type(s) experienced in last month-0.6']==7)]=1
df['Pain all over the body last month-0.0'][((df['Pain type(s) experienced in last month-0.0']==0)|((df['Pain type(s) experienced in last month-0.0']!=8)))&(df['Pain type(s) experienced in last month-0.0'].notna())]=0
df['Pain all over the body last month-0.0'][df['Pain type(s) experienced in last month-0.0']==8]=1
df['General pain-0.0']=np.nan
df['Neck/shoulder pain-0.0']=np.nan
df['Hip pain-0.0']=np.nan
df['Back pain-0.0']=np.nan
df['Stomach/abdominal pain-0.0']=np.nan
df['Knee pain-0.0']=np.nan
df['Headaches-0.0']=np.nan
df['Facial pains-0.0']=np.nan
df['General pain-0.0'][df['Pain all over the body last month-0.0']==0]=0
df['General pain-0.0'][(df['Pain all over the body last month-0.0']==1)&(df['General pain for 3+ months-0.0']==0)]=1
df['General pain-0.0'][(df['Pain all over the body last month-0.0']==1)&(df['General pain for 3+ months-0.0']==1)]=2
df['Neck/shoulder pain-0.0'][df['Neck or shoulder pain last month-0.0']==0]=0
df['Neck/shoulder pain-0.0'][(df['Neck or shoulder pain last month-0.0']==1)&(df['Neck/shoulder pain for 3+ months-0.0']==0)]=1
df['Neck/shoulder pain-0.0'][(df['Neck or shoulder pain last month-0.0']==1)&(df['Neck/shoulder pain for 3+ months-0.0']==1)]=2
df['Hip pain-0.0'][df['Hip pain last month-0.0']==0]=0
df['Hip pain-0.0'][(df['Hip pain last month-0.0']==1)&(df['Hip pain for 3+ months-0.0']==0)]=1
df['Hip pain-0.0'][(df['Hip pain last month-0.0']==1)&(df['Hip pain for 3+ months-0.0']==1)]=2
df['Back pain-0.0'][df['Back pain last month-0.0']==0]=0
df['Back pain-0.0'][(df['Back pain last month-0.0']==1)&(df['Back pain for 3+ months-0.0']==0)]=1
df['Back pain-0.0'][(df['Back pain last month-0.0']==1)&(df['Back pain for 3+ months-0.0']==1)]=2
df['Stomach/abdominal pain-0.0'][df['Stomach or abdominal pain last month-0.0']==0]=0
df['Stomach/abdominal pain-0.0'][(df['Stomach or abdominal pain last month-0.0']==1)&(df['Stomach/abdominal pain for 3+ months-0.0']==0)]=1
df['Stomach/abdominal pain-0.0'][(df['Stomach or abdominal pain last month-0.0']==1)&(df['Stomach/abdominal pain for 3+ months-0.0']==1)]=2
df['Knee pain-0.0'][df['Knee pain last month-0.0']==0]=0
df['Knee pain-0.0'][(df['Knee pain last month-0.0']==1)&(df['Knee pain for 3+ months-0.0']==0)]=1
df['Knee pain-0.0'][(df['Knee pain last month-0.0']==1)&(df['Knee pain for 3+ months-0.0']==1)]=2
df['Headaches-0.0'][df['Headache last month-0.0']==0]=0
df['Headaches-0.0'][(df['Headache last month-0.0']==1)&(df['Headaches for 3+ months-0.0']==0)]=1
df['Headaches-0.0'][(df['Headache last month-0.0']==1)&(df['Headaches for 3+ months-0.0']==1)]=2
df['Facial pains-0.0'][df['Facial pain last month-0.0']==0]=0
df['Facial pains-0.0'][(df['Facial pain last month-0.0']==1)&(df['Facial pains for 3+ months-0.0']==0)]=1
df['Facial pains-0.0'][(df['Facial pain last month-0.0']==1)&(df['Facial pains for 3+ months-0.0']==1)]=2
df['If bothered by diabetes related eye disease-0.0']=np.nan
df['If bothered by glaucoma-0.0']=np.nan
df['If bothered by injury or trauma resulting in loss of vision-0.0']=np.nan
df['If bothered by cataract-0.0']=np.nan
df['If bothered by macular degeneration-0.0']=np.nan
df['If bothered by other serious eye condition-0.0']=np.nan
df['If bothered by diabetes related eye disease-0.0'][((df['Eye problems/disorders-0.0']==0)|((df['Eye problems/disorders-0.0']!=1)))&(df['Eye problems/disorders-0.0'].notna())]=0
df['If bothered by diabetes related eye disease-0.0'][df['Eye problems/disorders-0.0']==1]=1
df['If bothered by glaucoma-0.0'][((df['Eye problems/disorders-0.0']==0)|((df['Eye problems/disorders-0.0']!=2)&(df['Eye problems/disorders-0.1']!=2)))&(df['Eye problems/disorders-0.0'].notna())]=0
df['If bothered by glaucoma-0.0'][(df['Eye problems/disorders-0.0']==2)|(df['Eye problems/disorders-0.1']==2)]=1
df['If bothered by injury or trauma resulting in loss of vision-0.0'][((df['Eye problems/disorders-0.0']==0)|((df['Eye problems/disorders-0.0']!=3)&(df['Eye problems/disorders-0.1']!=3)&(df['Eye problems/disorders-0.2']!=3)))&(df['Eye problems/disorders-0.0'].notna())]=0
df['If bothered by injury or trauma resulting in loss of vision-0.0'][(df['Eye problems/disorders-0.0']==3)|(df['Eye problems/disorders-0.1']==3)|(df['Eye problems/disorders-0.2']==3)]=1
df['If bothered by cataract-0.0'][((df['Eye problems/disorders-0.0']==0)|((df['Eye problems/disorders-0.0']!=4)&(df['Eye problems/disorders-0.1']!=4)&(df['Eye problems/disorders-0.2']!=4)&(df['Eye problems/disorders-0.3']!=4)))&(df['Eye problems/disorders-0.0'].notna())]=0
df['If bothered by cataract-0.0'][(df['Eye problems/disorders-0.0']==4)|(df['Eye problems/disorders-0.1']==4)|(df['Eye problems/disorders-0.2']==4)|(df['Eye problems/disorders-0.3']==4)]=1
df['If bothered by macular degeneration-0.0'][((df['Eye problems/disorders-0.0']==0)|((df['Eye problems/disorders-0.0']!=5)&(df['Eye problems/disorders-0.1']!=5)&(df['Eye problems/disorders-0.2']!=5)&(df['Eye problems/disorders-0.3']!=5)))&(df['Eye problems/disorders-0.0'].notna())]=0
df['If bothered by macular degeneration-0.0'][(df['Eye problems/disorders-0.0']==5)|(df['Eye problems/disorders-0.1']==5)|(df['Eye problems/disorders-0.2']==5)|(df['Eye problems/disorders-0.3']==5)]=1
df['If bothered by other serious eye condition-0.0'][((df['Eye problems/disorders-0.0']==0)|((df['Eye problems/disorders-0.0']!=6)&(df['Eye problems/disorders-0.1']!=6)&(df['Eye problems/disorders-0.2']!=6)&(df['Eye problems/disorders-0.3']!=6)&(df['Eye problems/disorders-0.4']!=6)))&(df['Eye problems/disorders-0.0'].notna())]=0
df['If bothered by other serious eye condition-0.0'][(df['Eye problems/disorders-0.0']==6)|(df['Eye problems/disorders-0.1']==6)|(df['Eye problems/disorders-0.2']==6)|(df['Eye problems/disorders-0.3']==6)|(df['Eye problems/disorders-0.4']==6)]=1
df['Age when diabetes-related eye disease diagnosed-0.0'][df['If bothered by diabetes related eye disease-0.0']==0]=0
df['Age glaucoma diagnosed-0.0'][df['If bothered by glaucoma-0.0']==0]=0
df['Age cataract diagnosed-0.0'][df['If bothered by cataract-0.0']==0]=0
df['Age when loss of vision due to injury or trauma diagnosed-0.0'][df['If bothered by injury or trauma resulting in loss of vision-0.0']==0]=0
df['Age macular degeneration diagnosed-0.0'][df['If bothered by macular degeneration-0.0']==0]=0
df['Age other serious eye condition diagnosed-0.0'][df['If bothered by other serious eye condition-0.0']==0]=0
df['Age started wearing glasses or contact lenses-0.0'][df['Wears glasses or contact lenses-0.0']==0]=0
df['Reason for glasses/contact lenses-0.0'][df['Wears glasses or contact lenses-0.0']==0]=0
df['For short-sightedness-0.0']=np.nan
df['For long-sightedness-0.0']=np.nan
df['For just reading/near work as you are getting older-0.0']=np.nan
df['For astigmatism-0.0']=np.nan
df['For a squint or turn in an eye since childhood-0.0']=np.nan
df['For a lazy eye or an eye with poor vision since childhood-0.0']=np.nan
df['Other eye condition-0.0']=np.nan
df['For short-sightedness-0.0'][((df['Reason for glasses/contact lenses-0.0']==0)|((df['Reason for glasses/contact lenses-0.0']!=1)))&(df['Reason for glasses/contact lenses-0.0'].notna())]=0
df['For short-sightedness-0.0'][df['Reason for glasses/contact lenses-0.0']==1]=1
df['For long-sightedness-0.0'][((df['Reason for glasses/contact lenses-0.0']==0)|((df['Reason for glasses/contact lenses-0.0']!=2)&(df['Reason for glasses/contact lenses-0.1']!=2)))&(df['Reason for glasses/contact lenses-0.0'].notna())]=0
df['For long-sightedness-0.0'][(df['Reason for glasses/contact lenses-0.0']==2)|(df['Reason for glasses/contact lenses-0.1']==2)]=1
df['For just reading/near work as you are getting older-0.0'][((df['Reason for glasses/contact lenses-0.0']==0)|((df['Reason for glasses/contact lenses-0.0']!=3)&(df['Reason for glasses/contact lenses-0.1']!=3)&(df['Reason for glasses/contact lenses-0.2']!=3)))&(df['Reason for glasses/contact lenses-0.0'].notna())]=0
df['For just reading/near work as you are getting older-0.0'][(df['Reason for glasses/contact lenses-0.0']==3)|(df['Reason for glasses/contact lenses-0.1']==3)|(df['Reason for glasses/contact lenses-0.2']==3)]=1
df['For astigmatism-0.0'][((df['Reason for glasses/contact lenses-0.0']==0)|((df['Reason for glasses/contact lenses-0.0']!=4)&(df['Reason for glasses/contact lenses-0.1']!=4)&(df['Reason for glasses/contact lenses-0.2']!=4)&(df['Reason for glasses/contact lenses-0.3']!=4)))&(df['Reason for glasses/contact lenses-0.0'].notna())]=0
df['For astigmatism-0.0'][(df['Reason for glasses/contact lenses-0.0']==4)|(df['Reason for glasses/contact lenses-0.1']==4)|(df['Reason for glasses/contact lenses-0.2']==4)|(df['Reason for glasses/contact lenses-0.3']==4)]=1
df['For a squint or turn in an eye since childhood-0.0'][((df['Reason for glasses/contact lenses-0.0']==0)|((df['Reason for glasses/contact lenses-0.0']!=5)&(df['Reason for glasses/contact lenses-0.1']!=5)&(df['Reason for glasses/contact lenses-0.2']!=5)&(df['Reason for glasses/contact lenses-0.3']!=5)&(df['Reason for glasses/contact lenses-0.4']!=5)))&(df['Reason for glasses/contact lenses-0.0'].notna())]=0
df['For a squint or turn in an eye since childhood-0.0'][(df['Reason for glasses/contact lenses-0.0']==5)|(df['Reason for glasses/contact lenses-0.1']==5)|(df['Reason for glasses/contact lenses-0.2']==5)|(df['Reason for glasses/contact lenses-0.3']==5)|(df['Reason for glasses/contact lenses-0.4']==5)]=1
df['For a lazy eye or an eye with poor vision since childhood-0.0'][((df['Reason for glasses/contact lenses-0.0']==0)|((df['Reason for glasses/contact lenses-0.0']!=6)&(df['Reason for glasses/contact lenses-0.1']!=6)&(df['Reason for glasses/contact lenses-0.2']!=6)&(df['Reason for glasses/contact lenses-0.3']!=6)&(df['Reason for glasses/contact lenses-0.4']!=6)&(df['Reason for glasses/contact lenses-0.5']!=6)))&(df['Reason for glasses/contact lenses-0.0'].notna())]=0
df['For a lazy eye or an eye with poor vision since childhood-0.0'][(df['Reason for glasses/contact lenses-0.0']==6)|(df['Reason for glasses/contact lenses-0.1']==6)|(df['Reason for glasses/contact lenses-0.2']==6)|(df['Reason for glasses/contact lenses-0.3']==6)|(df['Reason for glasses/contact lenses-0.4']==6)|(df['Reason for glasses/contact lenses-0.5']==6)]=1
df['Other eye condition-0.0'][((df['Reason for glasses/contact lenses-0.0']==0)|((df['Reason for glasses/contact lenses-0.0']!=7)&(df['Reason for glasses/contact lenses-0.1']!=7)&(df['Reason for glasses/contact lenses-0.2']!=7)&(df['Reason for glasses/contact lenses-0.3']!=7)&(df['Reason for glasses/contact lenses-0.4']!=7)&(df['Reason for glasses/contact lenses-0.5']!=7)))&(df['Reason for glasses/contact lenses-0.0'].notna())]=0
df['Other eye condition-0.0'][(df['Reason for glasses/contact lenses-0.0']==7)|(df['Reason for glasses/contact lenses-0.1']==7)|(df['Reason for glasses/contact lenses-0.2']==7)|(df['Reason for glasses/contact lenses-0.3']==7)|(df['Reason for glasses/contact lenses-0.4']==7)|(df['Reason for glasses/contact lenses-0.5']==7)]=1
df['Illnesses of father-0.0'][(df['Illnesses of father-0.0']==-17)&(df['Illnesses of father-0.1']==-27)]=0
df['Illnesses of mother-0.0'][(df['Illnesses of mother-0.0']==-17)&(df['Illnesses of father-0.1']==-27)]=0
df['Illnesses of siblings-0.0'][(df['Illnesses of siblings-0.0']==-17)&(df['Illnesses of siblings-0.1']==-27)]=0
df['Father Heart disease-0.0']=np.nan
df['Father Stroke-0.0']=np.nan
df['Father Lung cancer-0.0']=np.nan
df['Father Bowel cancer-0.0']=np.nan
df['Father Breast cancer-0.0']=np.nan
df['Father Chronic bronchitis/emphysema-0.0']=np.nan
df['Father High blood pressure-0.0']=np.nan
df['Father Diabetes-0.0']=np.nan
df['Father Alzheimers disease/dementia-0.0']=np.nan
df['Father Parkinsons disease-0.0']=np.nan
df['Father Severe depression-0.0']=np.nan
df['Father Prostate cancer-0.0']=np.nan
df['Father Heart disease-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=1)&(df['Illnesses of father-0.1']!=1)&(df['Illnesses of father-0.2']!=1)&(df['Illnesses of father-0.3']!=1)&(df['Illnesses of father-0.4']!=1)&(df['Illnesses of father-0.5']!=1)&(df['Illnesses of father-0.6']!=1)&(df['Illnesses of father-0.7']!=1)&(df['Illnesses of father-0.8']!=1)&(df['Illnesses of father-0.9']!=1)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Heart disease-0.0'][(df['Illnesses of father-0.0']==1)|(df['Illnesses of father-0.1']==1)|(df['Illnesses of father-0.2']==1)|(df['Illnesses of father-0.3']==1)|(df['Illnesses of father-0.4']==1)|(df['Illnesses of father-0.5']==1)|(df['Illnesses of father-0.6']==1)|(df['Illnesses of father-0.7']==1)|(df['Illnesses of father-0.8']==1)|(df['Illnesses of father-0.9']==1)]=1
df['Father Stroke-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=2)&(df['Illnesses of father-0.1']!=2)&(df['Illnesses of father-0.2']!=2)&(df['Illnesses of father-0.3']!=2)&(df['Illnesses of father-0.4']!=2)&(df['Illnesses of father-0.5']!=2)&(df['Illnesses of father-0.6']!=2)&(df['Illnesses of father-0.7']!=2)&(df['Illnesses of father-0.8']!=2)&(df['Illnesses of father-0.9']!=2)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Stroke-0.0'][(df['Illnesses of father-0.0']==2)|(df['Illnesses of father-0.1']==2)|(df['Illnesses of father-0.2']==2)|(df['Illnesses of father-0.3']==2)|(df['Illnesses of father-0.4']==2)|(df['Illnesses of father-0.5']==2)|(df['Illnesses of father-0.6']==2)|(df['Illnesses of father-0.7']==2)|(df['Illnesses of father-0.8']==2)|(df['Illnesses of father-0.9']==2)]=1
df['Father Lung cancer-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=3)&(df['Illnesses of father-0.1']!=3)&(df['Illnesses of father-0.2']!=3)&(df['Illnesses of father-0.3']!=3)&(df['Illnesses of father-0.4']!=3)&(df['Illnesses of father-0.5']!=3)&(df['Illnesses of father-0.6']!=3)&(df['Illnesses of father-0.7']!=3)&(df['Illnesses of father-0.8']!=3)&(df['Illnesses of father-0.9']!=3)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Lung cancer-0.0'][(df['Illnesses of father-0.0']==3)|(df['Illnesses of father-0.1']==3)|(df['Illnesses of father-0.2']==3)|(df['Illnesses of father-0.3']==3)|(df['Illnesses of father-0.4']==3)|(df['Illnesses of father-0.5']==3)|(df['Illnesses of father-0.6']==3)|(df['Illnesses of father-0.7']==3)|(df['Illnesses of father-0.8']==3)|(df['Illnesses of father-0.9']==3)]=1
df['Father Bowel cancer-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=4)&(df['Illnesses of father-0.1']!=4)&(df['Illnesses of father-0.2']!=4)&(df['Illnesses of father-0.3']!=4)&(df['Illnesses of father-0.4']!=4)&(df['Illnesses of father-0.5']!=4)&(df['Illnesses of father-0.6']!=4)&(df['Illnesses of father-0.7']!=4)&(df['Illnesses of father-0.8']!=4)&(df['Illnesses of father-0.9']!=4)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Bowel cancer-0.0'][(df['Illnesses of father-0.0']==4)|(df['Illnesses of father-0.1']==4)|(df['Illnesses of father-0.2']==4)|(df['Illnesses of father-0.3']==4)|(df['Illnesses of father-0.4']==4)|(df['Illnesses of father-0.5']==4)|(df['Illnesses of father-0.6']==4)|(df['Illnesses of father-0.7']==4)|(df['Illnesses of father-0.8']==4)|(df['Illnesses of father-0.9']==4)]=1
df['Father Breast cancer-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=5)&(df['Illnesses of father-0.1']!=5)&(df['Illnesses of father-0.2']!=5)&(df['Illnesses of father-0.3']!=5)&(df['Illnesses of father-0.4']!=5)&(df['Illnesses of father-0.5']!=5)&(df['Illnesses of father-0.6']!=5)&(df['Illnesses of father-0.7']!=5)&(df['Illnesses of father-0.8']!=5)&(df['Illnesses of father-0.9']!=5)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Breast cancer-0.0'][(df['Illnesses of father-0.0']==5)|(df['Illnesses of father-0.1']==5)|(df['Illnesses of father-0.2']==5)|(df['Illnesses of father-0.3']==5)|(df['Illnesses of father-0.4']==5)|(df['Illnesses of father-0.5']==5)|(df['Illnesses of father-0.6']==5)|(df['Illnesses of father-0.7']==5)|(df['Illnesses of father-0.8']==5)|(df['Illnesses of father-0.9']==5)]=1
df['Father Chronic bronchitis/emphysema-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=6)&(df['Illnesses of father-0.1']!=6)&(df['Illnesses of father-0.2']!=6)&(df['Illnesses of father-0.3']!=6)&(df['Illnesses of father-0.4']!=6)&(df['Illnesses of father-0.5']!=6)&(df['Illnesses of father-0.6']!=6)&(df['Illnesses of father-0.7']!=6)&(df['Illnesses of father-0.8']!=6)&(df['Illnesses of father-0.9']!=6)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Chronic bronchitis/emphysema-0.0'][(df['Illnesses of father-0.0']==6)|(df['Illnesses of father-0.1']==6)|(df['Illnesses of father-0.2']==6)|(df['Illnesses of father-0.3']==6)|(df['Illnesses of father-0.4']==6)|(df['Illnesses of father-0.5']==6)|(df['Illnesses of father-0.6']==6)|(df['Illnesses of father-0.7']==6)|(df['Illnesses of father-0.8']==6)|(df['Illnesses of father-0.9']==6)]=1
df['Father High blood pressure-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=8)&(df['Illnesses of father-0.1']!=8)&(df['Illnesses of father-0.2']!=8)&(df['Illnesses of father-0.3']!=8)&(df['Illnesses of father-0.4']!=8)&(df['Illnesses of father-0.5']!=8)&(df['Illnesses of father-0.6']!=8)&(df['Illnesses of father-0.7']!=8)&(df['Illnesses of father-0.8']!=8)&(df['Illnesses of father-0.9']!=8)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father High blood pressure-0.0'][(df['Illnesses of father-0.0']==8)|(df['Illnesses of father-0.1']==8)|(df['Illnesses of father-0.2']==8)|(df['Illnesses of father-0.3']==8)|(df['Illnesses of father-0.4']==8)|(df['Illnesses of father-0.5']==8)|(df['Illnesses of father-0.6']==8)|(df['Illnesses of father-0.7']==8)|(df['Illnesses of father-0.8']==8)|(df['Illnesses of father-0.9']==8)]=1
df['Father Diabetes-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=9)&(df['Illnesses of father-0.1']!=9)&(df['Illnesses of father-0.2']!=9)&(df['Illnesses of father-0.3']!=9)&(df['Illnesses of father-0.4']!=9)&(df['Illnesses of father-0.5']!=9)&(df['Illnesses of father-0.6']!=9)&(df['Illnesses of father-0.7']!=9)&(df['Illnesses of father-0.8']!=9)&(df['Illnesses of father-0.9']!=9)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Diabetes-0.0'][(df['Illnesses of father-0.0']==9)|(df['Illnesses of father-0.1']==9)|(df['Illnesses of father-0.2']==9)|(df['Illnesses of father-0.3']==9)|(df['Illnesses of father-0.4']==9)|(df['Illnesses of father-0.5']==9)|(df['Illnesses of father-0.6']==9)|(df['Illnesses of father-0.7']==9)|(df['Illnesses of father-0.8']==9)|(df['Illnesses of father-0.9']==9)]=1
df['Father Alzheimers disease/dementia-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=10)&(df['Illnesses of father-0.1']!=10)&(df['Illnesses of father-0.2']!=10)&(df['Illnesses of father-0.3']!=10)&(df['Illnesses of father-0.4']!=10)&(df['Illnesses of father-0.5']!=10)&(df['Illnesses of father-0.6']!=10)&(df['Illnesses of father-0.7']!=10)&(df['Illnesses of father-0.8']!=10)&(df['Illnesses of father-0.9']!=10)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Alzheimers disease/dementia-0.0'][(df['Illnesses of father-0.0']==10)|(df['Illnesses of father-0.1']==10)|(df['Illnesses of father-0.2']==10)|(df['Illnesses of father-0.3']==10)|(df['Illnesses of father-0.4']==10)|(df['Illnesses of father-0.5']==10)|(df['Illnesses of father-0.6']==10)|(df['Illnesses of father-0.7']==10)|(df['Illnesses of father-0.8']==10)|(df['Illnesses of father-0.9']==10)]=1
df['Father Parkinsons disease-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=11)&(df['Illnesses of father-0.1']!=11)&(df['Illnesses of father-0.2']!=11)&(df['Illnesses of father-0.3']!=11)&(df['Illnesses of father-0.4']!=11)&(df['Illnesses of father-0.5']!=11)&(df['Illnesses of father-0.6']!=11)&(df['Illnesses of father-0.7']!=11)&(df['Illnesses of father-0.8']!=11)&(df['Illnesses of father-0.9']!=11)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Parkinsons disease-0.0'][(df['Illnesses of father-0.0']==11)|(df['Illnesses of father-0.1']==11)|(df['Illnesses of father-0.2']==11)|(df['Illnesses of father-0.3']==11)|(df['Illnesses of father-0.4']==11)|(df['Illnesses of father-0.5']==11)|(df['Illnesses of father-0.6']==11)|(df['Illnesses of father-0.7']==11)|(df['Illnesses of father-0.8']==11)|(df['Illnesses of father-0.9']==11)]=1
df['Father Severe depression-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=12)&(df['Illnesses of father-0.1']!=12)&(df['Illnesses of father-0.2']!=12)&(df['Illnesses of father-0.3']!=12)&(df['Illnesses of father-0.4']!=12)&(df['Illnesses of father-0.5']!=12)&(df['Illnesses of father-0.6']!=12)&(df['Illnesses of father-0.7']!=12)&(df['Illnesses of father-0.8']!=12)&(df['Illnesses of father-0.9']!=12)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Severe depression-0.0'][(df['Illnesses of father-0.0']==12)|(df['Illnesses of father-0.1']==12)|(df['Illnesses of father-0.2']==12)|(df['Illnesses of father-0.3']==12)|(df['Illnesses of father-0.4']==12)|(df['Illnesses of father-0.5']==12)|(df['Illnesses of father-0.6']==12)|(df['Illnesses of father-0.7']==12)|(df['Illnesses of father-0.8']==12)|(df['Illnesses of father-0.9']==12)]=1
df['Father Prostate cancer-0.0'][((df['Illnesses of father-0.0']==0)|((df['Illnesses of father-0.0']!=13)&(df['Illnesses of father-0.1']!=13)&(df['Illnesses of father-0.2']!=13)&(df['Illnesses of father-0.3']!=13)&(df['Illnesses of father-0.4']!=13)&(df['Illnesses of father-0.5']!=13)&(df['Illnesses of father-0.6']!=13)&(df['Illnesses of father-0.7']!=13)&(df['Illnesses of father-0.8']!=13)&(df['Illnesses of father-0.9']!=13)))&(df['Illnesses of father-0.0'].notna())]=0
df['Father Prostate cancer-0.0'][(df['Illnesses of father-0.0']==13)|(df['Illnesses of father-0.1']==13)|(df['Illnesses of father-0.2']==13)|(df['Illnesses of father-0.3']==13)|(df['Illnesses of father-0.4']==13)|(df['Illnesses of father-0.5']==13)|(df['Illnesses of father-0.6']==13)|(df['Illnesses of father-0.7']==13)|(df['Illnesses of father-0.8']==13)|(df['Illnesses of father-0.9']==13)]=1
df['Mother Heart disease-0.0']=np.nan
df['Mother Stroke-0.0']=np.nan
df['Mother Lung cancer-0.0']=np.nan
df['Mother Bowel cancer-0.0']=np.nan
df['Mother Breast cancer-0.0']=np.nan
df['Mother Chronic bronchitis/emphysema-0.0']=np.nan
df['Mother High blood pressure-0.0']=np.nan
df['Mother Diabetes-0.0']=np.nan
df['Mother Alzheimers disease/dementia-0.0']=np.nan
df['Mother Parkinsons disease-0.0']=np.nan
df['Mother Severe depression-0.0']=np.nan
df['Mother Prostate cancer-0.0']=np.nan
df['Mother Heart disease-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=1)&(df['Illnesses of mother-0.1']!=1)&(df['Illnesses of mother-0.2']!=1)&(df['Illnesses of mother-0.3']!=1)&(df['Illnesses of mother-0.4']!=1)&(df['Illnesses of mother-0.5']!=1)&(df['Illnesses of mother-0.6']!=1)&(df['Illnesses of mother-0.7']!=1)&(df['Illnesses of mother-0.8']!=1)&(df['Illnesses of mother-0.9']!=1)&(df['Illnesses of mother-0.10']!=1)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Heart disease-0.0'][(df['Illnesses of mother-0.0']==1)|(df['Illnesses of mother-0.1']==1)|(df['Illnesses of mother-0.2']==1)|(df['Illnesses of mother-0.3']==1)|(df['Illnesses of mother-0.4']==1)|(df['Illnesses of mother-0.5']==1)|(df['Illnesses of mother-0.6']==1)|(df['Illnesses of mother-0.7']==1)|(df['Illnesses of mother-0.8']==1)|(df['Illnesses of mother-0.9']==1)|(df['Illnesses of mother-0.10']==1)]=1
df['Mother Stroke-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=2)&(df['Illnesses of mother-0.1']!=2)&(df['Illnesses of mother-0.2']!=2)&(df['Illnesses of mother-0.3']!=2)&(df['Illnesses of mother-0.4']!=2)&(df['Illnesses of mother-0.5']!=2)&(df['Illnesses of mother-0.6']!=2)&(df['Illnesses of mother-0.7']!=2)&(df['Illnesses of mother-0.8']!=2)&(df['Illnesses of mother-0.9']!=2)&(df['Illnesses of mother-0.10']!=2)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Stroke-0.0'][(df['Illnesses of mother-0.0']==2)|(df['Illnesses of mother-0.1']==2)|(df['Illnesses of mother-0.2']==2)|(df['Illnesses of mother-0.3']==2)|(df['Illnesses of mother-0.4']==2)|(df['Illnesses of mother-0.5']==2)|(df['Illnesses of mother-0.6']==2)|(df['Illnesses of mother-0.7']==2)|(df['Illnesses of mother-0.8']==2)|(df['Illnesses of mother-0.9']==2)|(df['Illnesses of mother-0.10']==2)]=1
df['Mother Lung cancer-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=3)&(df['Illnesses of mother-0.1']!=3)&(df['Illnesses of mother-0.2']!=3)&(df['Illnesses of mother-0.3']!=3)&(df['Illnesses of mother-0.4']!=3)&(df['Illnesses of mother-0.5']!=3)&(df['Illnesses of mother-0.6']!=3)&(df['Illnesses of mother-0.7']!=3)&(df['Illnesses of mother-0.8']!=3)&(df['Illnesses of mother-0.9']!=3)&(df['Illnesses of mother-0.10']!=3)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Lung cancer-0.0'][(df['Illnesses of mother-0.0']==3)|(df['Illnesses of mother-0.1']==3)|(df['Illnesses of mother-0.2']==3)|(df['Illnesses of mother-0.3']==3)|(df['Illnesses of mother-0.4']==3)|(df['Illnesses of mother-0.5']==3)|(df['Illnesses of mother-0.6']==3)|(df['Illnesses of mother-0.7']==3)|(df['Illnesses of mother-0.8']==3)|(df['Illnesses of mother-0.9']==3)|(df['Illnesses of mother-0.10']==3)]=1
df['Mother Bowel cancer-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=4)&(df['Illnesses of mother-0.1']!=4)&(df['Illnesses of mother-0.2']!=4)&(df['Illnesses of mother-0.3']!=4)&(df['Illnesses of mother-0.4']!=4)&(df['Illnesses of mother-0.5']!=4)&(df['Illnesses of mother-0.6']!=4)&(df['Illnesses of mother-0.7']!=4)&(df['Illnesses of mother-0.8']!=4)&(df['Illnesses of mother-0.9']!=4)&(df['Illnesses of mother-0.10']!=4)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Bowel cancer-0.0'][(df['Illnesses of mother-0.0']==4)|(df['Illnesses of mother-0.1']==4)|(df['Illnesses of mother-0.2']==4)|(df['Illnesses of mother-0.3']==4)|(df['Illnesses of mother-0.4']==4)|(df['Illnesses of mother-0.5']==4)|(df['Illnesses of mother-0.6']==4)|(df['Illnesses of mother-0.7']==4)|(df['Illnesses of mother-0.8']==4)|(df['Illnesses of mother-0.9']==4)|(df['Illnesses of mother-0.10']==4)]=1
df['Mother Breast cancer-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=5)&(df['Illnesses of mother-0.1']!=5)&(df['Illnesses of mother-0.2']!=5)&(df['Illnesses of mother-0.3']!=5)&(df['Illnesses of mother-0.4']!=5)&(df['Illnesses of mother-0.5']!=5)&(df['Illnesses of mother-0.6']!=5)&(df['Illnesses of mother-0.7']!=5)&(df['Illnesses of mother-0.8']!=5)&(df['Illnesses of mother-0.9']!=5)&(df['Illnesses of mother-0.10']!=5)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Breast cancer-0.0'][(df['Illnesses of mother-0.0']==5)|(df['Illnesses of mother-0.1']==5)|(df['Illnesses of mother-0.2']==5)|(df['Illnesses of mother-0.3']==5)|(df['Illnesses of mother-0.4']==5)|(df['Illnesses of mother-0.5']==5)|(df['Illnesses of mother-0.6']==5)|(df['Illnesses of mother-0.7']==5)|(df['Illnesses of mother-0.8']==5)|(df['Illnesses of mother-0.9']==5)|(df['Illnesses of mother-0.10']==5)]=1
df['Mother Chronic bronchitis/emphysema-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=6)&(df['Illnesses of mother-0.1']!=6)&(df['Illnesses of mother-0.2']!=6)&(df['Illnesses of mother-0.3']!=6)&(df['Illnesses of mother-0.4']!=6)&(df['Illnesses of mother-0.5']!=6)&(df['Illnesses of mother-0.6']!=6)&(df['Illnesses of mother-0.7']!=6)&(df['Illnesses of mother-0.8']!=6)&(df['Illnesses of mother-0.9']!=6)&(df['Illnesses of mother-0.10']!=6)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Chronic bronchitis/emphysema-0.0'][(df['Illnesses of mother-0.0']==6)|(df['Illnesses of mother-0.1']==6)|(df['Illnesses of mother-0.2']==6)|(df['Illnesses of mother-0.3']==6)|(df['Illnesses of mother-0.4']==6)|(df['Illnesses of mother-0.5']==6)|(df['Illnesses of mother-0.6']==6)|(df['Illnesses of mother-0.7']==6)|(df['Illnesses of mother-0.8']==6)|(df['Illnesses of mother-0.9']==6)|(df['Illnesses of mother-0.10']==6)]=1
df['Mother High blood pressure-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=8)&(df['Illnesses of mother-0.1']!=8)&(df['Illnesses of mother-0.2']!=8)&(df['Illnesses of mother-0.3']!=8)&(df['Illnesses of mother-0.4']!=8)&(df['Illnesses of mother-0.5']!=8)&(df['Illnesses of mother-0.6']!=8)&(df['Illnesses of mother-0.7']!=8)&(df['Illnesses of mother-0.8']!=8)&(df['Illnesses of mother-0.9']!=8)&(df['Illnesses of mother-0.10']!=8)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother High blood pressure-0.0'][(df['Illnesses of mother-0.0']==8)|(df['Illnesses of mother-0.1']==8)|(df['Illnesses of mother-0.2']==8)|(df['Illnesses of mother-0.3']==8)|(df['Illnesses of mother-0.4']==8)|(df['Illnesses of mother-0.5']==8)|(df['Illnesses of mother-0.6']==8)|(df['Illnesses of mother-0.7']==8)|(df['Illnesses of mother-0.8']==8)|(df['Illnesses of mother-0.9']==8)|(df['Illnesses of mother-0.10']==8)]=1
df['Mother Diabetes-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=9)&(df['Illnesses of mother-0.1']!=9)&(df['Illnesses of mother-0.2']!=9)&(df['Illnesses of mother-0.3']!=9)&(df['Illnesses of mother-0.4']!=9)&(df['Illnesses of mother-0.5']!=9)&(df['Illnesses of mother-0.6']!=9)&(df['Illnesses of mother-0.7']!=9)&(df['Illnesses of mother-0.8']!=9)&(df['Illnesses of mother-0.9']!=9)&(df['Illnesses of mother-0.10']!=9)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Diabetes-0.0'][(df['Illnesses of mother-0.0']==9)|(df['Illnesses of mother-0.1']==9)|(df['Illnesses of mother-0.2']==9)|(df['Illnesses of mother-0.3']==9)|(df['Illnesses of mother-0.4']==9)|(df['Illnesses of mother-0.5']==9)|(df['Illnesses of mother-0.6']==9)|(df['Illnesses of mother-0.7']==9)|(df['Illnesses of mother-0.8']==9)|(df['Illnesses of mother-0.9']==9)|(df['Illnesses of mother-0.10']==9)]=1
df['Mother Alzheimers disease/dementia-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=10)&(df['Illnesses of mother-0.1']!=10)&(df['Illnesses of mother-0.2']!=10)&(df['Illnesses of mother-0.3']!=10)&(df['Illnesses of mother-0.4']!=10)&(df['Illnesses of mother-0.5']!=10)&(df['Illnesses of mother-0.6']!=10)&(df['Illnesses of mother-0.7']!=10)&(df['Illnesses of mother-0.8']!=10)&(df['Illnesses of mother-0.9']!=10)&(df['Illnesses of mother-0.10']!=10)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Alzheimers disease/dementia-0.0'][(df['Illnesses of mother-0.0']==10)|(df['Illnesses of mother-0.1']==10)|(df['Illnesses of mother-0.2']==10)|(df['Illnesses of mother-0.3']==10)|(df['Illnesses of mother-0.4']==10)|(df['Illnesses of mother-0.5']==10)|(df['Illnesses of mother-0.6']==10)|(df['Illnesses of mother-0.7']==10)|(df['Illnesses of mother-0.8']==10)|(df['Illnesses of mother-0.9']==10)|(df['Illnesses of mother-0.10']==10)]=1
df['Mother Parkinsons disease-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=11)&(df['Illnesses of mother-0.1']!=11)&(df['Illnesses of mother-0.2']!=11)&(df['Illnesses of mother-0.3']!=11)&(df['Illnesses of mother-0.4']!=11)&(df['Illnesses of mother-0.5']!=11)&(df['Illnesses of mother-0.6']!=11)&(df['Illnesses of mother-0.7']!=11)&(df['Illnesses of mother-0.8']!=11)&(df['Illnesses of mother-0.9']!=11)&(df['Illnesses of mother-0.10']!=11)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Parkinsons disease-0.0'][(df['Illnesses of mother-0.0']==11)|(df['Illnesses of mother-0.1']==11)|(df['Illnesses of mother-0.2']==11)|(df['Illnesses of mother-0.3']==11)|(df['Illnesses of mother-0.4']==11)|(df['Illnesses of mother-0.5']==11)|(df['Illnesses of mother-0.6']==11)|(df['Illnesses of mother-0.7']==11)|(df['Illnesses of mother-0.8']==11)|(df['Illnesses of mother-0.9']==11)|(df['Illnesses of mother-0.10']==11)]=1
df['Mother Severe depression-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=12)&(df['Illnesses of mother-0.1']!=12)&(df['Illnesses of mother-0.2']!=12)&(df['Illnesses of mother-0.3']!=12)&(df['Illnesses of mother-0.4']!=12)&(df['Illnesses of mother-0.5']!=12)&(df['Illnesses of mother-0.6']!=12)&(df['Illnesses of mother-0.7']!=12)&(df['Illnesses of mother-0.8']!=12)&(df['Illnesses of mother-0.9']!=12)&(df['Illnesses of mother-0.10']!=12)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Severe depression-0.0'][(df['Illnesses of mother-0.0']==12)|(df['Illnesses of mother-0.1']==12)|(df['Illnesses of mother-0.2']==12)|(df['Illnesses of mother-0.3']==12)|(df['Illnesses of mother-0.4']==12)|(df['Illnesses of mother-0.5']==12)|(df['Illnesses of mother-0.6']==12)|(df['Illnesses of mother-0.7']==12)|(df['Illnesses of mother-0.8']==12)|(df['Illnesses of mother-0.9']==12)|(df['Illnesses of mother-0.10']==12)]=1
df['Mother Prostate cancer-0.0'][((df['Illnesses of mother-0.0']==0)|((df['Illnesses of mother-0.0']!=13)&(df['Illnesses of mother-0.1']!=13)&(df['Illnesses of mother-0.2']!=13)&(df['Illnesses of mother-0.3']!=13)&(df['Illnesses of mother-0.4']!=13)&(df['Illnesses of mother-0.5']!=13)&(df['Illnesses of mother-0.6']!=13)&(df['Illnesses of mother-0.7']!=13)&(df['Illnesses of mother-0.8']!=13)&(df['Illnesses of mother-0.9']!=13)&(df['Illnesses of mother-0.10']!=13)))&(df['Illnesses of mother-0.0'].notna())]=0
df['Mother Prostate cancer-0.0'][(df['Illnesses of mother-0.0']==13)|(df['Illnesses of mother-0.1']==13)|(df['Illnesses of mother-0.2']==13)|(df['Illnesses of mother-0.3']==13)|(df['Illnesses of mother-0.4']==13)|(df['Illnesses of mother-0.5']==13)|(df['Illnesses of mother-0.6']==13)|(df['Illnesses of mother-0.7']==13)|(df['Illnesses of mother-0.8']==13)|(df['Illnesses of mother-0.9']==13)|(df['Illnesses of mother-0.10']==13)]=1
df['Siblings Heart disease-0.0']=np.nan
df['Siblings Stroke-0.0']=np.nan
df['Siblings Lung cancer-0.0']=np.nan
df['Siblings Bowel cancer-0.0']=np.nan
df['Siblings Breast cancer-0.0']=np.nan
df['Siblings Chronic bronchitis/emphysema-0.0']=np.nan
df['Siblings High blood pressure-0.0']=np.nan
df['Siblings Diabetes-0.0']=np.nan
df['Siblings Alzheimers disease/dementia-0.0']=np.nan
df['Siblings Parkinsons disease-0.0']=np.nan
df['Siblings Severe depression-0.0']=np.nan
df['Siblings Prostate cancer-0.0']=np.nan
df['Siblings Heart disease-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=1)&(df['Illnesses of siblings-0.1']!=1)&(df['Illnesses of siblings-0.2']!=1)&(df['Illnesses of siblings-0.3']!=1)&(df['Illnesses of siblings-0.4']!=1)&(df['Illnesses of siblings-0.5']!=1)&(df['Illnesses of siblings-0.6']!=1)&(df['Illnesses of siblings-0.7']!=1)&(df['Illnesses of siblings-0.8']!=1)&(df['Illnesses of siblings-0.9']!=1)&(df['Illnesses of siblings-0.10']!=1)&(df['Illnesses of siblings-0.11']!=1)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Heart disease-0.0'][(df['Illnesses of siblings-0.0']==1)|(df['Illnesses of siblings-0.1']==1)|(df['Illnesses of siblings-0.2']==1)|(df['Illnesses of siblings-0.3']==1)|(df['Illnesses of siblings-0.4']==1)|(df['Illnesses of siblings-0.5']==1)|(df['Illnesses of siblings-0.6']==1)|(df['Illnesses of siblings-0.7']==1)|(df['Illnesses of siblings-0.8']==1)|(df['Illnesses of siblings-0.9']==1)|(df['Illnesses of siblings-0.10']==1)|(df['Illnesses of siblings-0.11']==1)]=1
df['Siblings Stroke-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=2)&(df['Illnesses of siblings-0.1']!=2)&(df['Illnesses of siblings-0.2']!=2)&(df['Illnesses of siblings-0.3']!=2)&(df['Illnesses of siblings-0.4']!=2)&(df['Illnesses of siblings-0.5']!=2)&(df['Illnesses of siblings-0.6']!=2)&(df['Illnesses of siblings-0.7']!=2)&(df['Illnesses of siblings-0.8']!=2)&(df['Illnesses of siblings-0.9']!=2)&(df['Illnesses of siblings-0.10']!=2)&(df['Illnesses of siblings-0.11']!=2)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Stroke-0.0'][(df['Illnesses of siblings-0.0']==2)|(df['Illnesses of siblings-0.1']==2)|(df['Illnesses of siblings-0.2']==2)|(df['Illnesses of siblings-0.3']==2)|(df['Illnesses of siblings-0.4']==2)|(df['Illnesses of siblings-0.5']==2)|(df['Illnesses of siblings-0.6']==2)|(df['Illnesses of siblings-0.7']==2)|(df['Illnesses of siblings-0.8']==2)|(df['Illnesses of siblings-0.9']==2)|(df['Illnesses of siblings-0.10']==2)|(df['Illnesses of siblings-0.11']==2)]=1
df['Siblings Lung cancer-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=3)&(df['Illnesses of siblings-0.1']!=3)&(df['Illnesses of siblings-0.2']!=3)&(df['Illnesses of siblings-0.3']!=3)&(df['Illnesses of siblings-0.4']!=3)&(df['Illnesses of siblings-0.5']!=3)&(df['Illnesses of siblings-0.6']!=3)&(df['Illnesses of siblings-0.7']!=3)&(df['Illnesses of siblings-0.8']!=3)&(df['Illnesses of siblings-0.9']!=3)&(df['Illnesses of siblings-0.10']!=3)&(df['Illnesses of siblings-0.11']!=3)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Lung cancer-0.0'][(df['Illnesses of siblings-0.0']==3)|(df['Illnesses of siblings-0.1']==3)|(df['Illnesses of siblings-0.2']==3)|(df['Illnesses of siblings-0.3']==3)|(df['Illnesses of siblings-0.4']==3)|(df['Illnesses of siblings-0.5']==3)|(df['Illnesses of siblings-0.6']==3)|(df['Illnesses of siblings-0.7']==3)|(df['Illnesses of siblings-0.8']==3)|(df['Illnesses of siblings-0.9']==3)|(df['Illnesses of siblings-0.10']==3)|(df['Illnesses of siblings-0.11']==3)]=1
df['Siblings Bowel cancer-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=4)&(df['Illnesses of siblings-0.1']!=4)&(df['Illnesses of siblings-0.2']!=4)&(df['Illnesses of siblings-0.3']!=4)&(df['Illnesses of siblings-0.4']!=4)&(df['Illnesses of siblings-0.5']!=4)&(df['Illnesses of siblings-0.6']!=4)&(df['Illnesses of siblings-0.7']!=4)&(df['Illnesses of siblings-0.8']!=4)&(df['Illnesses of siblings-0.9']!=4)&(df['Illnesses of siblings-0.10']!=4)&(df['Illnesses of siblings-0.11']!=4)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Bowel cancer-0.0'][(df['Illnesses of siblings-0.0']==4)|(df['Illnesses of siblings-0.1']==4)|(df['Illnesses of siblings-0.2']==4)|(df['Illnesses of siblings-0.3']==4)|(df['Illnesses of siblings-0.4']==4)|(df['Illnesses of siblings-0.5']==4)|(df['Illnesses of siblings-0.6']==4)|(df['Illnesses of siblings-0.7']==4)|(df['Illnesses of siblings-0.8']==4)|(df['Illnesses of siblings-0.9']==4)|(df['Illnesses of siblings-0.10']==4)|(df['Illnesses of siblings-0.11']==4)]=1
df['Siblings Breast cancer-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=5)&(df['Illnesses of siblings-0.1']!=5)&(df['Illnesses of siblings-0.2']!=5)&(df['Illnesses of siblings-0.3']!=5)&(df['Illnesses of siblings-0.4']!=5)&(df['Illnesses of siblings-0.5']!=5)&(df['Illnesses of siblings-0.6']!=5)&(df['Illnesses of siblings-0.7']!=5)&(df['Illnesses of siblings-0.8']!=5)&(df['Illnesses of siblings-0.9']!=5)&(df['Illnesses of siblings-0.10']!=5)&(df['Illnesses of siblings-0.11']!=5)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Breast cancer-0.0'][(df['Illnesses of siblings-0.0']==5)|(df['Illnesses of siblings-0.1']==5)|(df['Illnesses of siblings-0.2']==5)|(df['Illnesses of siblings-0.3']==5)|(df['Illnesses of siblings-0.4']==5)|(df['Illnesses of siblings-0.5']==5)|(df['Illnesses of siblings-0.6']==5)|(df['Illnesses of siblings-0.7']==5)|(df['Illnesses of siblings-0.8']==5)|(df['Illnesses of siblings-0.9']==5)|(df['Illnesses of siblings-0.10']==5)|(df['Illnesses of siblings-0.11']==5)]=1
df['Siblings Chronic bronchitis/emphysema-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=6)&(df['Illnesses of siblings-0.1']!=6)&(df['Illnesses of siblings-0.2']!=6)&(df['Illnesses of siblings-0.3']!=6)&(df['Illnesses of siblings-0.4']!=6)&(df['Illnesses of siblings-0.5']!=6)&(df['Illnesses of siblings-0.6']!=6)&(df['Illnesses of siblings-0.7']!=6)&(df['Illnesses of siblings-0.8']!=6)&(df['Illnesses of siblings-0.9']!=6)&(df['Illnesses of siblings-0.10']!=6)&(df['Illnesses of siblings-0.11']!=6)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Chronic bronchitis/emphysema-0.0'][(df['Illnesses of siblings-0.0']==6)|(df['Illnesses of siblings-0.1']==6)|(df['Illnesses of siblings-0.2']==6)|(df['Illnesses of siblings-0.3']==6)|(df['Illnesses of siblings-0.4']==6)|(df['Illnesses of siblings-0.5']==6)|(df['Illnesses of siblings-0.6']==6)|(df['Illnesses of siblings-0.7']==6)|(df['Illnesses of siblings-0.8']==6)|(df['Illnesses of siblings-0.9']==6)|(df['Illnesses of siblings-0.10']==6)|(df['Illnesses of siblings-0.11']==6)]=1
df['Siblings High blood pressure-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=8)&(df['Illnesses of siblings-0.1']!=8)&(df['Illnesses of siblings-0.2']!=8)&(df['Illnesses of siblings-0.3']!=8)&(df['Illnesses of siblings-0.4']!=8)&(df['Illnesses of siblings-0.5']!=8)&(df['Illnesses of siblings-0.6']!=8)&(df['Illnesses of siblings-0.7']!=8)&(df['Illnesses of siblings-0.8']!=8)&(df['Illnesses of siblings-0.9']!=8)&(df['Illnesses of siblings-0.10']!=8)&(df['Illnesses of siblings-0.11']!=8)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings High blood pressure-0.0'][(df['Illnesses of siblings-0.0']==8)|(df['Illnesses of siblings-0.1']==8)|(df['Illnesses of siblings-0.2']==8)|(df['Illnesses of siblings-0.3']==8)|(df['Illnesses of siblings-0.4']==8)|(df['Illnesses of siblings-0.5']==8)|(df['Illnesses of siblings-0.6']==8)|(df['Illnesses of siblings-0.7']==8)|(df['Illnesses of siblings-0.8']==8)|(df['Illnesses of siblings-0.9']==8)|(df['Illnesses of siblings-0.10']==8)|(df['Illnesses of siblings-0.11']==8)]=1
df['Siblings Diabetes-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=9)&(df['Illnesses of siblings-0.1']!=9)&(df['Illnesses of siblings-0.2']!=9)&(df['Illnesses of siblings-0.3']!=9)&(df['Illnesses of siblings-0.4']!=9)&(df['Illnesses of siblings-0.5']!=9)&(df['Illnesses of siblings-0.6']!=9)&(df['Illnesses of siblings-0.7']!=9)&(df['Illnesses of siblings-0.8']!=9)&(df['Illnesses of siblings-0.9']!=9)&(df['Illnesses of siblings-0.10']!=9)&(df['Illnesses of siblings-0.11']!=9)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Diabetes-0.0'][(df['Illnesses of siblings-0.0']==9)|(df['Illnesses of siblings-0.1']==9)|(df['Illnesses of siblings-0.2']==9)|(df['Illnesses of siblings-0.3']==9)|(df['Illnesses of siblings-0.4']==9)|(df['Illnesses of siblings-0.5']==9)|(df['Illnesses of siblings-0.6']==9)|(df['Illnesses of siblings-0.7']==9)|(df['Illnesses of siblings-0.8']==9)|(df['Illnesses of siblings-0.9']==9)|(df['Illnesses of siblings-0.10']==9)|(df['Illnesses of siblings-0.11']==9)]=1
df['Siblings Alzheimers disease/dementia-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=10)&(df['Illnesses of siblings-0.1']!=10)&(df['Illnesses of siblings-0.2']!=10)&(df['Illnesses of siblings-0.3']!=10)&(df['Illnesses of siblings-0.4']!=10)&(df['Illnesses of siblings-0.5']!=10)&(df['Illnesses of siblings-0.6']!=10)&(df['Illnesses of siblings-0.7']!=10)&(df['Illnesses of siblings-0.8']!=10)&(df['Illnesses of siblings-0.9']!=10)&(df['Illnesses of siblings-0.10']!=10)&(df['Illnesses of siblings-0.11']!=10)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Alzheimers disease/dementia-0.0'][(df['Illnesses of siblings-0.0']==10)|(df['Illnesses of siblings-0.1']==10)|(df['Illnesses of siblings-0.2']==10)|(df['Illnesses of siblings-0.3']==10)|(df['Illnesses of siblings-0.4']==10)|(df['Illnesses of siblings-0.5']==10)|(df['Illnesses of siblings-0.6']==10)|(df['Illnesses of siblings-0.7']==10)|(df['Illnesses of siblings-0.8']==10)|(df['Illnesses of siblings-0.9']==10)|(df['Illnesses of siblings-0.10']==10)|(df['Illnesses of siblings-0.11']==10)]=1
df['Siblings Parkinsons disease-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=11)&(df['Illnesses of siblings-0.1']!=11)&(df['Illnesses of siblings-0.2']!=11)&(df['Illnesses of siblings-0.3']!=11)&(df['Illnesses of siblings-0.4']!=11)&(df['Illnesses of siblings-0.5']!=11)&(df['Illnesses of siblings-0.6']!=11)&(df['Illnesses of siblings-0.7']!=11)&(df['Illnesses of siblings-0.8']!=11)&(df['Illnesses of siblings-0.9']!=11)&(df['Illnesses of siblings-0.10']!=11)&(df['Illnesses of siblings-0.11']!=11)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Parkinsons disease-0.0'][(df['Illnesses of siblings-0.0']==11)|(df['Illnesses of siblings-0.1']==11)|(df['Illnesses of siblings-0.2']==11)|(df['Illnesses of siblings-0.3']==11)|(df['Illnesses of siblings-0.4']==11)|(df['Illnesses of siblings-0.5']==11)|(df['Illnesses of siblings-0.6']==11)|(df['Illnesses of siblings-0.7']==11)|(df['Illnesses of siblings-0.8']==11)|(df['Illnesses of siblings-0.9']==11)|(df['Illnesses of siblings-0.10']==11)|(df['Illnesses of siblings-0.11']==11)]=1
df['Siblings Severe depression-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=12)&(df['Illnesses of siblings-0.1']!=12)&(df['Illnesses of siblings-0.2']!=12)&(df['Illnesses of siblings-0.3']!=12)&(df['Illnesses of siblings-0.4']!=12)&(df['Illnesses of siblings-0.5']!=12)&(df['Illnesses of siblings-0.6']!=12)&(df['Illnesses of siblings-0.7']!=12)&(df['Illnesses of siblings-0.8']!=12)&(df['Illnesses of siblings-0.9']!=12)&(df['Illnesses of siblings-0.10']!=12)&(df['Illnesses of siblings-0.11']!=12)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Severe depression-0.0'][(df['Illnesses of siblings-0.0']==12)|(df['Illnesses of siblings-0.1']==12)|(df['Illnesses of siblings-0.2']==12)|(df['Illnesses of siblings-0.3']==12)|(df['Illnesses of siblings-0.4']==12)|(df['Illnesses of siblings-0.5']==12)|(df['Illnesses of siblings-0.6']==12)|(df['Illnesses of siblings-0.7']==12)|(df['Illnesses of siblings-0.8']==12)|(df['Illnesses of siblings-0.9']==12)|(df['Illnesses of siblings-0.10']==12)|(df['Illnesses of siblings-0.11']==12)]=1
df['Siblings Prostate cancer-0.0'][((df['Illnesses of siblings-0.0']==0)|((df['Illnesses of siblings-0.0']!=13)&(df['Illnesses of siblings-0.1']!=13)&(df['Illnesses of siblings-0.2']!=13)&(df['Illnesses of siblings-0.3']!=13)&(df['Illnesses of siblings-0.4']!=13)&(df['Illnesses of siblings-0.5']!=13)&(df['Illnesses of siblings-0.6']!=13)&(df['Illnesses of siblings-0.7']!=13)&(df['Illnesses of siblings-0.8']!=13)&(df['Illnesses of siblings-0.9']!=13)&(df['Illnesses of siblings-0.10']!=13)&(df['Illnesses of siblings-0.11']!=13)))&(df['Illnesses of siblings-0.0'].notna())]=0
df['Siblings Prostate cancer-0.0'][(df['Illnesses of siblings-0.0']==13)|(df['Illnesses of siblings-0.1']==13)|(df['Illnesses of siblings-0.2']==13)|(df['Illnesses of siblings-0.3']==13)|(df['Illnesses of siblings-0.4']==13)|(df['Illnesses of siblings-0.5']==13)|(df['Illnesses of siblings-0.6']==13)|(df['Illnesses of siblings-0.7']==13)|(df['Illnesses of siblings-0.8']==13)|(df['Illnesses of siblings-0.9']==13)|(df['Illnesses of siblings-0.10']==13)|(df['Illnesses of siblings-0.11']==13)]=1
df['Mothers age-0.0'][df['Mother still alive-0.0']==0]=80
df['Fathers age-0.0'][df['Father still alive-0.0']==0]=80
df['Pulse rate, automated reading-0.0'][df['Pulse rate, automated reading-0.0'].isna()]=df['Pulse rate (during blood-pressure measurement)-0.0'][df['Pulse rate, automated reading-0.0'].isna()]
df['Pulse rate, automated reading-0.1'][df['Pulse rate, automated reading-0.1'].isna()]=df['Pulse rate (during blood-pressure measurement)-0.1'][df['Pulse rate, automated reading-0.1'].isna()]
df['Diastolic blood pressure, automated reading-0.0'][df['Diastolic blood pressure, automated reading-0.0'].isna()]=df['Diastolic blood pressure, manual reading-0.0'][df['Diastolic blood pressure, automated reading-0.0'].isna()]
df['Diastolic blood pressure, automated reading-0.1'][df['Diastolic blood pressure, automated reading-0.1'].isna()]=df['Diastolic blood pressure, manual reading-0.1'][df['Diastolic blood pressure, automated reading-0.1'].isna()]
df['Systolic blood pressure, automated reading-0.0'][df['Systolic blood pressure, automated reading-0.0'].isna()]=df['Systolic blood pressure, manual reading-0.0'][df['Systolic blood pressure, automated reading-0.0'].isna()]
df['Systolic blood pressure, automated reading-0.1'][df['Systolic blood pressure, automated reading-0.1'].isna()]=df['Systolic blood pressure, manual reading-0.1'][df['Systolic blood pressure, automated reading-0.1'].isna()]
df['Pulse rate-0.0']=(df['Pulse rate, automated reading-0.0'][df['Pulse rate, automated reading-0.0'].notna()]+df['Pulse rate, automated reading-0.1'][df['Pulse rate, automated reading-0.1'].notna()])/2
df['Diastolic blood pressure-0.0']=(df['Diastolic blood pressure, automated reading-0.0'][df['Diastolic blood pressure, automated reading-0.0'].notna()]+df['Diastolic blood pressure, automated reading-0.1'][df['Diastolic blood pressure, automated reading-0.1'].notna()])/2
df['Systolic blood pressure-0.0']=(df['Systolic blood pressure, automated reading-0.0'][df['Systolic blood pressure, automated reading-0.0'].notna()]+df['Systolic blood pressure, automated reading-0.1'][df['Systolic blood pressure, automated reading-0.1'].notna()])/2
df['Tinnitus-0.0'][df['Tinnitus-0.0']==11]=1
df['Tinnitus severity/nuisance-0.0'][df['Tinnitus severity/nuisance-0.0']==11]=1
df['Tinnitus-0.0'][df['Tinnitus-0.0']==12]=2
df['Tinnitus severity/nuisance-0.0'][df['Tinnitus severity/nuisance-0.0']==12]=2
df['Tinnitus-0.0'][df['Tinnitus-0.0']==13]=3
df['Tinnitus severity/nuisance-0.0'][df['Tinnitus severity/nuisance-0.0']==13]=3
df['Tinnitus-0.0'][df['Tinnitus-0.0']==4]=0
df['Tinnitus severity/nuisance-0.0'][df['Tinnitus severity/nuisance-0.0']==4]=0
df['Tinnitus-0.0'][df['Tinnitus-0.0']==14]=4
df['Tinnitus severity/nuisance-0.0'][df['Tinnitus severity/nuisance-0.0']==14]=4
df['Tinnitus severity/nuisance-0.0'][df['Tinnitus-0.0']==0]=0
df[df<0]=np.nan
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
df = df.drop(df.columns[[1,2,3,4,12,13,30,34,35,36,37,39,41,43,45,46,47,48,53,54,55,65,72,73,74,75,76,79,80,81,86,87,90,91,92,94,95,97,99,243,244,245,259,260,261]+[i for i in range(278,286)]+[i for i in range(66,71)]+[i for i in range(101,193)]],axis = 1)
dfillness=df.iloc[:,[45,46]+[i for i in range(57,95)]]
df = df.drop(df.columns[[45,46]+[i for i in range(57,95)]],axis = 1)
dfillness['Category of illness about cardiovascular-0']=50
dfillness.replace(1065,11,inplace=True)
dfillness.replace(1072,11,inplace=True)
dfillness.replace(1066,11,inplace=True)
dfillness.replace(1074,11,inplace=True)
dfillness.replace(1073,11,inplace=True)
dfillness.replace(1075,11,inplace=True)
dfillness.replace(1076,11,inplace=True)
dfillness.replace(1077,11,inplace=True)
dfillness.replace(1078,11,inplace=True)
dfillness.replace(1471,11,inplace=True)
dfillness.replace(1483,11,inplace=True)
dfillness.replace(1484,11,inplace=True)
dfillness.replace(1485,11,inplace=True)
dfillness.replace(1486,11,inplace=True)
dfillness.replace(1487,11,inplace=True)
dfillness.replace(1584,11,inplace=True)
dfillness.replace(1488,11,inplace=True)
dfillness.replace(1489,11,inplace=True)
dfillness.replace(1585,11,inplace=True)
dfillness.replace(1586,11,inplace=True)
dfillness.replace(1490,11,inplace=True)
dfillness.replace(1587,11,inplace=True)
dfillness.replace(1588,11,inplace=True)
dfillness.replace(1080,11,inplace=True)
dfillness.replace(1589,11,inplace=True)
dfillness.replace(1590,11,inplace=True)
dfillness.replace(1426,11,inplace=True)
dfillness.replace(1479,11,inplace=True)
dfillness.replace(1073,11,inplace=True)
dfillness.replace(1073,11,inplace=True)
dfillness.replace(1081,11,inplace=True)
dfillness.replace(1086,11,inplace=True)
dfillness.replace(1491,11,inplace=True)
dfillness.replace(1583,11,inplace=True)
dfillness.replace(1082,11,inplace=True)
dfillness.replace(1083,11,inplace=True)
dfillness.replace(1425,11,inplace=True)
dfillness.replace(1067,11,inplace=True)
dfillness.replace(1087,11,inplace=True)
dfillness.replace(1088,11,inplace=True)
dfillness.replace(1492,11,inplace=True)
dfillness.replace(1591,11,inplace=True)
dfillness.replace(1592,11,inplace=True)
dfillness.replace(1068,11,inplace=True)
dfillness.replace(1093,11,inplace=True)
dfillness.replace(1094,11,inplace=True)
dfillness.replace(1473,11,inplace=True)
dfillness.replace(1493,11,inplace=True)
dfillness.replace(1494,11,inplace=True)
dfillness.replace(1495,11,inplace=True)
dfillness.replace(1593,11,inplace=True)
dfillness['Number of illness about cardiovascular-0']=np.nan
dfillness['Number of illness about cardiovascular-0']=(dfillness == 11).astype(int).sum(axis=1)
dfillness['Category of illness about respiratory or ent-0']=36
dfillness.replace(1111,12,inplace=True)
dfillness.replace(1112,12,inplace=True)
dfillness.replace(1113,12,inplace=True)
dfillness.replace(1412,12,inplace=True)
dfillness.replace(1472,12,inplace=True)
dfillness.replace(1496,12,inplace=True)
dfillness.replace(1114,12,inplace=True)
dfillness.replace(1115,12,inplace=True)
dfillness.replace(1116,12,inplace=True)
dfillness.replace(1120,12,inplace=True)
dfillness.replace(1121,12,inplace=True)
dfillness.replace(1122,12,inplace=True)
dfillness.replace(1123,12,inplace=True)
dfillness.replace(1124,12,inplace=True)
dfillness.replace(1125,12,inplace=True)
dfillness.replace(1126,12,inplace=True)
dfillness.replace(1595,12,inplace=True)
dfillness.replace(1596,12,inplace=True)
dfillness.replace(1413,12,inplace=True)
dfillness.replace(1416,12,inplace=True)
dfillness.replace(1417,12,inplace=True)
dfillness.replace(1414,12,inplace=True)
dfillness.replace(1418,12,inplace=True)
dfillness.replace(1419,12,inplace=True)
dfillness.replace(1598,12,inplace=True)
dfillness.replace(1415,12,inplace=True)
dfillness.replace(1420,12,inplace=True)
dfillness.replace(1421,12,inplace=True)
dfillness.replace(1499,12,inplace=True)
dfillness.replace(1500,12,inplace=True)
dfillness.replace(1597,12,inplace=True)
dfillness.replace(1594,12,inplace=True)
dfillness.replace(1398,12,inplace=True)
dfillness.replace(1411,12,inplace=True)
dfillness.replace(1498,12,inplace=True)
dfillness['Number of illness about respiratory or ent-0']=np.nan
dfillness['Number of illness about respiratory or ent-0']=(dfillness == 12).astype(int).sum(axis=1)
dfillness['Category of illness about gastrointestinal or abdominal-0']=61
dfillness.replace(1134,13,inplace=True)
dfillness.replace(1138,13,inplace=True)
dfillness.replace(1139,13,inplace=True)
dfillness.replace(1140,13,inplace=True)
dfillness.replace(1141,13,inplace=True)
dfillness.replace(1474,13,inplace=True)
dfillness.replace(1135,13,inplace=True)
dfillness.replace(1142,13,inplace=True)
dfillness.replace(1143,13,inplace=True)
dfillness.replace(1501,13,inplace=True)
dfillness.replace(1154,13,inplace=True)
dfillness.replace(1456,13,inplace=True)
dfillness.replace(1457,13,inplace=True)
dfillness.replace(1458,13,inplace=True)
dfillness.replace(1459,13,inplace=True)
dfillness.replace(1460,13,inplace=True)
dfillness.replace(1461,13,inplace=True)
dfillness.replace(1462,13,inplace=True)
dfillness.replace(1463,13,inplace=True)
dfillness.replace(1502,13,inplace=True)
dfillness.replace(1503,13,inplace=True)
dfillness.replace(1504,13,inplace=True)
dfillness.replace(1505,13,inplace=True)
dfillness.replace(1599,13,inplace=True)
dfillness.replace(1600,13,inplace=True)
dfillness.replace(1601,13,inplace=True)
dfillness.replace(1602,13,inplace=True)
dfillness.replace(1603,13,inplace=True)
dfillness.replace(1136,13,inplace=True)
dfillness.replace(1155,13,inplace=True)
dfillness.replace(1156,13,inplace=True)
dfillness.replace(1578,13,inplace=True)
dfillness.replace(1579,13,inplace=True)
dfillness.replace(1580,13,inplace=True)
dfillness.replace(1581,13,inplace=True)
dfillness.replace(1582,13,inplace=True)
dfillness.replace(1157,13,inplace=True)
dfillness.replace(1158,13,inplace=True)
dfillness.replace(1506,13,inplace=True)
dfillness.replace(1604,13,inplace=True)
dfillness.replace(1159,13,inplace=True)
dfillness.replace(1160,13,inplace=True)
dfillness.replace(1475,13,inplace=True)
dfillness.replace(1161,13,inplace=True)
dfillness.replace(1162,13,inplace=True)
dfillness.replace(1163,13,inplace=True)
dfillness.replace(1164,13,inplace=True)
dfillness.replace(1165,13,inplace=True)
dfillness.replace(1507,13,inplace=True)
dfillness.replace(1508,13,inplace=True)
dfillness.replace(1137,13,inplace=True)
dfillness.replace(1190,13,inplace=True)
dfillness.replace(1191,13,inplace=True)
dfillness.replace(1400,13,inplace=True)
dfillness.replace(1509,13,inplace=True)
dfillness.replace(1510,13,inplace=True)
dfillness.replace(1511,13,inplace=True)
dfillness.replace(1512,13,inplace=True)
dfillness.replace(1513,13,inplace=True)
dfillness.replace(1605,13,inplace=True)
dfillness.replace(1606,13,inplace=True)
dfillness['Number of illness about gastrointestinal or abdominal-0']=np.nan
dfillness['Number of illness about gastrointestinal or abdominal-0']=(dfillness == 13).astype(int).sum(axis=1)
dfillness['Category of illness about renal or urology-0']=27
dfillness.replace(1192,14,inplace=True)
dfillness.replace(1193,14,inplace=True)
dfillness.replace(1194,14,inplace=True)
dfillness.replace(1196,14,inplace=True)
dfillness.replace(1514,14,inplace=True)
dfillness.replace(1515,14,inplace=True)
dfillness.replace(1197,14,inplace=True)
dfillness.replace(1200,14,inplace=True)
dfillness.replace(1201,14,inplace=True)
dfillness.replace(1202,14,inplace=True)
dfillness.replace(1207,14,inplace=True)
dfillness.replace(1396,14,inplace=True)
dfillness.replace(1516,14,inplace=True)
dfillness.replace(1517,14,inplace=True)
dfillness.replace(1210,14,inplace=True)
dfillness.replace(1214,14,inplace=True)
dfillness.replace(1403,14,inplace=True)
dfillness.replace(1518,14,inplace=True)
dfillness.replace(1679,14,inplace=True)
dfillness.replace(1405,14,inplace=True)
dfillness.replace(1427,14,inplace=True)
dfillness.replace(1519,14,inplace=True)
dfillness.replace(1520,14,inplace=True)
dfillness.replace(1607,14,inplace=True)
dfillness.replace(1608,14,inplace=True)
dfillness.replace(1609,14,inplace=True)
dfillness['Number of illness about renal or urology-0']=np.nan
dfillness['Number of illness about renal or urology-0']=(dfillness == 14).astype(int).sum(axis=1)
dfillness['Category of illness about endocrine or diabetes-0']=28
dfillness.replace(1220,15,inplace=True)
dfillness.replace(1221,15,inplace=True)
dfillness.replace(1222,15,inplace=True)
dfillness.replace(1223,15,inplace=True)
dfillness.replace(1521,15,inplace=True)
dfillness.replace(1224,15,inplace=True)
dfillness.replace(1225,15,inplace=True)
dfillness.replace(1226,15,inplace=True)
dfillness.replace(1228,15,inplace=True)
dfillness.replace(1428,15,inplace=True)
dfillness.replace(1522,15,inplace=True)
dfillness.replace(1610,15,inplace=True)
dfillness.replace(1229,15,inplace=True)
dfillness.replace(1230,15,inplace=True)
dfillness.replace(1611,15,inplace=True)
dfillness.replace(1232,15,inplace=True)
dfillness.replace(1233,15,inplace=True)
dfillness.replace(1234,15,inplace=True)
dfillness.replace(1235,15,inplace=True)
dfillness.replace(1236,15,inplace=True)
dfillness.replace(1237,15,inplace=True)
dfillness.replace(1238,15,inplace=True)
dfillness.replace(1429,15,inplace=True)
dfillness.replace(1430,15,inplace=True)
dfillness.replace(1431,15,inplace=True)
dfillness.replace(1239,15,inplace=True)
dfillness.replace(1432,15,inplace=True)
dfillness.replace(1682,15,inplace=True)
dfillness['Number of illness about endocrine or diabetes-0']=np.nan
dfillness['Number of illness about endocrine or diabetes-0']=(dfillness == 15).astype(int).sum(axis=1)
dfillness['Category of illness about neurology or eye or psychiatry-0']=68
dfillness.replace(1244,16,inplace=True)
dfillness.replace(1245,16,inplace=True)
dfillness.replace(1246,16,inplace=True)
dfillness.replace(1247,16,inplace=True)
dfillness.replace(1248,16,inplace=True)
dfillness.replace(1249,16,inplace=True)
dfillness.replace(1250,16,inplace=True)
dfillness.replace(1523,16,inplace=True)
dfillness.replace(1251,16,inplace=True)
dfillness.replace(1252,16,inplace=True)
dfillness.replace(1524,16,inplace=True)
dfillness.replace(1254,16,inplace=True)
dfillness.replace(1255,16,inplace=True)
dfillness.replace(1256,16,inplace=True)
dfillness.replace(1257,16,inplace=True)
dfillness.replace(1468,16,inplace=True)
dfillness.replace(1258,16,inplace=True)
dfillness.replace(1259,16,inplace=True)
dfillness.replace(1260,16,inplace=True)
dfillness.replace(1261,16,inplace=True)
dfillness.replace(1262,16,inplace=True)
dfillness.replace(1263,16,inplace=True)
dfillness.replace(1397,16,inplace=True)
dfillness.replace(1264,16,inplace=True)
dfillness.replace(1265,16,inplace=True)
dfillness.replace(1433,16,inplace=True)
dfillness.replace(1434,16,inplace=True)
dfillness.replace(1436,16,inplace=True)
dfillness.replace(1437,16,inplace=True)
dfillness.replace(1525,16,inplace=True)
dfillness.replace(1526,16,inplace=True)
dfillness.replace(1659,16,inplace=True)
dfillness.replace(1683,16,inplace=True)
dfillness.replace(1240,16,inplace=True)
dfillness.replace(1266,16,inplace=True)
dfillness.replace(1267,16,inplace=True)
dfillness.replace(1394,16,inplace=True)
dfillness.replace(1242,16,inplace=True)
dfillness.replace(1274,16,inplace=True)
dfillness.replace(1275,16,inplace=True)
dfillness.replace(1281,16,inplace=True)
dfillness.replace(1282,16,inplace=True)
dfillness.replace(1527,16,inplace=True)
dfillness.replace(1528,16,inplace=True)
dfillness.replace(1276,16,inplace=True)
dfillness.replace(1277,16,inplace=True)
dfillness.replace(1278,16,inplace=True)
dfillness.replace(1279,16,inplace=True)
dfillness.replace(1435,16,inplace=True)
dfillness.replace(1529,16,inplace=True)
dfillness.replace(1530,16,inplace=True)
dfillness.replace(1613,16,inplace=True)
dfillness.replace(1243,16,inplace=True)
dfillness.replace(1286,16,inplace=True)
dfillness.replace(1531,16,inplace=True)
dfillness.replace(1287,16,inplace=True)
dfillness.replace(1288,16,inplace=True)
dfillness.replace(1289,16,inplace=True)
dfillness.replace(1290,16,inplace=True)
dfillness.replace(1291,16,inplace=True)
dfillness.replace(1408,16,inplace=True)
dfillness.replace(1409,16,inplace=True)
dfillness.replace(1410,16,inplace=True)
dfillness.replace(1469,16,inplace=True)
dfillness.replace(1470,16,inplace=True)
dfillness.replace(1614,16,inplace=True)
dfillness.replace(1615,16,inplace=True)
dfillness.replace(1616,16,inplace=True)
dfillness['Number of illness about neurology or eye or psychiatry-0']=np.nan
dfillness['Number of illness about neurology or eye or psychiatry-0']=(dfillness == 16).astype(int).sum(axis=1)
dfillness['Category of illness about musculoskeletal or trauma-0']=68
dfillness.replace(1293,17,inplace=True)
dfillness.replace(1309,17,inplace=True)
dfillness.replace(1308,17,inplace=True)
dfillness.replace(1310,17,inplace=True)
dfillness.replace(1617,17,inplace=True)
dfillness.replace(1294,17,inplace=True)
dfillness.replace(1311,17,inplace=True)
dfillness.replace(1313,17,inplace=True)
dfillness.replace(1476,17,inplace=True)
dfillness.replace(1532,17,inplace=True)
dfillness.replace(1312,17,inplace=True)
dfillness.replace(1533,17,inplace=True)
dfillness.replace(1534,17,inplace=True)
dfillness.replace(1535,17,inplace=True)
dfillness.replace(1536,17,inplace=True)
dfillness.replace(1295,17,inplace=True)
dfillness.replace(1464,17,inplace=True)
dfillness.replace(1465,17,inplace=True)
dfillness.replace(1466,17,inplace=True)
dfillness.replace(1467,17,inplace=True)
dfillness.replace(1537,17,inplace=True)
dfillness.replace(1477,17,inplace=True)
dfillness.replace(1538,17,inplace=True)
dfillness.replace(1297,17,inplace=True)
dfillness.replace(1322,17,inplace=True)
dfillness.replace(1406,17,inplace=True)
dfillness.replace(1540,17,inplace=True)
dfillness.replace(1541,17,inplace=True)
dfillness.replace(1542,17,inplace=True)
dfillness.replace(1544,17,inplace=True)
dfillness.replace(1618,17,inplace=True)
dfillness.replace(1619,17,inplace=True)
dfillness.replace(1620,17,inplace=True)
dfillness.replace(1624,17,inplace=True)
dfillness.replace(1619,17,inplace=True)
dfillness.replace(1622,17,inplace=True)
dfillness.replace(1623,17,inplace=True)
dfillness.replace(1407,17,inplace=True)
dfillness.replace(1545,17,inplace=True)
dfillness.replace(1478,17,inplace=True)
dfillness.replace(1626,17,inplace=True)
dfillness.replace(1627,17,inplace=True)
dfillness.replace(1628,17,inplace=True)
dfillness.replace(1629,17,inplace=True)
dfillness.replace(1630,17,inplace=True)
dfillness.replace(1631,17,inplace=True)
dfillness.replace(1632,17,inplace=True)
dfillness.replace(1633,17,inplace=True)
dfillness.replace(1634,17,inplace=True)
dfillness.replace(1635,17,inplace=True)
dfillness.replace(1636,17,inplace=True)
dfillness.replace(1637,17,inplace=True)
dfillness.replace(1638,17,inplace=True)
dfillness.replace(1639,17,inplace=True)
dfillness.replace(1640,17,inplace=True)
dfillness.replace(1644,17,inplace=True)
dfillness.replace(1645,17,inplace=True)
dfillness.replace(1646,17,inplace=True)
dfillness.replace(1647,17,inplace=True)
dfillness.replace(1648,17,inplace=True)
dfillness.replace(1649,17,inplace=True)
dfillness.replace(1650,17,inplace=True)
dfillness.replace(1651,17,inplace=True)
dfillness.replace(1652,17,inplace=True)
dfillness.replace(1653,17,inplace=True)
dfillness.replace(1654,17,inplace=True)
dfillness.replace(1655,17,inplace=True)
dfillness.replace(1656,17,inplace=True)
dfillness['Number of illness about musculoskeletal or trauma-0']=np.nan
dfillness['Number of illness about musculoskeletal or trauma-0']=(dfillness == 17).astype(int).sum(axis=1)
dfillness['Category of illness about haematology or dermatology-0']=31
dfillness.replace(1445,18,inplace=True)
dfillness.replace(1327,18,inplace=True)
dfillness.replace(1328,18,inplace=True)
dfillness.replace(1546,18,inplace=True)
dfillness.replace(1446,18,inplace=True)
dfillness.replace(1330,18,inplace=True)
dfillness.replace(1331,18,inplace=True)
dfillness.replace(1332,18,inplace=True)
dfillness.replace(1447,18,inplace=True)
dfillness.replace(1448,18,inplace=True)
dfillness.replace(1449,18,inplace=True)
dfillness.replace(1438,18,inplace=True)
dfillness.replace(1658,18,inplace=True)
dfillness.replace(1450,18,inplace=True)
dfillness.replace(1451,18,inplace=True)
dfillness.replace(1339,18,inplace=True)
dfillness.replace(1340,18,inplace=True)
dfillness.replace(1452,18,inplace=True)
dfillness.replace(1453,18,inplace=True)
dfillness.replace(1454,18,inplace=True)
dfillness.replace(1344,18,inplace=True)
dfillness.replace(1345,18,inplace=True)
dfillness.replace(1455,18,inplace=True)
dfillness.replace(1548,18,inplace=True)
dfillness.replace(1549,18,inplace=True)
dfillness.replace(1550,18,inplace=True)
dfillness.replace(1625,18,inplace=True)
dfillness.replace(1660,18,inplace=True)
dfillness.replace(1661,18,inplace=True)
dfillness.replace(1667,18,inplace=True)
dfillness.replace(1680,18,inplace=True)
dfillness['Number of illness about haematology or dermatology-0']=np.nan
dfillness['Number of illness about haematology or dermatology-0']=(dfillness == 18).astype(int).sum(axis=1)
dfillness['Category of illness about gynaecology or breast-0']=27
dfillness.replace(1348,19,inplace=True)
dfillness.replace(1403,19,inplace=True)
dfillness.replace(1551,19,inplace=True)
dfillness.replace(1349,19,inplace=True)
dfillness.replace(1681,19,inplace=True)
dfillness.replace(1350,19,inplace=True)
dfillness.replace(1552,19,inplace=True)
dfillness.replace(1351,19,inplace=True)
dfillness.replace(1352,19,inplace=True)
dfillness.replace(1353,19,inplace=True)
dfillness.replace(1402,19,inplace=True)
dfillness.replace(1553,19,inplace=True)
dfillness.replace(1554,19,inplace=True)
dfillness.replace(1663,19,inplace=True)
dfillness.replace(1555,19,inplace=True)
dfillness.replace(1662,19,inplace=True)
dfillness.replace(1556,19,inplace=True)
dfillness.replace(1557,19,inplace=True)
dfillness.replace(1664,19,inplace=True)
dfillness.replace(1665,19,inplace=True)
dfillness.replace(1364,19,inplace=True)
dfillness.replace(1366,19,inplace=True)
dfillness.replace(1367,19,inplace=True)
dfillness.replace(1560,19,inplace=True)
dfillness.replace(1666,19,inplace=True)
dfillness.replace(1558,19,inplace=True)
dfillness.replace(1559,19,inplace=True)
dfillness['Number of illness about gynaecology or breast-0']=np.nan
dfillness['Number of illness about gynaecology or breast-0']=(dfillness == 19).astype(int).sum(axis=1)
dfillness['Category of illness about immunological or systemic disorders-0']=27
dfillness.replace(1371,20,inplace=True)
dfillness.replace(1373,20,inplace=True)
dfillness.replace(1372,20,inplace=True)
dfillness.replace(1376,20,inplace=True)
dfillness.replace(1377,20,inplace=True)
dfillness.replace(1378,20,inplace=True)
dfillness.replace(1379,20,inplace=True)
dfillness.replace(1380,20,inplace=True)
dfillness.replace(1381,20,inplace=True)
dfillness.replace(1382,20,inplace=True)
dfillness.replace(1383,20,inplace=True)
dfillness.replace(1480,20,inplace=True)
dfillness.replace(1481,20,inplace=True)
dfillness.replace(1384,20,inplace=True)
dfillness.replace(1561,20,inplace=True)
dfillness.replace(1374,20,inplace=True)
dfillness.replace(1385,20,inplace=True)
dfillness.replace(1386,20,inplace=True)
dfillness.replace(1387,20,inplace=True)
dfillness.replace(1562,20,inplace=True)
dfillness.replace(1563,20,inplace=True)
dfillness.replace(1668,20,inplace=True)
dfillness.replace(1669,20,inplace=True)
dfillness.replace(1670,20,inplace=True)
dfillness.replace(1671,20,inplace=True)
dfillness.replace(1482,20,inplace=True)
dfillness.replace(1564,20,inplace=True)
dfillness['Number of illness about immunological or systemic disorders-0']=np.nan
dfillness['Number of illness about immunological or systemic disorders-0']=(dfillness == 20).astype(int).sum(axis=1)
dfillness['Number of illness about unclassifiable-0']=np.nan
dfillness['Number of illness about unclassifiable-0']=(dfillness == 99999).astype(int).sum(axis=1)
dfillness['Category of illness about infections-0']=23
dfillness.replace(1657,21,inplace=True)
dfillness.replace(1439,21,inplace=True)
dfillness.replace(1568,21,inplace=True)
dfillness.replace(1570,21,inplace=True)
dfillness.replace(1674,21,inplace=True)
dfillness.replace(1571,21,inplace=True)
dfillness.replace(1573,21,inplace=True)
dfillness.replace(1575,21,inplace=True)
dfillness.replace(1567,21,inplace=True)
dfillness.replace(1569,21,inplace=True)
dfillness.replace(1566,21,inplace=True)
dfillness.replace(1442,21,inplace=True)
dfillness.replace(1440,21,inplace=True)
dfillness.replace(1574,21,inplace=True)
dfillness.replace(1572,21,inplace=True)
dfillness.replace(1677,21,inplace=True)
dfillness.replace(1678,21,inplace=True)
dfillness.replace(1441,21,inplace=True)
dfillness.replace(1443,21,inplace=True)
dfillness.replace(1576,21,inplace=True)
dfillness.replace(1577,21,inplace=True)
dfillness.replace(1675,21,inplace=True)
dfillness.replace(1676,21,inplace=True)
dfillness['Number of illness about infections-0']=np.nan
dfillness['Number of illness about infections-0']=(dfillness == 21).astype(int).sum(axis=1)
dfillness['Category of ear,nose or throat cancer-0']=12
dfillness.replace(1004,1,inplace=True)
dfillness.replace(1005,1,inplace=True)
dfillness.replace(1015,1,inplace=True)
dfillness.replace(1016,1,inplace=True)
dfillness.replace(1010,1,inplace=True)
dfillness.replace(1011,1,inplace=True)
dfillness.replace(1012,1,inplace=True)
dfillness.replace(1077,1,inplace=True)
dfillness.replace(1078,1,inplace=True)
dfillness.replace(1079,1,inplace=True)
dfillness.replace(1007,1,inplace=True)
dfillness.replace(1009,1,inplace=True)
dfillness['Number of ear,nose or throat cancer-0']=np.nan
dfillness['Number of ear,nose or throat cancer-0']=(dfillness == 1).astype(int).sum(axis=1)
dfillness['Category of gastrointestinal cancer-0']=12
dfillness.replace(1017,2,inplace=True)
dfillness.replace(1018,2,inplace=True)
dfillness.replace(1019,2,inplace=True)
dfillness.replace(1020,2,inplace=True)
dfillness.replace(1022,2,inplace=True)
dfillness.replace(1086,2,inplace=True)
dfillness.replace(1023,2,inplace=True)
dfillness.replace(1021,2,inplace=True)
dfillness.replace(1024,2,inplace=True)
dfillness.replace(1025,2,inplace=True)
dfillness.replace(1026,2,inplace=True)
dfillness.replace(1088,2,inplace=True)
dfillness['Number of gastrointestinal cancer-0']=np.nan
dfillness['Number of gastrointestinal cancer-0']=(dfillness == 2).astype(int).sum(axis=1)
dfillness['Category of neurological system cancer-0']=6
dfillness.replace(1029,3,inplace=True)
dfillness.replace(1030,3,inplace=True)
dfillness.replace(1075,3,inplace=True)
dfillness.replace(1031,3,inplace=True)
dfillness.replace(1032,3,inplace=True)
dfillness.replace(1033,3,inplace=True)
dfillness['Number of neurological system cancer-0']=np.nan
dfillness['Number of neurological system cancer-0']=(dfillness == 3).astype(int).sum(axis=1)
dfillness['Category of urinary tract cancer-0']=3
dfillness.replace(1034,4,inplace=True)
dfillness.replace(1035,4,inplace=True)
dfillness.replace(1036,4,inplace=True)
dfillness['Number of urinary tract cancer-0']=np.nan
dfillness['Number of urinary tract cancer-0']=(dfillness == 4).astype(int).sum(axis=1)
dfillness['Category of breast cancer-0']=1
dfillness['Number of breast cancer-0']=np.nan
dfillness['Number of breast cancer-0']=(dfillness == 1002).astype(int).sum(axis=1)
dfillness['Category of genital tract cancer-0']=12
dfillness.replace(1037,5,inplace=True)
dfillness.replace(1039,5,inplace=True)
dfillness.replace(1040,5,inplace=True)
dfillness.replace(1041,5,inplace=True)
dfillness.replace(1072,5,inplace=True)
dfillness.replace(1042,5,inplace=True)
dfillness.replace(1043,5,inplace=True)
dfillness.replace(1087,5,inplace=True)
dfillness.replace(1038,5,inplace=True)
dfillness.replace(1044,5,inplace=True)
dfillness.replace(1045,5,inplace=True)
dfillness.replace(1046,5,inplace=True)
dfillness['Number of genital tract cancer-0']=np.nan
dfillness['Number of genital tract cancer-0']=(dfillness == 5).astype(int).sum(axis=1)
dfillness['Category of haematological malignancy-0']=10
dfillness.replace(1047,11,inplace=True)
dfillness.replace(1052,11,inplace=True)
dfillness.replace(1053,11,inplace=True)
dfillness.replace(1074,11,inplace=True)
dfillness.replace(1055,11,inplace=True)
dfillness.replace(1056,11,inplace=True)
dfillness.replace(1074,11,inplace=True)
dfillness.replace(1050,11,inplace=True)
dfillness.replace(1051,11,inplace=True)
dfillness.replace(1058,11,inplace=True)
dfillness['Number of haematological malignancy-0']=np.nan
dfillness['Number of haematological malignancy-0']=(dfillness == 11).astype(int).sum(axis=1)
dfillness['Category of skin cancer-0']=6
dfillness.replace(1003,7,inplace=True)
dfillness.replace(1059,7,inplace=True)
dfillness.replace(1060,7,inplace=True)
dfillness.replace(1061,7,inplace=True)
dfillness.replace(1073,7,inplace=True)
dfillness.replace(1062,7,inplace=True)
dfillness['Number of skin cancer-0']=np.nan
dfillness['Number of skin cancer-0']=(dfillness == 7).astype(int).sum(axis=1)
dfillness['Category of other cancer-0']=10
dfillness.replace(1063,8,inplace=True)
dfillness.replace(1064,8,inplace=True)
dfillness.replace(1065,8,inplace=True)
dfillness.replace(1066,8,inplace=True)
dfillness.replace(1067,8,inplace=True)
dfillness.replace(1068,8,inplace=True)
dfillness.replace(1070,8,inplace=True)
dfillness.replace(1071,8,inplace=True)
dfillness.replace(1085,8,inplace=True)
dfillness.replace(1076,8,inplace=True)
dfillness['Number of other cancer-0']=np.nan
dfillness['Number of other cancer-0']=(dfillness == 8).astype(int).sum(axis=1)
dfillness['Category of respiratory or intrathoracic cancer-0']=9
dfillness.replace(1084,19,inplace=True)
dfillness.replace(1001,19,inplace=True)
dfillness.replace(1027,19,inplace=True)
dfillness.replace(1028,19,inplace=True)
dfillness.replace(1006,19,inplace=True)
dfillness.replace(1008,19,inplace=True)
dfillness.replace(1080,19,inplace=True)
dfillness.replace(1081,19,inplace=True)
dfillness.replace(1082,19,inplace=True)
dfillness['Number of respiratory or intrathoracic cancer-0']=np.nan
dfillness['Number of respiratory or intrathoracic cancer-0']=(dfillness == 19).astype(int).sum(axis=1)
dfillness['Number of unclassifiable cancer-0']=np.nan
dfillness['Number of unclassifiable cancer-0']=(dfillness == 99999).astype(int).sum(axis=1)
dfillness=dfillness.iloc[:,40:84]
var=[1,18,19,20,25,26,27,37,38,39,41,44,47,48,58,59,60,63,64,65,82,83,84,85,90,92,93,96,100,113,114,115,116,119,120,121,122,131,132,133,134]+[i for i in range(148,153)]+[i for i in range(136,147)]+[i for i in range(124,129)]+[i for i in range(103,110)]+[i for i in range(30,35)]+[i for i in range(51,56)]+[i for i in range(70,79)]
pd.concat([df.iloc[:,var],dfillness],axis=1).to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Female-specific factors
j=19
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21003','Age when attended assessment centre')
    i=i.replace('41222','Delivery onset methods')
    i=i.replace('3882','Age at bilateral oophorectomy (both ovaries removed)')
    i=i.replace('3872','Age of primiparous women at birth of child')
    i=i.replace('3849','Number of pregnancy terminations')
    i=i.replace('3839','Number of spontaneous miscarriages')
    i=i.replace('3829','Number of stillbirths')
    i=i.replace('3720','Menstruating today')
    i=i.replace('3710','Length of menstrual cycle')
    i=i.replace('3700','Time since last menstrual period')
    i=i.replace('3591','Ever had hysterectomy (womb removed)')
    i=i.replace('3546','Age last used hormone-replacement therapy (HRT)')
    i=i.replace('3536','Age started hormone-replacement therapy (HRT)')
    i=i.replace('2834','Bilateral oophorectomy (both ovaries removed)')
    i=i.replace('2824','Age at hysterectomy')
    i=i.replace('2814','Ever used hormone-replacement therapy (HRT)')
    i=i.replace('2804','Age when last used oral contraceptive pill')
    i=i.replace('2794','Age started oral contraceptive pill')
    i=i.replace('2784','Ever taken oral contraceptive pill')
    i=i.replace('2774','Ever had stillbirth, spontaneous miscarriage or termination')
    i=i.replace('2764','Age at last live birth')
    i=i.replace('2754','Age at first live birth')
    i=i.replace('2744','Birth weight of first child')
    i=i.replace('2734','Number of live births')
    i=i.replace('2724','Had menopause')
    i=i.replace('2714','Age when periods started (menarche)')
    i=i.replace('21026','Discomfort/pain occurring only during menstrual bleed')
    i=i.replace('4041','Gestational diabetes only')
    d.append(i)
df.columns=d
df['Had menopause-0.0'][df['Had menopause-0.0']==3]=np.nan
df['Age when last used oral contraceptive pill-0.0'][df['Age when last used oral contraceptive pill-0.0']==-11]=df['Age when attended assessment centre-0.0'][df['Age when last used oral contraceptive pill-0.0']==-11]
df['Age last used hormone-replacement therapy (HRT)-0.0'][df['Age last used hormone-replacement therapy (HRT)-0.0']==-11]=df['Age when attended assessment centre-0.0'][df['Age last used hormone-replacement therapy (HRT)-0.0']==-11]
df['Age started oral contraceptive pill-0.0'][df['Ever taken oral contraceptive pill-0.0']==0]=0
df['Age when last used oral contraceptive pill-0.0'][df['Ever taken oral contraceptive pill-0.0']==0]=0
df['Number of pregnancy terminations-0.0'][df['Ever had stillbirth, spontaneous miscarriage or termination-0.0']==0]=0
df['Number of spontaneous miscarriages-0.0'][df['Ever had stillbirth, spontaneous miscarriage or termination-0.0']==0]=0
df['Number of stillbirths-0.0'][df['Ever had stillbirth, spontaneous miscarriage or termination-0.0']==0]=0
df['Age of primiparous women at birth of child-0.0'][df['Number of live births-0.0']==0]=0
df['Age at first live birth-0.0'][df['Number of live births-0.0']==0]=0
df['Age at last live birth-0.0'][df['Number of live births-0.0']==0]=0
df['Birth weight of first child-0.0'][df['Number of live births-0.0']==0]=0
df['Menstruating today-0.0'][(df['Had menopause-0.0']==1)|(df['Had menopause-0.0']==2)]=0
df['Length of menstrual cycle-0.0'][(df['Had menopause-0.0']==1)|(df['Had menopause-0.0']==2)]=0
df['Ever had hysterectomy (womb removed)-0.0'][df['Had menopause-0.0']==2]=1
df['Had menopause-0.0'][df['Had menopause-0.0']==2]=np.nan
df['Age at hysterectomy-0.0'][df['Ever had hysterectomy (womb removed)-0.0']==0]=0
df['Age started hormone-replacement therapy (HRT)-0.0'][df['Ever used hormone-replacement therapy (HRT)-0.0']==0]=0
df['Age last used hormone-replacement therapy (HRT)-0.0'][df['Ever used hormone-replacement therapy (HRT)-0.0']==0]=0
df['Age at bilateral oophorectomy (both ovaries removed)-0.0'][df['Bilateral oophorectomy (both ovaries removed)-0.0']==0]=0
df['Delivery onset methods-0.0'][df['Delivery onset methods-0.0']==9]=np.nan
df['Delivery onset methods-0.1'][df['Delivery onset methods-0.1']==9]=np.nan
df['Delivery onset methods-0.2'][df['Delivery onset methods-0.2']==9]=np.nan
df['Delivery onset methods-0.3'][df['Delivery onset methods-0.3']==9]=np.nan
df['Delivery onset methods-0.4'][df['Delivery onset methods-0.4']==9]=np.nan
df[df<0]=np.nan
df['Spontaneous-0.0']=np.nan
df['Caesarean section-0.0']=np.nan
df['Surgical induction by amniotomy-0.0']=np.nan
df['Medical induction-0.0']=np.nan
df['Combination of surgical and medical induction-0.0']=np.nan
df['Spontaneous-0.0'][(df['Delivery onset methods-0.0']!=1)&(df['Delivery onset methods-0.0'].notna())]=0
df['Spontaneous-0.0'][df['Delivery onset methods-0.0']==1]=1
df['Caesarean section-0.0'][(((df['Delivery onset methods-0.0']!=2)&(df['Delivery onset methods-0.1']!=2)))&(df['Delivery onset methods-0.0'].notna())]=0
df['Caesarean section-0.0'][(df['Delivery onset methods-0.0']==2)|(df['Delivery onset methods-0.1']==2)]=1
df['Surgical induction by amniotomy-0.0'][(((df['Delivery onset methods-0.0']!=3)&(df['Delivery onset methods-0.1']!=3)&(df['Delivery onset methods-0.2']!=3)))&(df['Delivery onset methods-0.0'].notna())]=0
df['Surgical induction by amniotomy-0.0'][(df['Delivery onset methods-0.0']==3)|(df['Delivery onset methods-0.1']==3)|(df['Delivery onset methods-0.2']==3)]=1
df['Medical induction-0.0'][(((df['Delivery onset methods-0.0']!=4)&(df['Delivery onset methods-0.1']!=4)&(df['Delivery onset methods-0.2']!=4)&(df['Delivery onset methods-0.3']!=4)))&(df['Delivery onset methods-0.0'].notna())]=0
df['Medical induction-0.0'][(df['Delivery onset methods-0.0']==4)|(df['Delivery onset methods-0.1']==4)|(df['Delivery onset methods-0.2']==4)|(df['Delivery onset methods-0.3']==4)]=1
df['Combination of surgical and medical induction-0.0'][(((df['Delivery onset methods-0.0']!=5)&(df['Delivery onset methods-0.1']!=5)&(df['Delivery onset methods-0.2']!=5)&(df['Delivery onset methods-0.3']!=5)&(df['Delivery onset methods-0.4']!=5)))&(df['Delivery onset methods-0.0'].notna())]=0
df['Combination of surgical and medical induction-0.0'][(df['Delivery onset methods-0.0']==5)|(df['Delivery onset methods-0.1']==5)|(df['Delivery onset methods-0.2']==5)|(df['Delivery onset methods-0.3']==5)|(df['Delivery onset methods-0.4']==5)]=1
df['Spontaneous-0.0'][(df['Spontaneous-0.0'].isna())&(df['Number of live births-0.0']==0)&(df['Ever had stillbirth, spontaneous miscarriage or termination-0.0']==0)]=0
df['Caesarean section-0.0'][(df['Caesarean section-0.0'].isna())&(df['Number of live births-0.0']==0)&(df['Ever had stillbirth, spontaneous miscarriage or termination-0.0']==0)]=0
df['Surgical induction by amniotomy-0.0'][(df['Surgical induction by amniotomy-0.0'].isna())&(df['Number of live births-0.0']==0)&(df['Ever had stillbirth, spontaneous miscarriage or termination-0.0']==0)]=0
df['Medical induction-0.0'][(df['Medical induction-0.0'].isna())&(df['Number of live births-0.0']==0)&(df['Ever had stillbirth, spontaneous miscarriage or termination-0.0']==0)]=0
df['Combination of surgical and medical induction-0.0'][(df['Combination of surgical and medical induction-0.0'].isna())&(df['Number of live births-0.0']==0)&(df['Ever had stillbirth, spontaneous miscarriage or termination-0.0']==0)]=0
del df['Delivery onset methods-0.0']
del df['Delivery onset methods-0.1']
del df['Delivery onset methods-0.2']
del df['Delivery onset methods-0.3']
del df['Delivery onset methods-0.4']
del df['Time since last menstrual period-0.0']
df['Age at first live birth-0.0'][df['Age at first live birth-0.0'].isna()]=df['Age of primiparous women at birth of child-0.0'][df['Age at first live birth-0.0'].isna()]
df['Age at last live birth-0.0'][df['Age at last live birth-0.0'].isna()]=df['Age of primiparous women at birth of child-0.0'][df['Age at last live birth-0.0'].isna()]
del df['Age of primiparous women at birth of child-0.0']
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
df['Gestational diabetes only-0.0'].fillna(0,inplace=True)
var=[25,1,6,7,10,11,24,27,28,29,30]
df.iloc[:,var].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)

# %%
#Cleaning-Digestive health
j=20
df=pd.read_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'_raw.csv')
d=[]
for i in df.columns:
    i=i.replace('21076','Vomiting when IBS symptoms first began')
    i=i.replace('21075','Bloody diarrhoea when IBS symptoms first began')
    i=i.replace('21074','Diarrhoea when IBS symptoms first began')
    i=i.replace('21073','Fever when IBS symptoms first began')
    i=i.replace('21072','Infection diagnosed alongside IBS when IBS symptoms began')
    i=i.replace('21071','Infectious illness diagnosis status when IBS symptoms first began')
    i=i.replace('21070','Speed of onset of IBS symptoms')
    i=i.replace('21069','Method of coeliac disease/gluten sensitivity diagnosis')
    i=i.replace('21068','Diagnosed with coeliac disease or gluten sensitivity')
    i=i.replace('21067','Long-term/recurrent antibiotics as child or teenager')
    i=i.replace('21066','Born by caesarian section')
    i=i.replace('21065','Family history of IBS')
    i=i.replace('21064','Sensitive stomach')    
    i=i.replace('21063','Ever been offered/sought treatment for depression')
    i=i.replace('21062','Ever been offered/sought treatment for anxiety')    
    i=i.replace('21061','Degree bothered by trouble sleeping in the last 3 months')
    i=i.replace('21060','Degree bothered by feeling tired all the time in the last 3 months')
    i=i.replace('21059','Degree bothered by nausea in the last 3 months')
    i=i.replace('21058','Degree bothered by urinary frequency/bladder irritability in the last 3 months')
    i=i.replace('21057','Degree bothered by pain/problems during intercourse in the last 3 months')
    i=i.replace('21056','Degree bothered by shortness of breath in the last 3 months')
    i=i.replace('21055','Degree bothered by feeling heart pound/race in the last 3 months')
    i=i.replace('21054','Degree bothered by fainting spells in the last 3 months')
    i=i.replace('21053','Degree bothered by dizziness in the last 3 months')
    i=i.replace('21052','Degree bothered by chest pain in the last 3 months')
    i=i.replace('21051','Degree bothered by headaches in the last 3 months')    
    i=i.replace('21050','Degree bothered by menstrual cramps or other problems with period in the last 3 months')    
    i=i.replace('21049','Degree bothered by pain in arms/legs/joints in the past 3 months')
    i=i.replace('21048','Degree bothered by back pain in the past 3 months')
    i=i.replace('21047','Number of weeks (in the last year) at work suffering because of IBS')   
    i=i.replace('21045','Number of weeks absent from work due to IBS, in the last year')
    i=i.replace('21044','Average number of times bowels opened per day')
    i=i.replace('21043','Least number of times bowels opened per week')
    i=i.replace('21042','Greatest number of times bowels opened per day')
    i=i.replace('21041','Degree to which abdominal pain/discomfort/altered bowel habits affect/interfere with life in general')
    i=i.replace('21040','Satisfaction with bowel habits')
    i=i.replace('21039','Severity of current abdominal distension/tightness')
    i=i.replace('21038','Currently suffer from abdominal distension')
    i=i.replace('21037','Number of days (out of 10) with abdominal pain')
    i=i.replace('21036','Severity of current abdominal pain')
    i=i.replace('21035','Currently (in last 3 months) suffer from abdominal pain')
    i=i.replace('21034','Frequency of loose/mushy/watery stools in the last 3 months')
    i=i.replace('21033','Frequency of hard/lumpy stools in the last 3 months')
    i=i.replace('21032','Frequency of harder stools when abdominal discomfort/pain started')
    i=i.replace('21031','Stools looser when abdominal discomfort/pain started')
    i=i.replace('21030','Less frequent bowel movements when abdominal discomfort/pain started')
    i=i.replace('21029','More frequent bowel movements when abdominal discomfort/pain started')
    i=i.replace('21028','Frequency of discomfort/pain getting better or stopping after a bowel movement')
    i=i.replace('21027','Abdominal discomfort/pain for 6 months or longer')
    i=i.replace('21026','Discomfort/pain occurring only during menstrual bleed')
    i=i.replace('21025','Frequency of discomfort/pain in abdomen in last 3 months')
    i=i.replace('21024','Ever diagnosed with IBS')
    i=i.replace('21023','When digestive health questionnaire completed')
    i=i.replace('34-','Year of birth-')
    d.append(i)
df.columns=d    
df['When digestive health questionnaire completed-0.0']=df['When digestive health questionnaire completed-0.0'].str.split('-',expand=True)[0]
df['Age of digestive health questionnaire completed-0.0']=df['When digestive health questionnaire completed-0.0'].astype(int)-df['Year of birth-0.0']
del df['Year of birth-0.0']
del df['When digestive health questionnaire completed-0.0']
df['Degree bothered by menstrual cramps or other problems with period in the last 3 months-0.0'][df['31-0.0']==1]=0
del df['31-0.0']
df.replace(-500,0,inplace=True)
df.replace(-501,1,inplace=True)
df.replace(-502,2,inplace=True)
df.replace(-503,3,inplace=True)
df.replace(-504,4,inplace=True)
df.replace(-600,0,inplace=True)
df.replace(-601,1,inplace=True)
df.replace(-602,2,inplace=True)
df.replace(-801,1,inplace=True)
df.replace(-802,2,inplace=True)
del df['Method of coeliac disease/gluten sensitivity diagnosis-0.0']
del df['Infection diagnosed alongside IBS when IBS symptoms began-0.0']
del df['21046-0.0']
df[df<0]=np.nan
df['Bloody diarrhoea when IBS symptoms first began-0.0'][df['Ever diagnosed with IBS-0.0']==0]=0
df['Fever when IBS symptoms first began-0.0'][df['Ever diagnosed with IBS-0.0']==0]=0
df['Diarrhoea when IBS symptoms first began-0.0'][df['Ever diagnosed with IBS-0.0']==0]=0
df['Number of weeks absent from work due to IBS, in the last year-0.0'][df['Ever diagnosed with IBS-0.0']==0]=0
df['Number of weeks (in the last year) at work suffering because of IBS-0.0'][df['Ever diagnosed with IBS-0.0']==0]=0
df['Speed of onset of IBS symptoms-0.0'][df['Ever diagnosed with IBS-0.0']==0]=0
df['Infectious illness diagnosis status when IBS symptoms first began-0.0'][df['Ever diagnosed with IBS-0.0']==0]=0
df['Vomiting when IBS symptoms first began-0.0'][df['Ever diagnosed with IBS-0.0']==0]=0
df['Severity of current abdominal distension/tightness-0.0'][df['Currently suffer from abdominal distension-0.0']==0]=0
df['Number of days (out of 10) with abdominal pain-0.0'][df['Currently (in last 3 months) suffer from abdominal pain-0.0']==0]=0
df['Severity of current abdominal pain-0.0'][df['Currently (in last 3 months) suffer from abdominal pain-0.0']==0]=0
df['Frequency of harder stools when abdominal discomfort/pain started-0.0'][df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']==0]=0
df['Abdominal discomfort/pain for 6 months or longer-0.0'][df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']==0]=0
df['Frequency of discomfort/pain getting better or stopping after a bowel movement-0.0'][df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']==0]=0
df['Stools looser when abdominal discomfort/pain started-0.0'][df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']==0]=0
df['More frequent bowel movements when abdominal discomfort/pain started-0.0'][df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']==0]=0
df['Less frequent bowel movements when abdominal discomfort/pain started-0.0'][df['Frequency of discomfort/pain in abdomen in last 3 months-0.0']==0]=0
for i in range(df.shape[1]):
    if list(df[list(df)[i]]).count(0)/df[list(df)[i]].notna().sum()>0.9:
        df[list(df)[i]].fillna(0,inplace=True)
var=[20,21,24,28,40]+[i for i in range(42,50)]
df.iloc[:,var].to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_calculted.csv',index=False)
df=df.iloc[:,list(set([i for i in range(df.shape[1])]) - set(var))]
#remove outliers
col=list(df)
max=df.mean()+6*df.std()
min=df.mean()-6*df.std()
for i in range(1,len(col)):
    df.loc[(df[col[i]]<min[col[i]]) | (df[col[i]]>max[col[i]]),col[i]]=np.nan
df.to_csv(file_Pwd+'/'+Category_Name[j]+'/'+Category_Name[j]+'-for_MICE.csv',index=False)
